# %% [markdown]
# # Data Wrangle

# %% [markdown]
# #### DO NOT RUN IT WITHOUT GOING THROUGH THE FULL FILE
#
# ### Libraries used in the test

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import os
import glob
import json

import boto3
import configparser
import matplotlib.pyplot as plt
import pandas as pd
from time import time
import numpy as np
import html
import re

# %%
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))
KEY=config.get('AWS','key')
SECRET= config.get('AWS','secret')

DWH_DB= config.get("CLUSTER","DWH_DB")
DWH_DB_USER= config.get("CLUSTER","DWH_DB_USER")
DWH_DB_PASSWORD= config.get("CLUSTER","DWH_DB_PASSWORD")
DWH_PORT = config.get("CLUSTER","DWH_PORT")

# %% [markdown]
# ## Gather

# %%
s3 = boto3.resource('s3',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                     )

sampleDbBucket =  s3.Bucket("udacity-dend")

# %%
#Functions
def download_files_from_s3(prefix, limit):
    """
    Summary line. 
    Download files from AWS_S3
  
    Parameters: 
    arg1 (prefix of files to be downloaded)
    arg2 (number of files to be downloaded)
  
    Returns: 
    None
    """    
    i = 0
    files = []    
    tenPercentOfTotal = round(limit/10)
    
    for obj in sampleDbBucket.objects.filter(Prefix=prefix):
        if(len(files) % tenPercentOfTotal == 0 and i>1):
            print('Downloaded {}/{}'.format(len(files), limit) )
            
        if i>limit:
            break
        if obj.key.rsplit('/', 1)[1] != '':        
            folder = obj.key.rsplit('/', 1)[0]
            file= obj.key.rsplit('/', 1)[1]
            files.append(obj.key)
            #print(obj.key)
            os.makedirs(folder, exist_ok=True)  # succeeds even if directory exists.
            sampleDbBucket.download_file(obj.key, obj.key)        
        i+=1
        
def get_all_files(folder):
    """
    Summary line. 
    Scans folder and prepares files list
  
    Parameters: 
    arg1 (folder path)
  
    Returns: 
    Array of filepath
    """     
    # 1. checking your current working directory
    print('Current Working Directory : ',os.getcwd())

    # Get your current folder and subfolder event data
    filepath = os.getcwd() + folder
    print('Scanning Directory : ',filepath)

    # 2. Create a for loop to create a list of files and collect each filepath
    #    join the file path and roots with the subdirectories using glob
    #    get all files matching extension from directory
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))

    # 3. get total number of files found
    num_files = len(all_files)
    print('{} files found'.format(num_files))
    #print(all_files)
    return all_files
        
        
def merge_song_files(folder, mergedfile):        
    """
    Summary line. 
    Merges all song data into one file. Each song file contains only one JSON object.
  
    Parameters: 
    arg1 (folder path)
    arg2 (merged output filename)
  
    Returns: 
    None
    """     
    output_list = []
    all_files = get_all_files(folder)
    if len(all_files) > 0:
        for f in all_files:
            with open(f, "rb") as infile:
                output_list.append(json.load(infile))

        with open(mergedfile, "w", encoding="utf8") as outfile:
            json.dump(output_list, outfile)    

            
def merge_log_files(folder, mergedfile):
    """
    Summary line. 
    Merges all log data into one file. Each log file may contain more than one JSON objects and there will be only one JSON object per line.
  
    Parameters: 
    arg1 (folder path)
    arg2 (merged output filename)
  
    Returns: 
    None
    """         
    output_list = []
    all_files = get_all_files(folder)
    if len(all_files) > 0:
        for f in all_files:
            with open(f, 'r') as f:
                for line in f:
                    output_list.append(json.loads(line))

        with open(mergedfile, "w", encoding="utf8") as outfile:
            json.dump(output_list, outfile)    

            
def json_to_dataframe(infile):
    """
    Summary line. 
    Reads JSON file loads panda datafame
  
    Parameters: 
    arg1 (filename)
  
    Returns: 
    dataframe
    """         
    with open(infile) as datafile:
        data = json.load(datafile)

    df = pd.DataFrame(data)
    print("df shape {}".format(df.shape))
    return df

# %%
# %%time
#Getting info on number of files in AWS for prefix song_data
size = sum(1 for _ in sampleDbBucket.objects.filter(Prefix="song_data"))
print(size)
# Out:
# 14897
# CPU times: user 3.43 s, sys: 24 ms, total: 3.45 s
# Wall time: 10.4 s

# %%
# %%time
#Getting info on number of files in AWS for prefix log_data
size = sum(1 for _ in sampleDbBucket.objects.filter(Prefix="log_data"))
print(size)
# Out:
# 31
# CPU times: user 14.5 ms, sys: 0 ns, total: 14.5 ms
# Wall time: 98.9 ms

# %%
#Displaying the files
i = 0
for obj in sampleDbBucket.objects.filter(Prefix="song_data"):
    if i>5:
        break
    #print(obj.key)
    if obj.key.rsplit('/', 1)[1] != '': #condition to ignore folderPath
        print(obj.key.rsplit('/', 1))
    i+=1
# Out:
# ['song_data/A/A/A', 'TRAAAAK128F9318786.json']
# ['song_data/A/A/A', 'TRAAAAV128F421A322.json']
# ['song_data/A/A/A', 'TRAAABD128F429CF47.json']
# ['song_data/A/A/A', 'TRAAACN128F9355673.json']
# ['song_data/A/A/A', 'TRAAAEA128F935A30D.json']

# %%
# %%time
#This takes almost 1hr 30mins - So commenting it out
#download_files_from_s3('song_data', 20000)
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.39 µs

# %%
# %%time
#This takes almost 10Seconds - All done here, so not required to do it again
#download_files_from_s3('log_data', 50)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.44 µs

# %%
#Merging Done - So commenting it out
#merge_song_files('/song_data', 'merged_song_data.json')

# %%
song_df = json_to_dataframe('merged_song_data.json')
# Out:
# df shape (14896, 10)

# %%
#df1 = pd.read_json('log_data/2018/11/2018-11-02-events.json', lines=True)
#df1.head()

# %%
#Merging Done - So commenting it out
#merge_log_files('/log_data', 'merged_log_data.json')

# %%
log_df = json_to_dataframe('merged_log_data.json')
# Out:
# df shape (8056, 18)

# %%
#Downloading Done - So not doing it again
#s3://udacity-dend/log_json_path.json
#No clue what is this file gonna be used for

#sampleDbBucket.download_file('log_json_path.json', 'log_json_path.json')

# %% [markdown]
# ## Assess

# %% [markdown]
# ### song_df dataset

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14896 entries, 0 to 14895
# Data columns (total 10 columns):
# artist_id           14896 non-null object
# artist_latitude     5277 non-null float64
# artist_location     14895 non-null object
# artist_longitude    5277 non-null float64
# artist_name         14896 non-null object
# duration            14896 non-null float64
# num_songs           14896 non-null int64
# song_id             14896 non-null object
# title               14896 non-null object
# year                14896 non-null int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
song_df.head()
# Out:
#             artist_id  artist_latitude               artist_location  \
# 0  ARTH9041187FB43E1F              NaN                St. Joseph, MO
# 1  ARQFUGM1187FB3E24E              NaN  Los Angeles, California, USA
# 2  ARM2L4M1187B9B5F51              NaN
# 3  ARCQMJH1187B9B53CC         30.00875                Smithville, TX
# 4  ARNH6Q11187FB40FDD         40.65507                  Brooklyn, NY
#
#    artist_longitude                              artist_name   duration  \
# 0               NaN                                   Eminem  312.26730
# 1               NaN                      Black Label Society  258.95138
# 2               NaN                               FreQ Nasty  205.53098
# 3         -97.16001  DJ Screw_ B-Legit_ Lil Keke_ Phaz_ Duke  262.89587
# 4         -73.94888                          Jeru The Damaja  245.18485
#
#    num_songs             song_id  \
# 0          1  SOLXDDC12A6701FBFD
# 1          1  SOHVHKM12A8C13F716
# 2          1  SOFYPCI12A6701FF60
# 3          1  SOPEVXO12AB0185938
# 4          1  SOYZIYS12A6D4F5ED5
#
#                                              title  year
# 0                                         I'm Back  2000
# 1                                  Counterfeit God  2000
# 2                                            Fresh  2002
# 3  Screw Mix (feat. B-Legit_ Lil Keke_ Phaz_ Duke)     0
# 4                  Revenge Of The Prophet (Part 5)  1996

# %%
#Doesn't have latitude & longitude data(2926)
song_df[(song_df.artist_latitude.isnull()) & (song_df.artist_longitude.isnull()) & (song_df.artist_location != '')].head()
#song_df[(song_df.artist_latitude.isnull()) & (song_df.artist_longitude.isnull()) & (song_df.artist_location != '')].shape
# Out:
#              artist_id  artist_latitude               artist_location  \
# 0   ARTH9041187FB43E1F              NaN                St. Joseph, MO
# 1   ARQFUGM1187FB3E24E              NaN  Los Angeles, California, USA
# 24  ARJ0AL61187B9A3F27              NaN                       Georgia
# 27  ARJ2PMY1187FB5B563              NaN              NY - Long Island
# 31  ARWR6RK1187FB3AB52              NaN               Long Island, NY
#
#     artist_longitude           artist_name   duration  num_songs  \
# 0                NaN                Eminem  312.26730          1
# 1                NaN   Black Label Society  258.95138          1
# 24               NaN           Katie Melua  193.51465          1
# 27               NaN         Burning Spear  334.31465          1
# 31               NaN  From Autumn To Ashes  147.64363          1
#
#                song_id                              title  year
# 0   SOLXDDC12A6701FBFD                           I'm Back  2000
# 1   SOHVHKM12A8C13F716                    Counterfeit God  2000
# 24  SOFHFLK12AF72A4FB9  Mary Pickford (Used To Eat Roses)  2008
# 27  SOVTFUO12A6310D813  The Invasion (Aka Black Wa Da Da)     0
# 31  SOHKXAC12A58A7F6E5                                 IV  2002

# %%
#Around 6693 rows doesn't have location & lats & long
print(song_df[(song_df.artist_location == '') & (song_df.artist_latitude.isnull()) & (song_df.artist_longitude.isnull())].shape)
song_df[(song_df.artist_location == '') & (song_df.artist_latitude.isnull()) & (song_df.artist_longitude.isnull())].head()
# Out:
# (6693, 10)
#              artist_id  artist_latitude artist_location  artist_longitude  \
# 2   ARM2L4M1187B9B5F51              NaN                               NaN
# 5   AR1U3BY1187B9B136F              NaN                               NaN
# 6   AR1ILHX1187FB53892              NaN                               NaN
# 9   AR4K1XY1187B99479D              NaN                               NaN
# 11  AR1GZB111C8A421C7A              NaN                               NaN
#
#              artist_name   duration  num_songs             song_id  \
# 2             FreQ Nasty  205.53098          1  SOFYPCI12A6701FF60
# 5   God Lives Underwater  215.40526          1  SOPWHEV12AB017DC10
# 6     Magtens Korridorer  266.63138          1  SOUPGMR12AB01820DD
# 9         General Degree  213.68118          1  SOETCUF12AB0182C10
# 11            Andre Crom  400.82240          1  SOYXOEY12AB0180988
#
#                    title  year
# 2                  Fresh  2002
# 5   Don't Know How To Be  1995
# 6              Døden Nær  2005
# 9             Last Night     0
# 11                  Warp     0

# %%
#Thought one artist_id could have location details and same artist_id didn't have location details. It doesn't look like that
bool_series = song_df.artist_id.duplicated()
song_df[bool_series].sort_values(by=['artist_id']).head()
# Out:
#                 artist_id  artist_latitude        artist_location  \
# 11984  AR00B1I1187FB433EB              NaN      Stockholm, Sweden
# 5580   AR00FVC1187FB5BE3E         25.67084  Monterrey, NL, México
# 7301   AR00FVC1187FB5BE3E         25.67084  Monterrey, NL, México
# 2859   AR00Y9I1187B999412              NaN
# 13904  AR00Y9I1187B999412              NaN
#
#        artist_longitude       artist_name   duration  num_songs  \
# 11984               NaN  Eagle-Eye Cherry  207.15057          1
# 5580         -100.30953             Panda  225.82812          1
# 7301         -100.30953             Panda  194.66404          1
# 2859                NaN         Akercocke  467.59138          1
# 13904               NaN         Akercocke  256.52200          1
#
#                   song_id                  title  year
# 11984  SONHPYP12A8C1417AE        One Good Reason  2000
# 5580   SOSIUCT12AB0182323    Conversación Casual     0
# 7301   SOIBMQP12AB017FF20  Espejismos Y Visiones     0
# 2859   SOLMAZB12AB017FE90              Leviathan  2003
# 13904  SOQQWVQ12A8C132635       Breaking Silence  2001

# %%
#None needs to changed to blank
song_df[song_df.artist_location.isnull()]
# Out:
#                 artist_id  artist_latitude artist_location  artist_longitude  \
# 11357  AR0JBXL1187FB52810         19.40904            None         -99.14977
#
#        artist_name   duration  num_songs             song_id      title  year
# 11357  St. Vincent  307.53914          1  SORMAXQ12A8C139224  Landmines  2007

# %%
#only this row had lats & long without location name
song_df[(song_df.artist_location == '') & ( (song_df.artist_longitude.notnull()) | (song_df.artist_latitude.notnull()) )].head(50)
# Out:
#                 artist_id  artist_latitude artist_location  artist_longitude  \
# 10229  ARZPWMP12086C175D6          31.1689                        -100.07715
#
#       artist_name   duration  num_songs             song_id           title  \
# 10229      Jannes  184.08444          1  SORUGLY12AB0187CC5  Laat Me Alleen
#
#        year
# 10229     0

# %%
#Geo-coordinates are pointing to Salem, IL
song_df[song_df.artist_location.str.contains('originally', na=False)]
# Out:
#                 artist_id  artist_latitude  \
# 12184  ARAH4TU1187FB51D28         38.62666
# 12624  ARAH4TU1187FB51D28         38.62666
# 14699  ARAH4TU1187FB51D28         38.62666
#
#                               artist_location  artist_longitude  \
# 12184  New York City (Salem, IL - originally)         -88.94561
# 12624  New York City (Salem, IL - originally)         -88.94561
# 14699  New York City (Salem, IL - originally)         -88.94561
#
#                      artist_name   duration  num_songs             song_id  \
# 12184               Bill Laswell  132.67546          1  SOTTMXT12AF72A1B42
# 12624               Bill Laswell  258.87302          1  SOHLWHP12A6D4F614B
# 14699  Jah Wobble & Bill Laswell  463.35955          1  SOURIGQ12AB017FCA3
#
#                           title  year
# 12184  The Gary Selchie - Solas     0
# 12624        Don't Lose Control     0
# 14699                   Subcode     0

# %%
song_df['num_songs'].value_counts()
# Out:
# 1    14896
# Name: num_songs, dtype: int64

# %%
#Location name is not in consistent format
song_df['artist_location'].value_counts()
# Out:
#                                     6694
# London, England                      245
# Los Angeles, CA                      217
# New York, NY                         183
# Chicago, IL                          120
# California - LA                      103
# NY - New York City                    99
# Detroit, MI                           77
# Brooklyn, NY                          74
# California                            64
# Philadelphia, PA                      63
# Boston, MA                            63
# Seattle, WA                           59
# San Francisco, CA                     59
# Texas                                 57
# Atlanta, GA                           53
# Sweden                                50
# Glasgow, Scotland                     48
# Manchester, England                   48
# United States                         47
# London                                47
# Memphis, TN                           46
# Kingston, Jamaica                     46
# England                               45
# Florida                               43
# Birmingham, England                   43
# Berlin, Germany                       39
# New Jersey                            39
# New York                              39
# California - SF                       38
#                                     ...
# Santiago de Cuba                       1
# Elk City, OK                           1
# Cabra, Dublin, Ireland                 1
# SCOTTSDALE, Arizona                    1
# Mooringsport, Louisiana                1
# OH                                     1
# ?, Illinois                            1
# Ulm, Germany                           1
# Vernon, British Columbia, Canada       1
# Rosenheim, Germany                     1
# Tabor City, NC                         1
# Alaska                                 1
# Middlebourne, WV                       1
# Brixton, England                       1
# Chiswick, England                      1
# Ludovic Navarre                        1
# UK - England - North East              1
# Amityville, NY                         1
# Redding, CA                            1
# Fresno, CA                             1
# Sveio                                  1
# Perth Amboy, NJ                        1
# Los Angeles &amp; New York             1
# COLUMBIA, Maryland                     1
# Algeria                                1
# USA                                    1
# Bend, Oregon                           1
# Metro Detroit                          1
# Abilene, Texas                         1
# New Jersey USA                         1
# Name: artist_location, Length: 2084, dtype: int64

# %%
# Shows rows where any cell has null values.
hasnull_df = song_df[song_df.isnull().any(1)]
hasnull_df2 = hasnull_df[~( (hasnull_df.artist_location == '') & (hasnull_df.artist_latitude.isnull()) & (hasnull_df.artist_longitude.isnull()) )]
hasnull_df3 = hasnull_df2[~( (hasnull_df2.artist_location == '') | (hasnull_df2.artist_latitude.isnull()) | (hasnull_df2.artist_longitude.isnull()) )]
hasnull_df3
# Out:
#                 artist_id  artist_latitude artist_location  artist_longitude  \
# 11357  AR0JBXL1187FB52810         19.40904            None         -99.14977
#
#        artist_name   duration  num_songs             song_id      title  year
# 11357  St. Vincent  307.53914          1  SORMAXQ12A8C139224  Landmines  2007

# %%
#No duplicate records
print('All = ',song_df.shape)
bool_series = song_df.duplicated()
song_unique_df = song_df[~bool_series]
print('Unique = ',song_unique_df.shape)
# Out:
# All =  (14896, 10)
# Unique =  (14896, 10)

# %% [markdown]
# ### log_df dataset

# %%
log_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8056 entries, 0 to 8055
# Data columns (total 18 columns):
# artist           6820 non-null object
# auth             8056 non-null object
# firstName        7770 non-null object
# gender           7770 non-null object
# itemInSession    8056 non-null int64
# lastName         7770 non-null object
# length           6820 non-null float64
# level            8056 non-null object
# location         7770 non-null object
# method           8056 non-null object
# page             8056 non-null object
# registration     7770 non-null float64
# sessionId        8056 non-null int64
# song             6820 non-null object
# status           8056 non-null int64
# ts               8056 non-null int64
# userAgent        7770 non-null object
# userId           8056 non-null object
# dtypes: float64(2), int64(4), object(12)
# memory usage: 1.1+ MB

# %%
log_df.head()
# Out:
#             artist       auth firstName gender  itemInSession lastName  \
# 0  The Grass Roots  Logged In      Sara      F             72  Johnson
# 1            Stars  Logged In      Sara      F             73  Johnson
# 2   Eddie Palmieri  Logged In      Sara      F             74  Johnson
# 3      The Bravery  Logged In      Sara      F             75  Johnson
# 4          K.U.K.L  Logged In      Sara      F             76  Johnson
#
#       length level           location method      page  registration  \
# 0  166.71302  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
# 1  298.94485  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
# 2  391.83628  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
# 3  168.14975  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
# 4  181.28934  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
#
#    sessionId                                song  status             ts  \
# 0        411                Let's Live For Today     200  1542153802796
# 1        411  Time Can Never Kill The True Heart     200  1542153968796
# 2        411                          Nada De Ti     200  1542154266796
# 3        411                             Give In     200  1542154657796
# 4        411                                Anna     200  1542154825796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95
# 1  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95
# 2  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95
# 3  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95
# 4  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95

# %%
log_df.auth.value_counts()
# Out:
# Logged In     7770
# Logged Out     286
# Name: auth, dtype: int64

# %%
#log_df[(log_df.userId == '95') & (log_df.sessionId == 411)].sort_values(by=['itemInSession'])
log_df[(log_df.auth == 'Logged In')].sort_values(by=['itemInSession']).head()
# Out:
#                     artist       auth firstName gender  itemInSession  \
# 3091         Chris Cornell  Logged In    Aleena      F              0
# 3081        Patrick Jumpen  Logged In      Ryan      M              0
# 3083            Hoobastank  Logged In    Cierra      F              0
# 1325  Kid Cudi Vs Crookers  Logged In  Brantley      M              0
# 1323          Powderfinger  Logged In    Harper      M              0
#
#      lastName     length level                               location method  \
# 3091    Kirby  353.69751  paid               Waterloo-Cedar Falls, IA    PUT
# 3081    Smith  208.87465  free     San Jose-Sunnyvale-Santa Clara, CA    PUT
# 3083   Finley  241.39710  free                           Richmond, VA    PUT
# 1325     West  162.97751  free    Portland-Vancouver-Hillsboro, OR-WA    PUT
# 1323  Barrett  276.68853  paid  New York-Newark-Jersey City, NY-NJ-PA    PUT
#
#           page  registration  sessionId  \
# 3091  NextSong  1.541023e+12        350
# 3081  NextSong  1.541017e+12        480
# 3083  NextSong  1.541013e+12        132
# 1325  NextSong  1.541057e+12        242
# 1323  NextSong  1.540685e+12        129
#
#                                            song  status             ts  \
# 3091  Sunshower (Great Expectations Soundtrack)     200  1541835258796
# 3081                                    Holiday     200  1541979540796
# 3083                               Say The Same     200  1541808927796
# 1325                               Day 'N' Nite     200  1541407807796
# 1323                               My Happiness     200  1541407366796
#
#                                               userAgent userId
# 3091  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     44
# 3081  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 3083  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     96
# 1325  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     28
# 1323  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     42

# %%
#Total Unique Songs
len(log_df.song.unique())
# Out:
# 5190

# %%
#Status Error
# 200 = OK; 307 = Redirect; 404 = Resource not found
log_df.status.value_counts()
# Out:
# 200    7846
# 307     201
# 404       9
# Name: status, dtype: int64

# %%
log_df[log_df.status == 307].head()
# Out:
#     artist        auth firstName gender  itemInSession lastName  length level  \
# 77    None   Logged In      Lily      F              1   Cooper     NaN  free
# 80    None  Logged Out      None   None              4     None     NaN  free
# 100   None   Logged In     Rylan      M              2   George     NaN  free
# 170   None   Logged In     Chloe      F              3   Cuevas     NaN  free
# 285   None   Logged In      Kate      F              4  Harrell     NaN  paid
#
#                               location method            page  registration  \
# 77                        Columbia, SC    PUT          Logout  1.541058e+12
# 80                                None    PUT           Login           NaN
# 100              Birmingham-Hoover, AL    PUT  Submit Upgrade  1.541020e+12
# 170  San Francisco-Oakland-Hayward, CA    PUT  Submit Upgrade  1.540941e+12
# 285           Lansing-East Lansing, MI    PUT          Logout  1.540473e+12
#
#      sessionId  song  status             ts  \
# 77          58  None     307  1542174900796
# 80          58  None     307  1542174942796
# 100        479  None     307  1542177314796
# 170        568  None     307  1542184236796
# 285        558  None     307  1542197300796
#
#                                              userAgent userId
# 77   "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebK...     59
# 80                                                None
# 100  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     16
# 170  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 285  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     97

# %%
log_df[log_df.registration.isnull()].head()
# Out:
#     artist        auth firstName gender  itemInSession lastName  length level  \
# 78    None  Logged Out      None   None              2     None     NaN  free
# 79    None  Logged Out      None   None              3     None     NaN  free
# 80    None  Logged Out      None   None              4     None     NaN  free
# 286   None  Logged Out      None   None              5     None     NaN  paid
# 287   None  Logged Out      None   None              6     None     NaN  paid
#
#     location method   page  registration  sessionId  song  status  \
# 78      None    GET   Home           NaN         58  None     200
# 79      None    GET   Home           NaN         58  None     200
# 80      None    PUT  Login           NaN         58  None     307
# 286     None    GET   Home           NaN        558  None     200
# 287     None    PUT  Login           NaN        558  None     307
#
#                 ts userAgent userId
# 78   1542174903796      None
# 79   1542174941796      None
# 80   1542174942796      None
# 286  1542197341796      None
# 287  1542197342796      None

# %%
log_df[log_df.artist.isnull()].head()
# Out:
#    artist       auth firstName gender  itemInSession   lastName  length level  \
# 10   None  Logged In     Wyatt      M              0      Scott     NaN  free
# 15   None  Logged In      Sara      F             85    Johnson     NaN  paid
# 16   None  Logged In      Sara      F             86    Johnson     NaN  paid
# 17   None  Logged In      Sara      F             87    Johnson     NaN  paid
# 18   None  Logged In  Mohammad      M              0  Rodriguez     NaN  free
#
#                                    location method   page  registration  \
# 10                Eureka-Arcata-Fortuna, CA    GET   Home  1.540872e+12
# 15                        Winston-Salem, NC    GET   Home  1.540809e+12
# 16                        Winston-Salem, NC    GET  About  1.540809e+12
# 17                        Winston-Salem, NC    GET   Home  1.540809e+12
# 18  Sacramento--Roseville--Arden-Arcade, CA    GET   Home  1.540512e+12
#
#     sessionId  song  status             ts  \
# 10        551  None     200  1542156103796
# 15        411  None     200  1542156862796
# 16        411  None     200  1542157048796
# 17        411  None     200  1542157182796
# 18        539  None     200  1542162914796
#
#                                             userAgent userId
# 10  Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....      9
# 15  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95
# 16  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95
# 17  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95
# 18  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     88

# %% [markdown]
# ### Quality
# 1. log_df : Only page='NextSong' is required(not filtering in dataframe)
# 2. log_df : Delete rows which has userId as null/blank(not filtering in dataframe)
# 3. song_df: Around 6693 rows doesn't have location & lats & long.(No Action)
# 4. song_df: Around 4762 rows have Year has 0 (No Action)
# 5. song_df: Format of location is not consistent. London, England/Texas/California - LA
# 6. song_df: Around 2926 rows has just the location name doesn't have latitude, longitude(handled in tidiness)
# 7. song_df: artist_location has None & Blank (change none to blank) and other location corrections will be handled
# 8. log_df : When auth='Logged Out' it doesn't have userId. But when 'Logged In', userId is captured. Due to this quality issue, you cannot say exactly how long a user id logged in. You can just make a guess by listing the longs.(No Action)
#
# ### Tidiness
# 1. log_df : convert ts from integer to timestamp
# 2. song_df: column num_songs can be removed as it has only one value ( 1 ) (No Action in dataframe)
# 3. log_df : convert registration column to int(has null convert to 0 then int)
# 4. song_df: Add columns : county, city, state, country
# 5. song_df: Round duration column(value is seconds, it doesn't have to be in float)

# %% [markdown]
# ## Clean

# %%
song_df_copy = song_df.copy()
log_df_copy = log_df.copy()

# %%
print('Total rows in song_df_copy = {}'.format(song_df_copy.shape[0]))
print('Total rows in log_df_copy = {}'.format(log_df_copy.shape[0]))
# Out:
# Total rows in song_df_copy = 14896
# Total rows in log_df_copy = 8056

# %% [markdown]
# ### Issue 1 : Location corrections
# ### Define
# song_df: artist_location has None & Blank (change none to blank)
# ### Code

# %%
song_df_copy[song_df_copy.artist_location.isnull()]
# Out:
#                 artist_id  artist_latitude artist_location  artist_longitude  \
# 11357  AR0JBXL1187FB52810         19.40904            None         -99.14977
#
#        artist_name   duration  num_songs             song_id      title  year
# 11357  St. Vincent  307.53914          1  SORMAXQ12A8C139224  Landmines  2007

# %%
song_df_copy.artist_location = song_df_copy.artist_location.replace(np.nan, '')

# %% [markdown]
# ### Test

# %%
song_df_copy[song_df_copy.artist_location.isnull()]
# Out:
# Empty DataFrame
# Columns: [artist_id, artist_latitude, artist_location, artist_longitude, artist_name, duration, num_songs, song_id, title, year]
# Index: []

# %% [markdown]
# ### Define
# Artist Location = New York City (Salem, IL - originally) and geo-coordinates are pointing to Salem, IL not New York City.

# %%
song_df_copy[song_df_copy.artist_location.str.contains('originally', na=False)]
# Out:
#                 artist_id  artist_latitude  \
# 12184  ARAH4TU1187FB51D28         38.62666
# 12624  ARAH4TU1187FB51D28         38.62666
# 14699  ARAH4TU1187FB51D28         38.62666
#
#                               artist_location  artist_longitude  \
# 12184  New York City (Salem, IL - originally)         -88.94561
# 12624  New York City (Salem, IL - originally)         -88.94561
# 14699  New York City (Salem, IL - originally)         -88.94561
#
#                      artist_name   duration  num_songs             song_id  \
# 12184               Bill Laswell  132.67546          1  SOTTMXT12AF72A1B42
# 12624               Bill Laswell  258.87302          1  SOHLWHP12A6D4F614B
# 14699  Jah Wobble & Bill Laswell  463.35955          1  SOURIGQ12AB017FCA3
#
#                           title  year
# 12184  The Gary Selchie - Solas     0
# 12624        Don't Lose Control     0
# 14699                   Subcode     0

# %%
song_df_copy[song_df_copy.artist_location.str.contains('Belgica -- Namur, Namur/Ghent, East Flanders', na=False)]
# Out:
#                artist_id  artist_latitude  \
# 1110  ARZEWUR1187FB53DC8         50.45663
#
#                                    artist_location  artist_longitude  \
# 1110  Belgica -- Namur, Namur/Ghent, East Flanders           4.87137
#
#      artist_name   duration  num_songs             song_id  \
# 1110   Enthroned  240.74404          1  SOXCWTT12AC9075756
#
#                     title  year
# 1110  The Vitalized Shell  2010

# %%
song_df_copy[song_df_copy.artist_location.str.contains('D�orf, Germany', na=False)]
# Out:
#                 artist_id  artist_latitude artist_location  artist_longitude  \
# 251    ARI9UV41187B98AB58              NaN  D�orf, Germany               NaN
# 1257   ARQFRTG1187FB3F003              NaN  D�orf, Germany               NaN
# 6028   AR1ZKBE1187FB53629              NaN  D�orf, Germany               NaN
# 7095   AROZOP31187FB5A969          50.7266  D�orf, Germany           6.51747
# 8746   AR1ZKBE1187FB53629              NaN  D�orf, Germany               NaN
# 12218  AR1ZKBE1187FB53629              NaN  D�orf, Germany               NaN
# 12585  AR1ZKBE1187FB53629              NaN  D�orf, Germany               NaN
# 12830  ARHJMEF1187FB415AE              NaN  D�orf, Germany               NaN
# 12902  ARD3OO31187FB4F937          50.7266  D�orf, Germany           6.51747
# 13197  AROZOP31187FB5A969          50.7266  D�orf, Germany           6.51747
# 13802  AROZOP31187FB5A969          50.7266  D�orf, Germany           6.51747
#
#           artist_name   duration  num_songs             song_id  \
# 251          Kreidler  128.54812          1  SOYWKMX12A6D4FA6A0
# 1257   Waldo's People  197.58975          1  SOMKOPP12A8C13BD34
# 6028        Kraftwerk  272.03873          1  SOXOUJH12A6D4FC39B
# 7095       Propaganda  395.31057          1  SOPZREU12A58A79EAB
# 8746        Kraftwerk  201.09016          1  SOXVRHB12A8C13F14B
# 12218       Kraftwerk  399.33342          1  SORWDCM12A6D4FC397
# 12585       Kraftwerk   54.69995          1  SOPJCER12A6D4FCFCE
# 12830      Fehlfarben  291.13424          1  SOJXNPU12A8C13170B
# 12902   Mouse On Mars  316.76036          1  SOKUJRJ12A6D4FA026
# 13197      Propaganda  311.22240          1  SORQPVK12A6D4F7F78
# 13802      Propaganda   46.68036          1  SOFJIER12A8C13C453
#
#                                              title  year
# 251                                       Hillwood  1996
# 1257                              U Drive Me Crazy  1998
# 6028     Pocket Calculator (2009 Digital Remaster)     0
# 7095                   Das Testament Des Dr Mabuse     0
# 8746              Titanium (2009 Digital Remaster)     0
# 12218        Computer Love (2009 Digital Remaster)     0
# 12585  The Voice Of Energy (2009 Digital Remaster)     0
# 12830                        Magnificent Obsession  1983
# 12902                                First : Break  2001
# 13197                         Heaven Give Me Words     0
# 13802                                       Loving     0

# %%
song_df_copy[song_df_copy.artist_location.str.contains('�gelholm, Sweden', na=False)]
# Out:
#               artist_id  artist_latitude   artist_location  artist_longitude  \
# 830  ARNUU2R1187B9A316C         62.19845  �gelholm, Sweden          17.55142
#
#               artist_name  duration  num_songs             song_id  \
# 830  Sounds Like Violence  266.4224          1  SOJIUNI12A6D4FCA34
#
#             title  year
# 830  The Greatest  2007

# %%
song_df_copy[song_df_copy.artist_location.str.contains('Dubioza kolektiv', na=False)]
# Out:
#               artist_id  artist_latitude  \
# 461  ARTHJGQ1187FB42F1F          43.8586
#
#                                        artist_location  artist_longitude  \
# 461  Dubioza kolektiv (aka Dubioza as referred to b...           18.4295
#
#           artist_name   duration  num_songs             song_id      title  \
# 461  Dubioza kolektiv  318.85016          1  SOLPTHV12AC9073057  Marijuana
#
#      year
# 461  2006

# %%
song_df_copy[song_df_copy.artist_location.str.contains('href', na=False)]
# Out:
#                 artist_id  artist_latitude  \
# 5785   AR4T2IF1187B9ADBB7         63.96027
# 7451   AR4T2IF1187B9ADBB7         63.96027
# 9049   AR4T2IF1187B9ADBB7         63.96027
# 10749  AR4T2IF1187B9ADBB7         63.96027
# 11505  AR4T2IF1187B9ADBB7         63.96027
#
#                                          artist_location  artist_longitude  \
# 5785   <a href="http://billyidol.net" onmousedown='Un...          10.22442
# 7451   <a href="http://billyidol.net" onmousedown='Un...          10.22442
# 9049   <a href="http://billyidol.net" onmousedown='Un...          10.22442
# 10749  <a href="http://billyidol.net" onmousedown='Un...          10.22442
# 11505  <a href="http://billyidol.net" onmousedown='Un...          10.22442
#
#       artist_name   duration  num_songs             song_id  \
# 5785   Billy Idol  287.92118          1  SOVYXYL12AF72A3373
# 7451   Billy Idol  247.53587          1  SOLQYSZ12AB0181F97
# 9049   Billy Idol  443.14077          1  SOIEXLS12A6D4F792F
# 10749  Billy Idol  237.06077          1  SOETDBF12A81C20BC0
# 11505  Billy Idol  233.22077          1  SOVIYJY12AF72A4B00
#
#                                               title  year
# 5785             Rebel Yell (1999 Digital Remaster)  1983
# 7451                               Mony Mony (Live)  1987
# 9049                                      Shangrila  1993
# 10749                                 Body Snatcher  2005
# 11505  The Dead Next Door (Digitally Remastered 99)  1983

# %%
#artist_location has integer values
for index, row in song_df_copy.iterrows():
    if(type(row['artist_location']) == int):
        print(row.values)
# Out:
# ['ARPPJJO1187B99D171' 25.03512 100 121.5152 'Michael Stearns' 427.59791 1
#  'SOEBWIE12A8C14380F' 'Sacred Site Soundtrack' 1993]
# ['ARBZIN01187FB362CC' 1.32026 27 103.78871 'Paris Hilton' 192.28689 1
#  'SOERIDA12A6D4F8506' 'I Want You (Album Version)' 2006]
# ['ARC0IOF1187FB3F6E6' nan 108 nan 'Huey Lewis & The News' 286.4322 1
#  'SOHDWWH12A6D4F7F6A' 'I Want A New Drug' 1983]
# ['ARZ4DLQ1187B9B9106' nan 99 nan 'Frankie Bones' 196.0224 1
#  'SOPNQYA12AB018A04E' 'Circus Plate #1' 2005]
# ['ARC0IOF1187FB3F6E6' nan 108 nan 'Huey Lewis And The News' 216.11057 1
#  'SOTIFMS12A5891F8D1' "It's Alright (LP Version)" 2005]
# ['ARC0IOF1187FB3F6E6' nan 108 nan 'Huey Lewis And The News' 345.96526 1
#  'SOHVMFI12A8C13C63E' 'Thank You #19 (LP Version)' 2005]
# ['ARBZIN01187FB362CC' 1.32026 27 103.78871 'Paris Hilton' 274.05016 1
#  'SOYEDMV12A58A7AF6D' "Do Ya Think I'm Sexy (Album Version)" 2006]
# ['ARV36QK1187FB52260' nan 104 nan 'Charlie Hunter Trio' 278.83057 1
#  'SOOIAVT12A8C13B7F9' 'Drop A Dime' 2007]
# ['ARZ8MVL1187FB41D17' 35.85683 780 129.2459 'Shout Out Out Out Out'
#  233.9522 1 'SOFIUCS12AB01896AD' 'How Do I Maintain Pt. II' 2009]
# ['ARZ4DLQ1187B9B9106' nan 99 nan 'Frankie Bones' 163.42159 1
#  'SOIQYCB12AC468A56D' 'The Saga Continues' 0]
# ['ARYV92D1187B9B67E2' 25.06634 104 121.53189 'The Amity Affliction'
#  310.77832 1 'SOTSSCM12AB017FD93' 'Severance' 2005]
# ['AREUT471187FB47D1D' 19.48498 20 -99.18169 'Newworldaquarium' 513.67138 1
#  'SOJWLCO12AC46873DB' 'NoworldbutU' 2008]

# %%
for index, row in song_df_copy.iterrows():
    if(type(row['artist_location']) == int):
        song_df_copy.at[index,'artist_location']=''

# %%
#artist_location has href links
for index, row in song_df_copy.iterrows():
    if('href' in row.artist_location):
        print(row['artist_location'])
# Out:
# <a href="http://billyidol.net" onmousedown='UntrustedLink.bootstrap($(this), "fc44f8f60d13ab68c56b3c6709c6d670", event)' target="_blank" rel="nofollow">http://billyidol.net</a>
# <a href="http://billyidol.net" onmousedown='UntrustedLink.bootstrap($(this), "fc44f8f60d13ab68c56b3c6709c6d670", event)' target="_blank" rel="nofollow">http://billyidol.net</a>
# <a href="http://billyidol.net" onmousedown='UntrustedLink.bootstrap($(this), "fc44f8f60d13ab68c56b3c6709c6d670", event)' target="_blank" rel="nofollow">http://billyidol.net</a>
# <a href="http://billyidol.net" onmousedown='UntrustedLink.bootstrap($(this), "fc44f8f60d13ab68c56b3c6709c6d670", event)' target="_blank" rel="nofollow">http://billyidol.net</a>
# <a href="http://billyidol.net" onmousedown='UntrustedLink.bootstrap($(this), "fc44f8f60d13ab68c56b3c6709c6d670", event)' target="_blank" rel="nofollow">http://billyidol.net</a>

# %%
song_df_copy[song_df_copy.artist_location.str.contains('DA BEAN', na=False)]
# Out:
#                 artist_id  artist_latitude  \
# 5161   ARAQMES1187FB4D46A         28.64334
# 11435  ARAQMES1187FB4D46A         28.64334
#
#                                       artist_location  artist_longitude  \
# 5161   I AM DA BEAN!!! YIMEAN!!! 3S4LIF3!!!!, Florida         -81.23258
# 11435  I AM DA BEAN!!! YIMEAN!!! 3S4LIF3!!!!, Florida         -81.23258
#
#                                              artist_name   duration  \
# 5161                               Benzino / The Outlawz  228.96281
# 11435  Benzino / K.T. / Prince / Smoke / Luv' / Weird...  260.83220
#
#        num_songs             song_id                            title  year
# 5161           1  SOHJBCO12AB01889CD                   Feel Your Pain     0
# 11435          1  SOSHXLZ12AB0185894  Throw Them 3's (Bouston Ni****)     0

# %%
song_df_copy[song_df_copy.artist_location.str.contains('YAHD!', na=False)]
# Out:
#                 artist_id  artist_latitude artist_location  artist_longitude  \
# 1725   ARZLVVQ11F4C8421BA         39.49974           YAHD!        -111.54732
# 11363  ARFH6FT1187FB5BF47         39.49974           YAHD!        -111.54732
#
#       artist_name   duration  num_songs             song_id        title  year
# 1725        T.O.K  188.10730          1  SOTQSHS12A8AE46A4A  Money Maker     0
# 11363      T.O.K.  225.72363          1  SOFLPJR12A8C134166     Saturday  2001

# %%
song_df_copy[song_df_copy.artist_location.str.contains('Superdupont', na=False)]
# Out:
#                 artist_id  artist_latitude  \
# 10725  AR107SB1187B9A79F9              NaN
#
#                                          artist_location  artist_longitude  \
# 10725  Bézu, comme Superdupont, ne connait qu&#039;un...               NaN
#
#       artist_name  duration  num_songs             song_id  \
# 10725        Bézu  184.0322          1  SOQJWZI12A8C140181
#
#                      title  year
# 10725  La bite du plombier     0

# %%
song_df_copy[song_df_copy.artist_location.str.contains('&', na=False)]
# Out:
#                 artist_id  artist_latitude  \
# 26     ARX2R5A1187FB5B85B         33.74831
# 33     AR6TW8G119B8668BA1         54.50292
# 5780   ART4QZC1187FB51612              NaN
# 10236  ARNHJW31187B9A2113         38.04859
# 10725  AR107SB1187B9A79F9              NaN
# 12426  AR548LF1187FB4ADDF         42.50382
# 13842  AR72HPG1187B9A1496         51.84005
#
#                                          artist_location  artist_longitude  \
# 26                          Joliet, IL &amp; Atlanta, GA         -84.39111
# 33                      Derry &amp; Dungannon, N.Ireland          -6.76687
# 5780                          Los Angeles &amp; New York               NaN
# 10236                    Lexington, KY &amp; Atlanta, GA         -84.50032
# 10725  Bézu, comme Superdupont, ne connait qu&#039;un...               NaN
# 12426                                 Italy &amp; London          12.57347
# 13842      HERTS,SG, Producer, song writter & rapper, UK          -0.27510
#
#                  artist_name   duration  num_songs             song_id  \
# 26                 Ann Nesby  243.01669          1  SOUEARP12A58A7D643
# 33     The Japanese Popstars  235.83302          1  SODJQMR12A6D4FD321
# 5780           Janet Jackson   67.10812          1  SOBKMDD12A58A7F476
# 10236                 Donnie  310.96118          1  SOJZGKZ12A6D4F84E8
# 10725                   Bézu  184.03220          1  SOQJWZI12A8C140181
# 12426              Italoboyz  477.83138          1  SOAHYWV12A58A7AA0C
# 13842            The Mission  229.98159          1  SOCKMDZ12A6D4F6A79
#
#                                           title  year
# 26                                  Tables Turn     0
# 33                                 Sample Whore  2008
# 5780   Interlude: Livin'...In Complete Darkness     0
# 10236                                   Cloud 9  2002
# 10725                       La bite du plombier     0
# 12426                               L'Anagramme     0
# 13842                    Hands Across The Ocean  1990

# %%
# 1)convert &amp; to & 2)Pick one of two locations(2 from array)
for index, row in song_df_copy.iterrows():
    if('&' in row.artist_location):
        print(row['artist_location'],'|', html.unescape(row.artist_location).split('&')[-1])
# Out:
# Joliet, IL &amp; Atlanta, GA |  Atlanta, GA
# Derry &amp; Dungannon, N.Ireland |  Dungannon, N.Ireland
# Los Angeles &amp; New York |  New York
# Lexington, KY &amp; Atlanta, GA |  Atlanta, GA
# Bézu, comme Superdupont, ne connait qu&#039;un pays : la France ! | Bézu, comme Superdupont, ne connait qu'un pays : la France !
# Italy &amp; London |  London
# HERTS,SG, Producer, song writter & rapper, UK |  rapper, UK

# %%
song_df_copy[song_df_copy.artist_location.str.contains('born', na=False)]
# Out:
#                 artist_id  artist_latitude  \
# 10825  ARQF61A1187FB4A61F         59.33217
#
#                                          artist_location  artist_longitude  \
# 10825  born 19 July 1976 (age 33) in Täby, Stockholm,...          18.06243
#
#       artist_name   duration  num_songs             song_id  \
# 10825  Eric Prydz  360.46322          1  SOYZIFC12AB0186300
#
#                               title  year
# 10825  Pjanoo (High Contrast Remix)  2008

# %%
song_df_copy[song_df_copy.artist_location.str.contains('slightly', na=False)]
# Out:
#                artist_id  artist_latitude  \
# 7667  AR7WSQE1187FB4CF08              NaN
#
#                                         artist_location  artist_longitude  \
# 7667  Copenhagen, Denmark (With a slightly touch of ...               NaN
#
#      artist_name  duration  num_songs             song_id  \
# 7667        Aqua  239.3073          1  SOOLCUY12A6D4F9119
#
#                       title  year
# 7667  Goodbye To The Circus     0

# %%
song_df_copy[song_df_copy.artist_location.str.contains('Rossville, Tennessee', na=False)]
# Out:
#                artist_id  artist_latitude  \
# 7405  AR06M3F1187FB38BED         34.51042
#
#                                         artist_location  artist_longitude  \
# 7405  Rossville, Tennessee (Lived in Como, Mississippi)         -89.94049
#
#                     artist_name   duration  num_songs             song_id  \
# 7405  Mississippi Fred McDowell  226.37669          1  SOWKEYU12A8C13C384
#
#                title  year
# 7405  You Gotta Move  1999

# %%
song_df_copy.artist_location = song_df_copy.artist_location.replace('New York City (Salem, IL - originally)','Salem, IL')
song_df_copy.artist_location = song_df_copy.artist_location.replace('Belgica -- Namur, Namur/Ghent, East Flanders','Namur, Namur')
song_df_copy.artist_location = song_df_copy.artist_location.replace('D�orf, Germany','Dorf, Germany')
song_df_copy.artist_location = song_df_copy.artist_location.replace('�gelholm, Sweden','angelholm, Sweden')
song_df_copy.artist_location = song_df_copy.artist_location.replace('Dubioza kolektiv (aka Dubioza as referred to by some fans) is a Bosnian band from Sarajevo','Sarajevo')
song_df_copy.artist_location = song_df_copy.artist_location.replace('YAHD!','')

ix = int(song_df_copy[song_df_copy.artist_location.str.contains('Superdupont', na=False)].index.values)
song_df_copy.at[ix,'artist_location']='France'

#song_df_copy.artist_location = song_df_copy.artist_location.replace("&",'')
#Replace integer value with string
#song_df_copy['artist_location'] = song_df_copy['artist_location'].map({27:'', 100:''})

# %%
for index, row in song_df_copy.iterrows():
    if(type(row['artist_location']) == int):
        song_df_copy.at[index,'artist_location']=''
        
    if('href' in row.artist_location):
        song_df_copy.at[index,'artist_location']=''
    if('DA BEAN' in row.artist_location):
        song_df_copy.at[index,'artist_location']=''        
    if('Superdupont' in row.artist_location):
        song_df_copy.at[index,'artist_location']=''     
    if('&' in row.artist_location):
        song_df_copy.at[index,'artist_location']=html.unescape(row.artist_location).split('&')[-1]
        
    if('born' in row.artist_location):
        song_df_copy.at[index,'artist_location']=''             
    if('slightly' in row.artist_location):
        song_df_copy.at[index,'artist_location']='Copenhagen, Denmark'
    if('Rossville, Tennessee' in row.artist_location):
        song_df_copy.at[index,'artist_location']='Rossville, Tennessee'

# %%
#print(''.join(row['artist_location']))
for index, row in song_df_copy.iterrows():
    if(type(row['artist_location']) == tuple):
        print(row.values)

# %%
#print(''.join(row['artist_location']))
for index, row in song_df_copy.iterrows():
    if(type(row['artist_location']) == tuple):
        song_df_copy.at[index,'artist_location']=''.join(row['artist_location'])

# %% [markdown]
# ### Test

# %%
#print(''.join(row['artist_location']))
for index, row in song_df_copy.iterrows():    
    if(type(row['artist_location']) == tuple):
        print(row.values)

# %%
song_df_copy[song_df_copy.artist_location.str.contains('originally', na=False)]
# Out:
# Empty DataFrame
# Columns: [artist_id, artist_latitude, artist_location, artist_longitude, artist_name, duration, num_songs, song_id, title, year]
# Index: []

# %%
song_df_copy[song_df_copy.artist_location.str.contains('Belgica -- Namur, Namur/Ghent, East Flanders', na=False)]
# Out:
# Empty DataFrame
# Columns: [artist_id, artist_latitude, artist_location, artist_longitude, artist_name, duration, num_songs, song_id, title, year]
# Index: []

# %%
song_df_copy[song_df_copy.artist_location.str.contains('D�orf, Germany', na=False)]
# Out:
# Empty DataFrame
# Columns: [artist_id, artist_latitude, artist_location, artist_longitude, artist_name, duration, num_songs, song_id, title, year]
# Index: []

# %%
song_df_copy[song_df_copy.artist_location.str.contains('�gelholm, Sweden', na=False)]
# Out:
# Empty DataFrame
# Columns: [artist_id, artist_latitude, artist_location, artist_longitude, artist_name, duration, num_songs, song_id, title, year]
# Index: []

# %%
song_df_copy[song_df_copy.artist_location.str.contains('Dubioza kolektiv', na=False)]
# Out:
# Empty DataFrame
# Columns: [artist_id, artist_latitude, artist_location, artist_longitude, artist_name, duration, num_songs, song_id, title, year]
# Index: []

# %%
#artist_location has integer values
for index, row in song_df_copy.iterrows():
    if(type(row['artist_location']) == int):
        print(row.values)

# %%
#artist_location has href links
for index, row in song_df_copy.iterrows():
    if('href' in row.artist_location):
        print(row['artist_location'])

# %%
song_df_copy[song_df_copy.artist_location.str.contains('Superdupont', na=False)]
# Out:
# Empty DataFrame
# Columns: [artist_id, artist_latitude, artist_location, artist_longitude, artist_name, duration, num_songs, song_id, title, year]
# Index: []

# %%
song_df_copy[song_df_copy.artist_location.str.contains('&', na=False)]
# Out:
# Empty DataFrame
# Columns: [artist_id, artist_latitude, artist_location, artist_longitude, artist_name, duration, num_songs, song_id, title, year]
# Index: []

# %% [markdown]
# ### Issue 2 : Convert ts(integer) to timestamp
# ### Define
# log_df : convert ts from integer to timestamp
# ### Code

# %%
log_df_copy.head(2)
# Out:
#             artist       auth firstName gender  itemInSession lastName  \
# 0  The Grass Roots  Logged In      Sara      F             72  Johnson
# 1            Stars  Logged In      Sara      F             73  Johnson
#
#       length level           location method      page  registration  \
# 0  166.71302  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
# 1  298.94485  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
#
#    sessionId                                song  status             ts  \
# 0        411                Let's Live For Today     200  1542153802796
# 1        411  Time Can Never Kill The True Heart     200  1542153968796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95
# 1  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95

# %%
log_df_copy['ts'] = pd.to_datetime(log_df_copy['ts'], unit='ms')

# %% [markdown]
# ### Test

# %%
log_df_copy.head(2)
# Out:
#             artist       auth firstName gender  itemInSession lastName  \
# 0  The Grass Roots  Logged In      Sara      F             72  Johnson
# 1            Stars  Logged In      Sara      F             73  Johnson
#
#       length level           location method      page  registration  \
# 0  166.71302  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
# 1  298.94485  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
#
#    sessionId                                song  status  \
# 0        411                Let's Live For Today     200
# 1        411  Time Can Never Kill The True Heart     200
#
#                        ts                                          userAgent  \
# 0 2018-11-14 00:03:22.796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 1 2018-11-14 00:06:08.796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
#
#   userId
# 0     95
# 1     95

# %%
log_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8056 entries, 0 to 8055
# Data columns (total 18 columns):
# artist           6820 non-null object
# auth             8056 non-null object
# firstName        7770 non-null object
# gender           7770 non-null object
# itemInSession    8056 non-null int64
# lastName         7770 non-null object
# length           6820 non-null float64
# level            8056 non-null object
# location         7770 non-null object
# method           8056 non-null object
# page             8056 non-null object
# registration     7770 non-null float64
# sessionId        8056 non-null int64
# song             6820 non-null object
# status           8056 non-null int64
# ts               8056 non-null datetime64[ns]
# userAgent        7770 non-null object
# userId           8056 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Issue 3 : Convert registration column to int
# ### Define
# log_df : convert registration column to int(has null convert to 0 then int)
# ### Code

# %%
log_df_copy[log_df_copy.registration.isnull()].head()
# Out:
#     artist        auth firstName gender  itemInSession lastName  length level  \
# 78    None  Logged Out      None   None              2     None     NaN  free
# 79    None  Logged Out      None   None              3     None     NaN  free
# 80    None  Logged Out      None   None              4     None     NaN  free
# 286   None  Logged Out      None   None              5     None     NaN  paid
# 287   None  Logged Out      None   None              6     None     NaN  paid
#
#     location method   page  registration  sessionId  song  status  \
# 78      None    GET   Home           NaN         58  None     200
# 79      None    GET   Home           NaN         58  None     200
# 80      None    PUT  Login           NaN         58  None     307
# 286     None    GET   Home           NaN        558  None     200
# 287     None    PUT  Login           NaN        558  None     307
#
#                          ts userAgent userId
# 78  2018-11-14 05:55:03.796      None
# 79  2018-11-14 05:55:41.796      None
# 80  2018-11-14 05:55:42.796      None
# 286 2018-11-14 12:09:01.796      None
# 287 2018-11-14 12:09:02.796      None

# %%
log_df_copy.registration = log_df_copy.registration.replace(np.nan, 0)
log_df_copy['registration'] = log_df_copy.registration.astype(int)

# %% [markdown]
# ### Test

# %%
log_df_copy[log_df_copy.registration.isnull()].head()
# Out:
# Empty DataFrame
# Columns: [artist, auth, firstName, gender, itemInSession, lastName, length, level, location, method, page, registration, sessionId, song, status, ts, userAgent, userId]
# Index: []

# %%
log_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8056 entries, 0 to 8055
# Data columns (total 18 columns):
# artist           6820 non-null object
# auth             8056 non-null object
# firstName        7770 non-null object
# gender           7770 non-null object
# itemInSession    8056 non-null int64
# lastName         7770 non-null object
# length           6820 non-null float64
# level            8056 non-null object
# location         7770 non-null object
# method           8056 non-null object
# page             8056 non-null object
# registration     7770 non-null float64
# sessionId        8056 non-null int64
# song             6820 non-null object
# status           8056 non-null int64
# ts               8056 non-null int64
# userAgent        7770 non-null object
# userId           8056 non-null object
# dtypes: float64(2), int64(4), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Issue 4 : Round duration column
# ### Define
# song_df: Round duration column(value is seconds, it doesn't have to be in float)
#
# ### Code

# %%
song_df_copy['duration'] = song_df_copy['duration'].astype('int64')

# %% [markdown]
# ### Test

# %%
song_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14896 entries, 0 to 14895
# Data columns (total 10 columns):
# artist_id           14896 non-null object
# artist_latitude     5277 non-null float64
# artist_location     14896 non-null object
# artist_longitude    5277 non-null float64
# artist_name         14896 non-null object
# duration            14896 non-null int64
# num_songs           14896 non-null int64
# song_id             14896 non-null object
# title               14896 non-null object
# year                14896 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 1.1+ MB

# %%
song_df_copy.head()
# Out:
#             artist_id  artist_latitude               artist_location  \
# 0  ARTH9041187FB43E1F              NaN                St. Joseph, MO
# 1  ARQFUGM1187FB3E24E              NaN  Los Angeles, California, USA
# 2  ARM2L4M1187B9B5F51              NaN
# 3  ARCQMJH1187B9B53CC         30.00875                Smithville, TX
# 4  ARNH6Q11187FB40FDD         40.65507                  Brooklyn, NY
#
#    artist_longitude                              artist_name  duration  \
# 0               NaN                                   Eminem       312
# 1               NaN                      Black Label Society       258
# 2               NaN                               FreQ Nasty       205
# 3         -97.16001  DJ Screw_ B-Legit_ Lil Keke_ Phaz_ Duke       262
# 4         -73.94888                          Jeru The Damaja       245
#
#    num_songs             song_id  \
# 0          1  SOLXDDC12A6701FBFD
# 1          1  SOHVHKM12A8C13F716
# 2          1  SOFYPCI12A6701FF60
# 3          1  SOPEVXO12AB0185938
# 4          1  SOYZIYS12A6D4F5ED5
#
#                                              title  year
# 0                                         I'm Back  2000
# 1                                  Counterfeit God  2000
# 2                                            Fresh  2002
# 3  Screw Mix (feat. B-Legit_ Lil Keke_ Phaz_ Duke)     0
# 4                  Revenge Of The Prophet (Part 5)  1996

# %% [markdown]
# ### Issue 5 : Add columns county, city, state, country, country_code to song_df
# ### Define
# a. Fix some artist_location names
# b. Add columns county, city, state, country, country_code
#
# ### Code

# %%
print('All = ',song_df_copy.shape[0])
print('Locations = ',song_df_copy[(song_df_copy.artist_location != '')].shape[0])
print('Blank = ',song_df_copy[song_df_copy.artist_location.str.strip() == ''].shape[0])
print('LatLon = ',song_df_copy[(song_df_copy.artist_location.str.strip() == '') & ( (song_df_copy.artist_longitude.notnull()) & (song_df_copy.artist_latitude.notnull()) )].shape[0])
# Out:
# All =  14896
# Locations =  8179
# Blank =  6725
# LatLon =  18

# %%
#song_df with locations
song_df_wlocations = song_df_copy[(song_df_copy.artist_location.str.strip() != '')]
song_df_wblank = song_df_copy[(song_df_copy.artist_location.str.strip() == '')]
song_df_latlon = song_df_copy[(song_df_copy.artist_location.str.strip() == '') & ( (song_df_copy.artist_longitude.notnull()) & (song_df_copy.artist_latitude.notnull()) )]

#Getting the true blanks(no locations & no coordinates)
song_df_tblank = pd.merge(song_df_wblank,song_df_latlon, how='outer', indicator=True)
song_df_wblank = song_df_tblank[song_df_tblank._merge =='left_only'].copy()
#song_df_wblank.drop(['_merge'], axis=1)
print(song_df_wblank.shape)

#song_df_wlocations.reset_index(drop=True)
#song_df_wblank.reset_index(drop=True)
#song_df_latlon.reset_index(drop=True)

print('All = ',song_df_copy.shape[0])
print('Locations = ',song_df_wlocations.shape[0])
print('Blank = ',song_df_wblank.shape[0])
print('LatLon= ',song_df_latlon.shape[0])
# Out:
# (6707, 11)
# All =  14896
# Locations =  8171
# Blank =  6707
# LatLon=  18

# %%
song_df_wblank.head()
# Out:
#             artist_id  artist_latitude artist_location  artist_longitude  \
# 0  ARM2L4M1187B9B5F51              NaN                               NaN
# 1  AR1U3BY1187B9B136F              NaN                               NaN
# 2  AR1ILHX1187FB53892              NaN                               NaN
# 3  AR4K1XY1187B99479D              NaN                               NaN
# 4  AR1GZB111C8A421C7A              NaN                               NaN
#
#             artist_name  duration  num_songs             song_id  \
# 0            FreQ Nasty       205          1  SOFYPCI12A6701FF60
# 1  God Lives Underwater       215          1  SOPWHEV12AB017DC10
# 2    Magtens Korridorer       266          1  SOUPGMR12AB01820DD
# 3        General Degree       213          1  SOETCUF12AB0182C10
# 4            Andre Crom       400          1  SOYXOEY12AB0180988
#
#                   title  year     _merge
# 0                 Fresh  2002  left_only
# 1  Don't Know How To Be  1995  left_only
# 2             Døden Nær  2005  left_only
# 3            Last Night     0  left_only
# 4                  Warp     0  left_only

# %%
song_df_wlocations_artist = song_df_wlocations["artist_name"].tolist()
song_df_wblank_artist = song_df_wblank['artist_name'].tolist()
print(len(song_df_wlocations_artist))
print(len(song_df_wblank_artist))

artist_found = []
for s in song_df_wblank_artist:
    if(s in song_df_wlocations_artist):
        #print(s)
        artist_found.append(s)
        
        
#song_df_wlocations[song_df_wlocations.artist_name =='Billy Idol']
# Out:
# 8171
# 6707

# %%
print('song_df_wblank = ', song_df_wblank.shape)
# Out:
# song_df_wblank =  (6707, 11)

# %%
#Its found certain known artists locations(song_df_wlocations) are not filled in song_df_wblank. 
#updating song_df_blank with location details
index_list = []
count = 0
song_df_new_rows = pd.DataFrame()

for index, row in song_df_wblank.iterrows():
    #    print(index)
    artist_name = row['artist_name']
    artist_location = ''
    lrow = song_df_wlocations[song_df_wlocations.artist_name == artist_name]
    if(lrow.shape[0] != 0):
        count+=1
        #print(lrow.shape)
        artist_location = lrow.iloc[0]['artist_location']
        song_df_wblank.at[index,'artist_location']=artist_location
        index_list.append(index)
        song_df_new_rows = song_df_new_rows.append(lrow)
        
        #print(index, ' - ', artist_location)
        
    #a = round(song_df_latlon[song_df_latlon.artist_name =='Billy Idol'].iloc[0]['artist_latitude'], 4)
    
print('Count = ', count)
print(index_list)
# Out:
# Count =  58
# [79, 97, 125, 399, 439, 487, 510, 528, 639, 1061, 1206, 1416, 1564, 1609, 1719, 1776, 2023, 2118, 2204, 2359, 2841, 2973, 2993, 3006, 3120, 3317, 3514, 3537, 3729, 3748, 3841, 4058, 4081, 4332, 4442, 4457, 4527, 4531, 4657, 4719, 4907, 5091, 5166, 5224, 5246, 5254, 5331, 5427, 5484, 5571, 5682, 5924, 6181, 6182, 6233, 6384, 6621, 6622]

# %%
#song_df_new_rows.reset_index(drop=True)
print(song_df_new_rows.shape)
print(len(index_list))
print(len(artist_found))
#song_df_new_rows[song_df_new_rows.artist_location.str.strip() == '']
# Out:
# (77, 10)
# 58
# 58

# %%
print(song_df_wlocations.shape)
print(song_df_new_rows.shape)
# Out:
# (8171, 10)
# (77, 10)

# %%
#Moving artist_location updated rows from song_df_wblank to song_df_wlocations
print('Before song_df_wblank = ',song_df_wblank.shape)
print('Before song_df_wlocations = ',song_df_wlocations.shape)
song_df_new = song_df_wblank[song_df_wblank.artist_location.str.strip() !=''].copy()
song_df_wblank = song_df_wblank[song_df_wblank.artist_location.str.strip() ==''].copy()

#Commenting below due to ValueError: cannot reindex from a duplicate axis
#song_df_new = song_df_new[['artist_id', 'artist_latitude', 'artist_location', 'artist_latitude', 'artist_name', 'duration', 'num_songs', 'song_id', 'title', 'year']]
#song_df_wlocations = song_df_wlocations[['artist_id', 'artist_latitude', 'artist_location', 'artist_latitude', 'artist_name', 'duration', 'num_songs', 'song_id', 'title', 'year']]

song_df_wlocations = song_df_wlocations.append(song_df_new, sort=False)
#song_df_wlocations = pd.concat([song_df_wlocations,song_df_new], ignore_index=True)
print('After song_df_wblank = ',song_df_wblank.shape)
print('After song_df_wlocations = ',song_df_wlocations.shape)
# Out:
# Before song_df_wblank =  (6707, 11)
# Before song_df_wlocations =  (8171, 10)
# After song_df_wblank =  (6649, 11)
# After song_df_wlocations =  (8229, 11)

# %%
#Write song_df_wblank to CSV
song_df_wblank.to_csv('song_df_wblank.csv', encoding='utf-8', index=False)

# %%
#Moving rows with lats & longs to song_df_latlon
print('Before song_df_latlon = ',song_df_latlon.shape)
print('Before song_df_wlocations = ',song_df_wlocations.shape)
temp = song_df_wlocations[song_df_wlocations.artist_latitude.notnull()].copy()
song_df_wlocations = song_df_wlocations[song_df_wlocations.artist_latitude.isnull()].copy()
song_df_latlon = song_df_latlon.append(temp, sort=False)
print('After song_df_latlon = ',song_df_latlon.shape)
print('After song_df_wlocations = ',song_df_wlocations.shape)
# Out:
# Before song_df_latlon =  (18, 10)
# Before song_df_wlocations =  (8229, 11)
# After song_df_latlon =  (5277, 11)
# After song_df_wlocations =  (2970, 11)

# %%
#Adding extra columns to song_df_latlon for processing.
'''
song_df_latlon_copy = song_df_latlon.copy()

song_df_latlon_copy['process'] = np.NaN
song_df_latlon_copy['process'] = song_df_latlon_copy.process.astype(str)
song_df_latlon_copy['corrected_location'] = np.NaN
song_df_latlon_copy['corrected_location'] = song_df_latlon_copy.corrected_location.astype(str)
song_df_latlon_copy['county'] = np.NaN
song_df_latlon_copy['county'] = song_df_latlon_copy.county.astype(str)
song_df_latlon_copy['city'] = np.NaN
song_df_latlon_copy['city'] = song_df_latlon_copy.city.astype(str)
song_df_latlon_copy['state'] = np.NaN
song_df_latlon_copy['state'] = song_df_latlon_copy.state.astype(str)
song_df_latlon_copy['country'] = np.NaN
song_df_latlon_copy['country'] = song_df_latlon_copy.country.astype(str)
song_df_latlon_copy['country_code'] = np.NaN
song_df_latlon_copy['country_code'] = song_df_latlon_copy.country_code.astype(str)
'''
#Don't uncomment will override the existing worked up file
#song_df_latlon_copy.to_csv('song_df_latlon.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Query geopy and get data for latitude & longitude by running GatherLocationDetails.ipynb

# %%
song_df_latlon = pd.read_csv("song_df_latlon.csv")
print('song_df_latlon.csv = ',song_df_latlon.shape)
# Out:
# song_df_latlon.csv =  (5277, 18)

# %%
#Geo Coordinates are found to be wrong for these countries as per geopy.
#Verified (16.855760, -69.468540) and seems to be middle of nowhere, ocean between Jamica & British Virgin Islands
song_df_latlon[song_df_latlon.process.isnull()]
# Out:
#                artist_id  artist_latitude        artist_location  \
# 761   ARD2GXE1187B9A2E26         16.85576    Guyana, West Indies
# 3770  AR40FJJ1187FB3C72C         16.85576            West Indies
# 5167  AR40FJJ1187FB3C72C         16.85576            West Indies
# 5252  ARMDBW21187FB37126         16.85576  Barbados, West Indies
#
#       artist_longitude        artist_name  duration  num_songs  \
# 761          -69.46854      Mad Professor       266          1
# 3770         -69.46854            Osibisa       233          1
# 5167         -69.46854            Osibisa       320          1
# 5252         -69.46854  Grandmaster Flash       197          1
#
#                  song_id              title  year  _merge process  \
# 761   SOUIPHX12A6D4F8AB0  Schizophrenic Dub  1986     NaN     NaN
# 3770  SOTENWL12A6D4FCAED              Abele  1995     NaN     NaN
# 5167  SOSLAOP12A6D4FCAE2             Get Up  1995     NaN     NaN
# 5252  SOAYSDV12AB0186EE0           The King     0     NaN     NaN
#
#       corrected_location county city state country country_code
# 761                  NaN    NaN  NaN   NaN     NaN          NaN
# 3770                 NaN    NaN  NaN   NaN     NaN          NaN
# 5167                 NaN    NaN  NaN   NaN     NaN          NaN
# 5252                 NaN    NaN  NaN   NaN     NaN          NaN

# %%
print('Total = {}'.format(song_df_latlon.shape))
print('Null  = {}'.format(song_df_latlon[song_df_latlon.process.isnull()].shape))
print('Values= {}'.format(song_df_latlon[song_df_latlon.process.notnull()].shape))
# Out:
# Total = (5277, 18)
# Null  = (4, 18)
# Values= (5273, 18)

# %%
#Moving rows from song_df_latlon to song_df_wlocations due to wrong geo-coordinates
print('Before song_df_latlon = ',song_df_latlon.shape)
print('Before song_df_wlocations = ',song_df_wlocations.shape)

song_df_wlocations_copy = song_df_wlocations.copy()
temp = song_df_latlon[song_df_latlon.process.isnull()].copy()
song_df_latlon = song_df_latlon[song_df_latlon.process.notnull()].copy()
song_df_wlocations = song_df_wlocations.append(temp, sort=False)

print('After song_df_latlon = ',song_df_latlon.shape)
print('After song_df_wlocations = ',song_df_wlocations.shape)
# Out:
# Before song_df_latlon =  (5277, 18)
# Before song_df_wlocations =  (2970, 11)
# After song_df_latlon =  (5273, 18)
# After song_df_wlocations =  (2974, 18)

# %%
def correct_spelling(dictSpell, istr):
    outArray = [];
    location = 'Jping, Sweden'
    #print('Input = ',istr)
    array = istr.split(',')
    #print('Array = ',array)
    output = ''
    for s in array:
        s = s.strip()
        #print(s)
        if(spelling_corrections.get(s) != None):
            if(len(spelling_corrections[s].strip()) != 0):
                outArray.append(spelling_corrections[s])
        else:
            outArray.append(s)
        #print('Val = ',output)

    #print('outArray = ', ", ".join(outArray))
    output = ", ".join(outArray)    
    #print('Output = ',output)    
    return output

# %%
spelling_corrections = {
    'Jping' : 'Koping'
    ,'Trollhan' : 'Trollhattan'
    ,'Montr' : 'Montreal'
    ,'Saverene' : 'Saverne'
    ,'Brookyln' : 'Brooklyn'
    ,'Halifaz' : 'Halifax'
    ,'Massachusettes' : 'Massachusetts'
    ,'Bundundu' : 'Bandundu'
    ,'Upstate NY' : ''
}
#print(spelling_corrections['Jpingg'])
print(spelling_corrections.get('Jpingg'))
location = 'Jping, Sweden'
print('correct_spelling = ',correct_spelling(spelling_corrections, location))
location = 'Trollhan, Sweden'
print('correct_spelling = ',correct_spelling(spelling_corrections, location))
location = 'Vancouver, Canada'
print('correct_spelling = ',correct_spelling(spelling_corrections, location))


print('http' in 'http://www.sneakerpimps.net')
# Out:
# None
# correct_spelling =  Koping, Sweden
# correct_spelling =  Trollhattan, Sweden
# correct_spelling =  Vancouver, Canada
# True

# %%
#Adding extra columns to song_df_wlocations for processing.
song_df_wlocations_copy = song_df_wlocations.copy()

song_df_wlocations_copy['process'] = np.NaN
song_df_wlocations_copy['process'] = song_df_wlocations_copy.process.astype(str)
song_df_wlocations_copy['corrected_location'] = np.NaN
song_df_wlocations_copy['corrected_location'] = song_df_wlocations_copy.corrected_location.astype(str)
song_df_wlocations_copy['county'] = np.NaN
song_df_wlocations_copy['county'] = song_df_wlocations_copy.county.astype(str)
song_df_wlocations_copy['city'] = np.NaN
song_df_wlocations_copy['city'] = song_df_wlocations_copy.city.astype(str)
song_df_wlocations_copy['state'] = np.NaN
song_df_wlocations_copy['state'] = song_df_wlocations_copy.state.astype(str)
song_df_wlocations_copy['country'] = np.NaN
song_df_wlocations_copy['country'] = song_df_wlocations_copy.country.astype(str)
song_df_wlocations_copy['country_code'] = np.NaN
song_df_wlocations_copy['country_code'] = song_df_wlocations_copy.country_code.astype(str)

#to be added after spelling correction
#song_df_wlocations_copy.to_csv('song_df_wlocations.csv', encoding='utf-8', index=False)

# %%
spelling_corrections = {
    'Jping' : 'Koping'
    ,'Trollhan' : 'Trollhattan'
    ,'Montr' : 'Montreal'
    ,'Saverene' : 'Saverne'
    ,'Brookyln' : 'Brooklyn'
    ,'Halifaz' : 'Halifax'
    ,'Massachusettes' : 'Massachusetts'
    ,'Bundundu' : 'Bandundu'
    ,'Hell' : ''
    ,'Upstate NY' : ''
    ,'East End de Londres' : 'East End of London'
}

for index, row in song_df_wlocations_copy.iterrows():
    #print('Location : ',len(row['artist_location'].split(',')),row['artist_location'])
    location = row['artist_location']
    str1 = ''
    #Handling square brackets []
    pos1 = re.search('\[.*', location)
    #print(str1, pos1)
    if(pos1 != None):
        pos1 = pos1.start() + 1
        str1 = location[pos1:-1]        
        array = location.split(',')
        str1 = str1 + ', ' + array[0]
        #print('1. ',str1)        
        
    if((', Can' in location) or (', Cana' in location)):
        #print(row.artist_location)
        array = location.split(',')
        if(len(array) == 3):
            str1 = array[0].strip()+', '+array[1].strip()+', Canada'
        if(len(array) == 2):
            str1 = array[0].strip()+', Canada'

        #print('2. ',str1)
        #df3_lo.at[index,'loc1']=str1        

    if(', Eng' in location):
        #print(row.artist_location)
        array = row['artist_location'].split(',')
        if(len(array) == 3):
            str1 = array[0].strip()+', '+array[1].strip()+', England'
        if(len(array) == 2):
            str1 = array[0].strip()+', England'
        
        #print('3. ',str1)
        #df3_lo.at[index,'loc1']=str1        

    if(', Lo' in location):
        #print(row.artist_location)
        array = row['artist_location'].split(',')
        if(len(array) == 3):
            str1 = array[0].strip()+', '+array[1].strip()+', London'
        if(len(array) == 2):
            str1 = array[0].strip()+', London'

    if(len(str1) == 0):
        str1 = location
                               
    if('http' in str1):
        str1 = ''
            
    if('/' in str1):
        str1 = str1.replace('/',', ')
        
    if(' - ' in str1):
        str1 = str1.replace(' - ',', ')        
        
    #Assumption is location to be on format city, state, country
    array = str1.split(',')
    if(len(array) == 3):
        str1 = array[0].strip()+', '+array[2].strip()

    #print('4. ',str1)
    #df3_lo.at[index,'loc1']=str1        

    #Remove non-alphanumeric characters
    str2 = re.sub(r'[^a-zA-Z, \.]+', '', str1)
    str1 = correct_spelling(spelling_corrections, str2)
    #print('Final = ', str1)
    if(len(location) != len(str1)):
        print('{}. Analyzing {} and result is {} '.format(index, location, str1))
    song_df_wlocations_copy.at[index,'corrected_location']=str1
# Out:
# 1. Analyzing Los Angeles, California, USA and result is Los Angeles, USA
# 27. Analyzing NY - Long Island and result is NY, Long Island
# 143. Analyzing Vancouver, British Columbia, Cana and result is Vancouver, Canada
# 147. Analyzing California - LA and result is California, LA
# 152. Analyzing New York, NY [Queens] and result is Queens, New York
# 301. Analyzing Braintree, Essex, England and result is Braintree, England
# 302. Analyzing İngiltere and result is ngiltere
# 331. Analyzing Bangor, County Down, Ireland and result is Bangor, Ireland
# 387. Analyzing Paddington, London, England and result is Paddington, London
# 427. Analyzing NY - New York City and result is NY, New York City
# 443. Analyzing Kingston, Ontario, Canada and result is Kingston, Canada
# 480. Analyzing Wellington, Aotearoa, New Zealand and result is Wellington, New Zealand
# 481. Analyzing California - LA and result is California, LA
# 496. Analyzing Lisboa, Portugal  and result is Lisboa, Portugal
# 569. Analyzing Sheffield, Yorkshire, England and result is Sheffield, England
# 570. Analyzing Great Britain / UK and result is Great Britain, UK
# 617. Analyzing Burlington, Ontario, Canada and result is Burlington, Canada
# 653. Analyzing Miami , Florida and result is Miami, Florida
# 703. Analyzing  Ubá, Minas Gerais and result is Ub, Minas Gerais
# 751. Analyzing NY - New York City and result is NY, New York City
# 779. Analyzing Bradford, W. Yorks, England and result is Bradford, England
# 855. Analyzing Bexleyheath, Kent, England and result is Bexleyheath, England
# 914. Analyzing California - LA and result is California, LA
# 1001. Analyzing Los Angeles, California, USA and result is Los Angeles, USA
# 1071. Analyzing Dumfries, Scotland, United Kingdom and result is Dumfries, United Kingdom
# 1099. Analyzing New York City, NY, USA and result is New York City, USA
# 1102. Analyzing Buff Bay, Portland, Jamaica and result is Buff Bay, Jamaica
# 1126. Analyzing Wigan, Lancashire, England and result is Wigan, England
# 1127. Analyzing New York, NY [Brooklyn] and result is Brooklyn, New York
# 1143. Analyzing Burlington, Ontario, Canada and result is Burlington, Canada
# 1144. Analyzing Sheffield UK-England and result is Sheffield UKEngland
# 1197. Analyzing Sheffield, Yorkshire, England and result is Sheffield, England
# 1227. Analyzing Leyton, East End de Londres and result is Leyton, East End of London
# 1230. Analyzing Richmond, California, U.S. and result is Richmond, U.S.
# 1231. Analyzing California - LA and result is California, LA
# 1237. Analyzing CANADA - Ontario and result is CANADA, Ontario
# 1252. Analyzing NY - Long Island and result is NY, Long Island
# 1259. Analyzing New York, NY [Bronx] and result is Bronx, New York
# 1261. Analyzing Montreal/Berlin and result is Montreal, Berlin
# 1262. Analyzing Great Britain / UK and result is Great Britain, UK
# 1275. Analyzing Havířov, Česká republika and result is Havov, esk republika
# 1280. Analyzing Boston, MA, USA and result is Boston, USA
# 1354. Analyzing California - LA and result is California, LA
# 1374. Analyzing Boston, MA, USA and result is Boston, USA
# 1380. Analyzing Winnipeg, Manitoba, Canada and result is Winnipeg, Canada
# 1402. Analyzing St. Albans, Herts, England and result is St. Albans, England
# 1425. Analyzing California - LA and result is California, LA
# 1440. Analyzing NY - New York City and result is NY, New York City
# 1452. Analyzing Piapot Reserve, Saskatchewan, Can and result is Piapot Reserve, Canada
# 1455. Analyzing California - LA and result is California, LA
# 1474. Analyzing CORSE / PARIS and result is CORSE, PARIS
# 1519. Analyzing RSC Slauson Boy : CA and result is RSC Slauson Boy  CA
# 1594. Analyzing Eltham, Kent, England and result is Eltham, England
# 1666. Analyzing Buff Bay, Portland, Jamaica and result is Buff Bay, Jamaica
# 1672. Analyzing Eltham, Kent, England and result is Eltham, England
# 1740. Analyzing Newcastle, Tyne and Wear, England and result is Newcastle, England
# 1805. Analyzing California - SF and result is California, SF
# 1806. Analyzing California - LA and result is California, LA
# 1823. Analyzing California - LA and result is California, LA
# 1835. Analyzing St. Albans, Herts, England and result is St. Albans, England
# 1905. Analyzing Malmö and result is Malm
# 1921. Analyzing Edmonton, Alberta, Canada and result is Edmonton, Canada
# 1949. Analyzing London UK-England and result is London UKEngland
# 1958. Analyzing California - LA and result is California, LA
# 1975. Analyzing Québec and result is Qubec
# 2002. Analyzing  Ubá, Minas Gerais and result is Ub, Minas Gerais
# 2093. Analyzing Havířov, Česká republika and result is Havov, esk republika
# 2104. Analyzing Mass. - Boston and result is Mass., Boston
# 2181. Analyzing The Bronx, New York City, NY and result is The Bronx, NY
# 2212. Analyzing Wimbledon, London, England and result is Wimbledon, London
# 2361. Analyzing NY - Long Island and result is NY, Long Island
# 2380. Analyzing Chiswick, London, England and result is Chiswick, London
# 2417. Analyzing Montreal, Quebec, Canada and result is Montreal, Canada
# 2440. Analyzing New York, NY [Harlem] and result is Harlem, New York
# 2513. Analyzing New York, NY [Queens] and result is Queens, New York
# 2527. Analyzing Düsseldorf-Oberbilk and result is DsseldorfOberbilk
# 2584. Analyzing Boston, MA, USA and result is Boston, USA
# 2613. Analyzing Saverene, France and result is Saverne, France
# 2661. Analyzing Bexleyheath, Kent, England and result is Bexleyheath, England
# 2762. Analyzing California - SF and result is California, SF
# 2927. Analyzing Montreal, Quebec, Canada and result is Montreal, Canada
# 3001. Analyzing California - LA and result is California, LA
# 3034. Analyzing NY - Long Island and result is NY, Long Island
# 3037. Analyzing Ottawa, Ontario, Canada and result is Ottawa, Canada
# 3075. Analyzing Orange County, California, United States and result is Orange County, United States
# 3109. Analyzing New York, NY [Harlem] and result is Harlem, New York
# 3121. Analyzing NY - New York City and result is NY, New York City
# 3165. Analyzing Vancouver, British Columbia, Cana and result is Vancouver, Canada
# 3186. Analyzing NY - Upstate NY and result is NY
# 3221. Analyzing Mass. - Boston and result is Mass., Boston
# 3256. Analyzing La Mirada - California and result is La Mirada, California
# 3268. Analyzing New York, NY [Harlem] and result is Harlem, New York
# 3414. Analyzing London, Ontario, Canada and result is London, Canada
# 3438. Analyzing Burnham-On-Crouch, England and result is BurnhamOnCrouch, England
# 3594. Analyzing Brixton, London, England and result is Brixton, London
# 3604. Analyzing Toronto, Ontario, Canada and result is Toronto, Canada
# 3625. Analyzing Whitby, Yorkshire, England and result is Whitby, England
# 3626. Analyzing NY - New York City and result is NY, New York City
# 3652. Analyzing Ottawa, Ontario, Canada and result is Ottawa, Canada
# 3698. Analyzing LDN  and result is LDN
# 3707. Analyzing NY - New York City and result is NY, New York City
# 3803. Analyzing Montreal, Qu�c, Canada and result is Montreal, Canada
# 3829. Analyzing Toronto, Ontario, Canada and result is Toronto, Canada
# 3836. Analyzing Montreal, Quebec, Canada and result is Montreal, Canada
# 3877. Analyzing NY - New York City and result is NY, New York City
# 3904. Analyzing NY - New York City and result is NY, New York City
# 3924. Analyzing Toronto, NYC, Oakland and result is Toronto, Oakland
# 3963. Analyzing rotherham/sheffield and result is rotherham, sheffield
# 3985. Analyzing Montreal, Quebec, Canada and result is Montreal, Canada
# 4044. Analyzing Egremont, Cumbria, England and result is Egremont, England
# 4081. Analyzing Fort Lauderdale/Orlando, FL and result is Fort Lauderdale, FL
# 4120. Analyzing CANADA - Ontario and result is CANADA, Ontario
# 4147. Analyzing Braintree, Essex, England and result is Braintree, England
# 4181. Analyzing Halifaz, Nova Scotia, Canada and result is Halifax, Canada
# 4249. Analyzing CANADA - Ontario and result is CANADA, Ontario
# 4289. Analyzing Luton, Bedfordshire, England and result is Luton, England
# 4316. Analyzing paris, Ile-de-France and result is paris, IledeFrance
# 4343. Analyzing California - LA and result is California, LA
# 4400. Analyzing California - LA and result is California, LA
# 4473. Analyzing Brixton, London, England and result is Brixton, London
# 4487. Analyzing Monfalcone, Friuli-Venezia Giulia and result is Monfalcone, FriuliVenezia Giulia
# 4506. Analyzing Wilkes-Barre, Pennsylvania and result is WilkesBarre, Pennsylvania
# 4549. Analyzing Burlington, Ontario, Canada and result is Burlington, Canada
# 4554. Analyzing Toronto, Ontario, Canada and result is Toronto, Canada
# 4559. Analyzing Hastings, East Sussex, England and result is Hastings, England
# 4576. Analyzing California - LA and result is California, LA
# 4582. Analyzing California - LA and result is California, LA
# 4753. Analyzing 台北, Taiwan and result is , Taiwan
# 4763. Analyzing Toronto, Ontario, Canada and result is Toronto, Canada
# 4793. Analyzing Halifaz, Nova Scotia, Canada and result is Halifax, Canada
# 4815. Analyzing Fort Lauderdale/Orlando, FL and result is Fort Lauderdale, FL
# 4817. Analyzing Birmingham, West Midlands, Englan and result is Birmingham, England
# 4856. Analyzing Toronto, Ontario, Canada and result is Toronto, Canada
# 4862. Analyzing Stockholm / Sweden and result is Stockholm, Sweden
# 4881. Analyzing California - LA and result is California, LA
# 4923. Analyzing Burlington, Ontario, Canada and result is Burlington, Canada
# 4927. Analyzing Bishop Auckland, County Durham, I and result is Bishop Auckland, I
# 4996. Analyzing Sheffield, South Yorkshire, Engla and result is Sheffield, England
# 5060. Analyzing Dagenham, Essex, England and result is Dagenham, England
# 5112. Analyzing Vancouver, British Columbia, Cana and result is Vancouver, Canada
# 5136. Analyzing NY - New York City and result is NY, New York City
# 5201. Analyzing New York, NY [The Bronx] and result is The Bronx, New York
# 5221. Analyzing Wigan, Lancashire, England and result is Wigan, England
# 5249. Analyzing California - LA and result is California, LA
# 5294. Analyzing Boston, Massachusettes and result is Boston, Massachusetts
# 5326. Analyzing New York, NY [The Bronx] and result is The Bronx, New York
# 5330. Analyzing NY - New York City and result is NY, New York City
# 5338. Analyzing Winston-Salem, NC and result is WinstonSalem, NC
# 5353. Analyzing Croix-des-Bouquets,  Haiti and result is CroixdesBouquets, Haiti
# 5392. Analyzing Bishop Auckland, County Durham, I and result is Bishop Auckland, I
# 5404. Analyzing Westbury, Long Island, NY and result is Westbury, London
# 5429. Analyzing New York City, NY, USA and result is New York City, USA
# 5441. Analyzing Torelló / Barcelona and result is Torell, Barcelona
# 5443. Analyzing Düsseldorf and result is Dsseldorf
# 5448. Analyzing  Ubá, Minas Gerais and result is Ub, Minas Gerais
# 5473. Analyzing Barking, Essex, England and result is Barking, England
# 5590. Analyzing London UK-England and result is London UKEngland
# 5602. Analyzing Barking, Essex, England and result is Barking, England
# 5603. Analyzing Borlänge and result is Borlnge
# 5614. Analyzing Charlemagne, Quebec, Canada and result is Charlemagne, Canada
# 5619. Analyzing Minneapolis/St. Paul, MN and result is Minneapolis, MN
# 5655. Analyzing Reading, Berkshire, England and result is Reading, England
# 5713. Analyzing Hell, Alabama and result is Alabama
# 5740. Analyzing Borlänge and result is Borlnge
# 5744. Analyzing Vancouver, British Columbia, Cana and result is Vancouver, Canada
# 5754. Analyzing California - LA and result is California, LA
# 5776. Analyzing California - SF and result is California, SF
# 5779. Analyzing Toronto, Ontario, Canada and result is Toronto, Canada
# 5780. Analyzing  New York and result is New York
# 5841. Analyzing Düsseldorf and result is Dsseldorf
# 5874. Analyzing Coventry (UK) and result is Coventry UK
# 5893. Analyzing Billinge, Lancashire, England and result is Billinge, England
# 5976. Analyzing Westbury, Long Island, NY and result is Westbury, London
# 6057. Analyzing Saverene, France and result is Saverne, France
# 6059. Analyzing Paddington, London, England and result is Paddington, London
# 6062. Analyzing İngiltere and result is ngiltere
# 6130. Analyzing California - LA and result is California, LA
# 6179. Analyzing NY - New York City and result is NY, New York City
# 6220. Analyzing East Flatbush, Brooklyn, NY and result is East Flatbush, NY
# 6236. Analyzing 台北, Taiwan and result is , Taiwan
# 6237. Analyzing Montr�, Qu�c, Canada and result is Montreal, Canada
# 6256. Analyzing UK - England - South East and result is UK, South East
# 6369. Analyzing Bay Area / Oakland, US and result is Bay Area, US
# 6417. Analyzing California - SF and result is California, SF
# 6430. Analyzing Los Angeles, California, USA and result is Los Angeles, USA
# 6434. Analyzing Westbury, Long Island, NY and result is Westbury, London
# 6499. Analyzing Barking, Essex, England and result is Barking, England
# 6505. Analyzing El, Paso, TX and result is El, TX
# 6510. Analyzing Southampton, Hampshire, England and result is Southampton, England
# 6593. Analyzing NY - New York City and result is NY, New York City
# 6637. Analyzing Sheffield, Yorkshire, England and result is Sheffield, England
# 6646. Analyzing Boston, Massachusettes and result is Boston, Massachusetts
# 6684. Analyzing California - SF and result is California, SF
# 6707. Analyzing Winston-Salem, NC and result is WinstonSalem, NC
# 6946. Analyzing Leyton, East End de Londres and result is Leyton, East End of London
# 6958. Analyzing Havířov, Česká republika and result is Havov, esk republika
# 6975. Analyzing Bronx,New York City (USA) and result is Bronx, New York City USA
# 6979. Analyzing Billinge, Lancashire, England and result is Billinge, England
# 6984. Analyzing NY - New York City and result is NY, New York City
# 7105. Analyzing New York City, NY, USA and result is New York City, USA
# 7129. Analyzing California - LA and result is California, LA
# 7132. Analyzing NY - New York City and result is NY, New York City
# 7282. Analyzing Tri-Cities, Washington and result is TriCities, Washington
# 7319. Analyzing Bergen/Brooklyn and result is Bergen, Brooklyn
# 7335. Analyzing rotherham/sheffield and result is rotherham, sheffield
# 7372. Analyzing California - LA and result is California, LA
# 7394. Analyzing East Flatbush, Brooklyn, NY and result is East Flatbush, NY
# 7397. Analyzing Scarborough, Ontario, Canada and result is Scarborough, Canada
# 7426. Analyzing NY - Upstate NY and result is NY
# 7570. Analyzing Coventry (UK) and result is Coventry UK
# 7583. Analyzing Wiädikä and result is Widik
# 7603. Analyzing AUSTRALIA - New South Wales and result is AUSTRALIA, New South Wales
# 7642. Analyzing Montreal, Quebec, Canada and result is Montreal, Canada
# 7647. Analyzing Lekunberri, Nafarroa, Euskal Herria and result is Lekunberri, Euskal Herria
# 7653. Analyzing Wigan, Lancashire, England and result is Wigan, England
# 7662. Analyzing Borlänge and result is Borlnge
# 7669. Analyzing Berlín and result is Berln
# 7691. Analyzing Collingwood, Canada, ON and result is Collingwood, Canada
# 7751. Analyzing Toronto, Ontario, Canada and result is Toronto, Canada
# 7815. Analyzing CANADA - Ontario and result is CANADA, Ontario
# 7836. Analyzing California - LA and result is California, LA
# 8005. Analyzing Los Angeles, CA - United States and result is Los Angeles, United States
# 8075. Analyzing New York, NY [Queens] and result is Queens, New York
# 8108. Analyzing Beckenham, Kent, England and result is Beckenham, England
# 8179. Analyzing London UK-England and result is London UKEngland
# 8182. Analyzing Barking, Essex, England and result is Barking, England
# 8244. Analyzing Borlänge and result is Borlnge
# 8248. Analyzing Burlington, Ontario, Canada and result is Burlington, Canada
# 8277. Analyzing Paddington, London, England and result is Paddington, London
# 8282. Analyzing Chiswick, London, England and result is Chiswick, London
# 8324. Analyzing SLC/Dogden, Utah and result is SLC, Utah
# 8360. Analyzing CANADA - Ontario and result is CANADA, Ontario
# 8373. Analyzing Ottawa, Ontario, Canada and result is Ottawa, Canada
# 8397. Analyzing İngiltere and result is ngiltere
# 8405. Analyzing Leyton, East End de Londres and result is Leyton, East End of London
# 8432. Analyzing Bishop Auckland, County Durham, I and result is Bishop Auckland, I
# 8520. Analyzing Croix-des-Bouquets,  Haiti and result is CroixdesBouquets, Haiti
# 8529. Analyzing Madrid, España  and result is Madrid, Espaa
# 8563. Analyzing Buff Bay, Portland, Jamaica and result is Buff Bay, Jamaica
# 8590. Analyzing Boston, Massachusettes and result is Boston, Massachusetts
# 8634. Analyzing Ottawa, Ontario, Canada and result is Ottawa, Canada
# 8639. Analyzing Chiswick, London, England and result is Chiswick, London
# 8656. Analyzing Bexleyheath, Kent, England and result is Bexleyheath, England
# 8674. Analyzing Chiswick, London, England and result is Chiswick, London
# 8705. Analyzing Montreal, Qu�c, Canada and result is Montreal, Canada
# 8722. Analyzing NY - Upstate NY and result is NY
# 8739. Analyzing Bradford, W. Yorks, England and result is Bradford, England
# 8765. Analyzing Brixton, London, England and result is Brixton, London
# 8787. Analyzing California - LA and result is California, LA
# 8801. Analyzing Tooting, London, England and result is Tooting, London
# 8839. Analyzing Boston, MA, USA and result is Boston, USA
# 8887. Analyzing Boston, Massachusettes and result is Boston, Massachusetts
# 8907. Analyzing St. Catharines, ON, Canada and result is St. Catharines, Canada
# 8964. Analyzing Sheffield, South Yorkshire, Engla and result is Sheffield, England
# 8981. Analyzing Boston, MA, USA and result is Boston, USA
# 9145. Analyzing Macclesfield, Cheshire, England and result is Macclesfield, England
# 9171. Analyzing Egremont, Cumbria, England and result is Egremont, England
# 9176. Analyzing Newcastle, Tyne and Wear, England and result is Newcastle, England
# 9180. Analyzing Charlemagne, Quebec, Canada and result is Charlemagne, Canada
# 9235. Analyzing New Orleans, Louisiana and result is New Orleans, London
# 9334. Analyzing California - LA and result is California, LA
# 9337. Analyzing NY - New York City and result is NY, New York City
# 9341. Analyzing La Granada del Penedès and result is La Granada del Peneds
# 9345. Analyzing Montreal, Quebec, Canada and result is Montreal, Canada
# 9351. Analyzing CANADA - other and result is CANADA, other
# 9403. Analyzing Sackville, Nova Scotia, Canada and result is Sackville, Canada
# 9413. Analyzing California - LA and result is California, LA
# 9431. Analyzing Fort Lauderdale/Orlando, FL and result is Fort Lauderdale, FL
# 9573. Analyzing Montreal, Qu�c, Canada and result is Montreal, Canada
# 9596. Analyzing Montreal, Qu�c, Canada and result is Montreal, Canada
# 9638. Analyzing New York City, NY, USA and result is New York City, USA
# 9673. Analyzing Lille, Nord-Pas-de-Calais, France and result is Lille, France
# 9684. Analyzing NY - New York City and result is NY, New York City
# 9728. Analyzing Tooting, London, England and result is Tooting, London
# 9741. Analyzing Halifax, Nova Scotia, Canada and result is Halifax, Canada
# 9762. Analyzing Kingston, Ontario, Canada and result is Kingston, Canada
# 9776. Analyzing Toledo,Ohio and result is Toledo, Ohio
# 9857. Analyzing Chatham UK-England and result is Chatham UKEngland
# 9918. Analyzing New York, NY [Bronx] and result is Bronx, New York
# 9985. Analyzing Macclesfield, Cheshire, England and result is Macclesfield, England
# 10004. Analyzing Vancouver, British Columbia, Cana and result is Vancouver, Canada
# 10027. Analyzing CANADA - Ontario and result is CANADA, Ontario
# 10038. Analyzing Chiswick, London, England and result is Chiswick, London
# 10047. Analyzing New York City, NY, USA and result is New York City, USA
# 10164. Analyzing Charlemagne, Quebec, Canada and result is Charlemagne, Canada
# 10243. Analyzing New York, NY [Harlem] and result is Harlem, New York
# 10304. Analyzing Ottawa, Ontario, Canada and result is Ottawa, Canada
# 10446. Analyzing Hammersmith, London, England and result is Hammersmith, London
# 10482. Analyzing NY - New York City and result is NY, New York City
# 10487. Analyzing Toronto, Ontario, Canada and result is Toronto, Canada
# 10506. Analyzing Paddington, London, England and result is Paddington, London
# 10529. Analyzing Edmonton, Alberta, Canada and result is Edmonton, Canada
# 10580. Analyzing CANADA - Ontario and result is CANADA, Ontario
# 10605. Analyzing Charlemagne, Quebec, Canada and result is Charlemagne, Canada
# 10671. Analyzing Reykjavík, Iceland and result is Reykjavk, Iceland
# 10704. Analyzing California - LA and result is California, LA
# 10719. Analyzing Wiädikä and result is Widik
# 10761. Analyzing California - LA and result is California, LA
# 10804. Analyzing Piapot Reserve, Saskatchewan, Can and result is Piapot Reserve, Canada
# 10839. Analyzing Paddington, London, England and result is Paddington, London
# 10960. Analyzing CANADA - Ontario and result is CANADA, Ontario
# 10988. Analyzing California - LA and result is California, LA
# 11033. Analyzing California - LA and result is California, LA
# 11128. Analyzing East Flatbush, Brooklyn, NY and result is East Flatbush, NY
# 11196. Analyzing Braintree, Essex, England and result is Braintree, England
# 11198. Analyzing Espoo/Helsinki and result is Espoo, Helsinki
# 11203. Analyzing Düsseldorf and result is Dsseldorf
# 11289. Analyzing Bradford, Yorkshire, England and result is Bradford, England
# 11296. Analyzing CANADA - Ontario and result is CANADA, Ontario
# 11353. Analyzing CANADA - Nova Scotia and result is CANADA, Nova Scotia
# 11358. Analyzing NY - New York City and result is NY, New York City
# 11457. Analyzing UK - England - London and result is UK, London
# 11581. Analyzing California - LA and result is California, LA
# 11607. Analyzing Bexleyheath, Kent, England and result is Bexleyheath, England
# 11619. Analyzing Vancouver, British Columbia, Cana and result is Vancouver, Canada
# 11622. Analyzing Vancouver, British Columbia, Cana and result is Vancouver, Canada
# 11680. Analyzing New York, NY [The Bronx] and result is The Bronx, New York
# 11697. Analyzing Dumfries, Scotland, United Kingdom and result is Dumfries, United Kingdom
# 11719. Analyzing Great Britain / UK and result is Great Britain, UK
# 11755. Analyzing Timmins, Ontario, Canada and result is Timmins, Canada
# 11769. Analyzing NEW ORLEANS, Louisiana and result is NEW ORLEANS, London
# 11837. Analyzing  Ubá, Minas Gerais and result is Ub, Minas Gerais
# 11861. Analyzing Glasgow UK-SCOTLAND and result is Glasgow UKSCOTLAND
# 11905. Analyzing CORSE / PARIS and result is CORSE, PARIS
# 11916. Analyzing Bishop Auckland, County Durham, I and result is Bishop Auckland, I
# 11991. Analyzing CANADA - Ontario and result is CANADA, Ontario
# 12052. Analyzing Great Britain / UK and result is Great Britain, UK
# 12185. Analyzing Charlemagne, Quebec, Canada and result is Charlemagne, Canada
# 12203. Analyzing Mass. - Boston and result is Mass., Boston
# 12204. Analyzing rotherham/sheffield and result is rotherham, sheffield
# 12221. Analyzing Vancouver, British Columbia, Cana and result is Vancouver, Canada
# 12229. Analyzing Halifaz, Nova Scotia, Canada and result is Halifax, Canada
# 12295. Analyzing Rennes, France, FR and result is Rennes, FR
# 12347. Analyzing Charlemagne, Quebec, Canada and result is Charlemagne, Canada
# 12377. Analyzing Toronto, Ontario, Canada and result is Toronto, Canada
# 12432. Analyzing Mooringsport, Louisiana and result is Mooringsport, London
# 12514. Analyzing Milano, 31 maggio 1953 and result is Milano, maggio
# 12518. Analyzing California - LA and result is California, LA
# 12558. Analyzing Newcastle, Tyne and Wear, England and result is Newcastle, England
# 12559. Analyzing California - LA and result is California, LA
# 12594. Analyzing Chiswick, London, England and result is Chiswick, London
# 12680. Analyzing La Granada del Penedès and result is La Granada del Peneds
# 12700. Analyzing London UK-England and result is London UKEngland
# 12739. Analyzing Burlington, Ontario, Canada and result is Burlington, Canada
# 12823. Analyzing NEW ORLEANS, Louisiana and result is NEW ORLEANS, London
# 12827. Analyzing Eltham, Kent, England and result is Eltham, England
# 12849. Analyzing Ottawa, Ontario, Canada and result is Ottawa, Canada
# 12910. Analyzing Madrid, España  and result is Madrid, Espaa
# 13046. Analyzing Welwyn, Garden City, England and result is Welwyn, England
# 13092. Analyzing California - LA and result is California, LA
# 13099. Analyzing Sheffield, South Yorkshire, Engla and result is Sheffield, England
# 13204. Analyzing Fort Worth (Aledo), TX and result is Fort Worth Aledo, TX
# 13248. Analyzing St. Catharines, ON, Canada and result is St. Catharines, Canada
# 13319. Analyzing Ottawa, Ontario, Canada and result is Ottawa, Canada
# 13321. Analyzing The Bronx, New York City, NY and result is The Bronx, NY
# 13405. Analyzing Västerås and result is Vsters
# 13412. Analyzing NY - New York City and result is NY, New York City
# 13504. Analyzing California - LA and result is California, LA
# 13575. Analyzing Vancouver, British Columbia, Cana and result is Vancouver, Canada
# 13666. Analyzing CANADA - B.C. and result is CANADA, B.C.
# 13669. Analyzing California - SF and result is California, SF
# 13713. Analyzing Ottawa, Ontario, Canada and result is Ottawa, Canada
# 13719. Analyzing Luton, North London, England and result is Luton, England
# 13721. Analyzing New York, NY [Bronx] and result is Bronx, New York
# 13808. Analyzing Great Britain / UK and result is Great Britain, UK
# 13847. Analyzing Fort Worth (Aledo), TX and result is Fort Worth Aledo, TX
# 13852. Analyzing Toronto, Ontario, Canada and result is Toronto, Canada
# 13878. Analyzing Lisboa, Portugal  and result is Lisboa, Portugal
# 13962. Analyzing Ottawa, Ontario, Canada and result is Ottawa, Canada
# 13965. Analyzing Winnipeg, Manitoba, Canada and result is Winnipeg, Canada
# 13995. Analyzing CANADA - Ontario and result is CANADA, Ontario
# 14014. Analyzing Sheffield, South Yorkshire, Engla and result is Sheffield, England
# 14122. Analyzing NY - Long Island and result is NY, Long Island
# 14151. Analyzing Borlänge and result is Borlnge
# 14169. Analyzing Halifax, Nova Scotia, Canada and result is Halifax, Canada
# 14171. Analyzing Bangor, County Down, Ireland and result is Bangor, Ireland
# 14216. Analyzing Mass. - Boston and result is Mass., Boston
# 14239. Analyzing CANADA - Ontario and result is CANADA, Ontario
# 14271. Analyzing Croix-des-Bouquets,  Haiti and result is CroixdesBouquets, Haiti
# 14323. Analyzing Mass. - Boston and result is Mass., Boston
# 14327. Analyzing http://www.sneakerpimps.net and result is
# 14376. Analyzing California - LA and result is California, LA
# 14407. Analyzing NY - Long Island and result is NY, Long Island
# 14472. Analyzing California - LA and result is California, LA
# 14605. Analyzing California - LA and result is California, LA
# 14719. Analyzing Trollh�an, Sweden and result is Trollhattan, Sweden
# 14874. Analyzing Lisboa, Portugal  and result is Lisboa, Portugal
# 79. Analyzing Woking, Surrey, England and result is Woking, England
# 439. Analyzing Great Britain / UK and result is Great Britain, UK
# 487. Analyzing Dundalk, County Louth, Ireland and result is Dundalk, Ireland
# 528. Analyzing Basildon, Essex, England and result is Basildon, England
# 639. Analyzing Wangaratta, Victoria, Australia and result is Wangaratta, Australia
# 1416. Analyzing Lee's Summit, MO and result is Lees Summit, MO
# 2023. Analyzing Wangaratta, Victoria, Australia and result is Wangaratta, Australia
# 2118. Analyzing NY - Long Island and result is NY, Long Island
# 2204. Analyzing Baimorto, La Coruna, Spain and result is Baimorto, Spain
# 2359. Analyzing Wangaratta, Victoria, Australia and result is Wangaratta, Australia
# 2841. Analyzing Wangaratta, Victoria, Australia and result is Wangaratta, Australia
# 3514. Analyzing Sheffield, Yorkshire, England and result is Sheffield, England
# 3537. Analyzing Lee's Summit, MO and result is Lees Summit, MO
# 4457. Analyzing Bogotá Colombia and result is Bogot Colombia
# 5091. Analyzing Wangaratta, Victoria, Australia and result is Wangaratta, Australia
# 5246. Analyzing Münster, Germany and result is Mnster, Germany
# 6621. Analyzing Wangaratta, Victoria, Australia and result is Wangaratta, Australia
# 6622. Analyzing Woking, Surrey, England and result is Woking, England

# %%
print('All = {}'.format(song_df_wlocations_copy.shape))
print('corrected_location not null = {}'.format(song_df_wlocations_copy[song_df_wlocations_copy.corrected_location.notnull()].shape))
# Out:
# All = (2974, 18)
# corrected_location not null = (2974, 18)

# %%
song_df_wlocations_copy.head()
# Out:
#              artist_id  artist_latitude               artist_location  \
# 0   ARTH9041187FB43E1F              NaN                St. Joseph, MO
# 1   ARQFUGM1187FB3E24E              NaN  Los Angeles, California, USA
# 24  ARJ0AL61187B9A3F27              NaN                       Georgia
# 27  ARJ2PMY1187FB5B563              NaN              NY - Long Island
# 31  ARWR6RK1187FB3AB52              NaN               Long Island, NY
#
#     artist_longitude           artist_name  duration  num_songs  \
# 0                NaN                Eminem       312          1
# 1                NaN   Black Label Society       258          1
# 24               NaN           Katie Melua       193          1
# 27               NaN         Burning Spear       334          1
# 31               NaN  From Autumn To Ashes       147          1
#
#                song_id                              title  year _merge  \
# 0   SOLXDDC12A6701FBFD                           I'm Back  2000    NaN
# 1   SOHVHKM12A8C13F716                    Counterfeit God  2000    NaN
# 24  SOFHFLK12AF72A4FB9  Mary Pickford (Used To Eat Roses)  2008    NaN
# 27  SOVTFUO12A6310D813  The Invasion (Aka Black Wa Da Da)     0    NaN
# 31  SOHKXAC12A58A7F6E5                                 IV  2002    NaN
#
#    process corrected_location county city state country country_code
# 0      nan     St. Joseph, MO    nan  nan   nan     nan          nan
# 1      nan   Los Angeles, USA    nan  nan   nan     nan          nan
# 24     nan            Georgia    nan  nan   nan     nan          nan
# 27     nan    NY, Long Island    nan  nan   nan     nan          nan
# 31     nan    Long Island, NY    nan  nan   nan     nan          nan

# %%
#song_df_wlocations_copy.to_csv('song_df_wlocations.csv', encoding='utf-8', index=False)

# %%
#song_df_wlocations_copy.to_csv('song_df_wlocations-backup.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Query geopy and get data for artist_location by running GatherLocationDetails.ipynb

# %%
song_df_wlocations_copy = pd.read_csv("song_df_wlocations.csv")
print('song_df_wlocations.csv = ',song_df_wlocations_copy.shape)
# Out:
# song_df_wlocations.csv =  (2974, 18)

# %%
song_df_wlocations_copy[song_df_wlocations_copy.process != 'Y'].shape
# Out:
# (21, 18)

# %%
song_df_wlocations_copy[song_df_wlocations_copy.process != 'Y']
# Out:
#                artist_id  artist_latitude                    artist_location  \
# 228   ARHTAPO1187FB5AADE              NaN        Leyton, East End de Londres
# 293   AREQFUK11F94B58515              NaN               RSC Slauson Boy : CA
# 338   ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 507   ARQEFHV1187FB42762              NaN      Penarth, Wales to Los Angeles
# 822   ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 1015  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 1277  ARIDCB61187B98952E              NaN             por el mundo cantando.
# 1353  ARHTAPO1187FB5AADE              NaN        Leyton, East End de Londres
# 1365  ARO3SS31187FB3729C              NaN                         Antarctica
# 1432  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 1479  ARLS8UK1187B9898D8              NaN                            Wiädikä
# 1661  ARHTAPO1187FB5AADE              NaN        Leyton, East End de Londres
# 2052  ARO3SS31187FB3729C              NaN                         Antarctica
# 2107  ARLS8UK1187B9898D8              NaN                            Wiädikä
# 2389  ARO3SS31187FB3729C              NaN                         Antarctica
# 2401  AR065TW1187FB4C3A5              NaN  Knowle West, Bristol, Avon, Engla
# 2524  ART39ZB1187B9B1E3A              NaN            Hillside of Vallejo, CA
# 2531  AR40YBH1187FB38A1A              NaN                  Maynardsville, TN
# 2757  ART39ZB1187B9B1E3A              NaN            Hillside of Vallejo, CA
# 2930  ARKDO731187B98E21B              NaN         Baimorto, La Coruna, Spain
# 2970  ARD2GXE1187B9A2E26         16.85576                Guyana, West Indies
#
#       artist_longitude            artist_name  duration  num_songs  \
# 228                NaN                   1001       251          1
# 293                NaN          Nipsey Hussle       200          1
# 338                NaN            Of Montreal       121          1
# 507                NaN                    Jem       282          1
# 822                NaN            Of Montreal       138          1
# 1015               NaN            Of Montreal       201          1
# 1277               NaN  Arcangel La Maravilla       188          1
# 1353               NaN            Iron Maiden       410          1
# 1365               NaN                   GWAR       159          1
# 1432               NaN            Of Montreal       173          1
# 1479               NaN              Phenomden       229          1
# 1661               NaN            Iron Maiden       514          1
# 2052               NaN                   GWAR       261          1
# 2107               NaN              Phenomden       252          1
# 2389               NaN                   GWAR       189          1
# 2401               NaN                 Tricky       266          1
# 2524               NaN                   E-40       226          1
# 2531               NaN              Roy Acuff       138          1
# 2757               NaN      E-40_ Goldie Gold       254          1
# 2930               NaN              Luz Casal       216          1
# 2970         -69.46854          Mad Professor       266          1
#
#                  song_id                                              title  \
# 228   SOYAAAT12AB018C947                                        Underground
# 293   SOSPMPH12AB01849F5                                 One Take Freestyle
# 338   SOPMCEZ12A8C136DCD                 A Dreamy Day Of Daydreaming Of You
# 507   SOSIWPS12A58A7ED14                   Maybe I'm Amazed (Album Version)
# 822   SODAZBR12A6D4F6FFA                 Requiem for O.M.M. (Album Version)
# 1015  SOZCITS12A8C13C65D                             Oslo in the Summertime
# 1277  SOARXRJ12AF72AACE9                                     En el Callejon
# 1353  SOJKLHZ12A6D4F90FC                            These Colours Don't Run
# 1365  SOUBXTR12AB0186DF5                                      Slap U Around
# 1432  SODUMOP12A8C136DCB                                           Penelope
# 1479  SOXUVEB12A8C13B65F                                      Wänn Lärnemer
# 1661  SOHOGUR12A6D4F58E0  Alexander The Great (356-323 BC) (1998 Digital...
# 2052  SORGVTY12AB018349A                                        Surf of Syn
# 2107  SONOTHB12A8C13EFFF                                     Jetz isch Ziit
# 2389  SOCAEYG12AB01849C0                           Let's Blame The Lightman
# 2401  SOJQHWI12B0B80BBC7                                   Record Companies
# 2524  SOGGNFQ12AB017F83C                                          Get Em Up
# 2531  SOBGYAV12A58A7E45D                                Back In The Country
# 2757  SOEXHJE12AB0184322  Off That Vodka (feat. Goldie Gold) (Clean Vers...
# 2930  SOPVGTJ12A8C13EACD                                     Bajo Tu Abrazo
# 2970  SOUIPHX12A6D4F8AB0                                  Schizophrenic Dub
#
#       year     _merge process                 corrected_location county city  \
# 228      0        NaN     NaN         Leyton, East End of London    NaN  NaN
# 293      0        NaN     NaN                RSC Slauson Boy  CA    NaN  NaN
# 338   2001        NaN     NaN                          Sunlandia    NaN  NaN
# 507      0        NaN     NaN      Penarth, Wales to Los Angeles    NaN  NaN
# 822      0        NaN     NaN                          Sunlandia    NaN  NaN
# 1015  2005        NaN     NaN                          Sunlandia    NaN  NaN
# 1277     0        NaN     NaN             por el mundo cantando.    NaN  NaN
# 1353  2006        NaN     NaN         Leyton, East End of London    NaN  NaN
# 1365  1994        NaN     NaN                         Antarctica    NaN  NaN
# 1432  2001        NaN     NaN                          Sunlandia    NaN  NaN
# 1479     0        NaN     NaN                              Widik    NaN  NaN
# 1661  1986        NaN     NaN         Leyton, East End of London    NaN  NaN
# 2052  1995        NaN     NaN                         Antarctica    NaN  NaN
# 2107     0        NaN     NaN                              Widik    NaN  NaN
# 2389  1997        NaN     NaN                         Antarctica    NaN  NaN
# 2401  1998        NaN     NaN  Knowle West, Bristol, Avon, Engla    NaN  NaN
# 2524  1993        NaN     NaN            Hillside of Vallejo, CA    NaN  NaN
# 2531  2001        NaN     NaN                  Maynardsville, TN    NaN  NaN
# 2757     0        NaN     NaN            Hillside of Vallejo, CA    NaN  NaN
# 2930     0  left_only     NaN                    Baimorto, Spain    NaN  NaN
# 2970  1986        NaN     NaN                Guyana, West Indies    NaN  NaN
#
#      state country country_code
# 228    NaN     NaN          NaN
# 293    NaN     NaN          NaN
# 338    NaN     NaN          NaN
# 507    NaN     NaN          NaN
# 822    NaN     NaN          NaN
# 1015   NaN     NaN          NaN
# 1277   NaN     NaN          NaN
# 1353   NaN     NaN          NaN
# 1365   NaN     NaN          NaN
# 1432   NaN     NaN          NaN
# 1479   NaN     NaN          NaN
# 1661   NaN     NaN          NaN
# 2052   NaN     NaN          NaN
# 2107   NaN     NaN          NaN
# 2389   NaN     NaN          NaN
# 2401   NaN     NaN          NaN
# 2524   NaN     NaN          NaN
# 2531   NaN     NaN          NaN
# 2757   NaN     NaN          NaN
# 2930   NaN     NaN          NaN
# 2970   NaN     NaN          NaN

# %%
#Observation found that is county, state, country is filled but not the corrected_location. So just filling that up
#song_df_wlocations_copy[song_df_wlocations_copy.artist_location.str.contains('http', na=False)]
song_df_wlocations_copy[song_df_wlocations_copy.corrected_location.isnull()]
# Out:
#                artist_id  artist_latitude              artist_location  \
# 2779  ART9KTA1187B9A3956         34.22678  http://www.sneakerpimps.net
#
#       artist_longitude    artist_name  duration  num_songs  \
# 2779         70.396426  Sneaker Pimps       298          1
#
#                  song_id          title  year _merge process  \
# 2779  SOQFCCN12AB0182A43  Walk The Rain  1997    NaN       Y
#
#      corrected_location     county city      state      country country_code
# 2779                NaN  Chaparhar  NaN  Nangarhar  Afghanistan           af

# %%
ix = int(song_df_wlocations_copy[song_df_wlocations_copy.corrected_location.isnull()].index.values)
print(ix)
song_df_wlocations_copy.at[ix,'corrected_location']='Jalalabad Afghanistan'
song_df_wlocations_copy.at[ix,'process']='N'
# Out:
# 2779

# %%
temp = song_df_wlocations_copy[song_df_wlocations_copy.process != 'Y'].copy()

# %%
temp
# Out:
#                artist_id  artist_latitude                    artist_location  \
# 2779  ART9KTA1187B9A3956         34.22678        http://www.sneakerpimps.net
# 2953  ARHTAPO1187FB5AADE              NaN        Leyton, East End de Londres
# 2954  AREQFUK11F94B58515              NaN               RSC Slauson Boy : CA
# 2955  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 2956  ARQEFHV1187FB42762              NaN      Penarth, Wales to Los Angeles
# 2957  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 2958  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 2959  ARIDCB61187B98952E              NaN             por el mundo cantando.
# 2960  ARHTAPO1187FB5AADE              NaN        Leyton, East End de Londres
# 2961  ARO3SS31187FB3729C              NaN                         Antarctica
# 2962  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 2963  ARLS8UK1187B9898D8              NaN                            Wiädikä
# 2964  ARHTAPO1187FB5AADE              NaN        Leyton, East End de Londres
# 2965  ARO3SS31187FB3729C              NaN                         Antarctica
# 2966  ARLS8UK1187B9898D8              NaN                            Wiädikä
# 2967  ARO3SS31187FB3729C              NaN                         Antarctica
# 2968  AR065TW1187FB4C3A5              NaN  Knowle West, Bristol, Avon, Engla
# 2969  ART39ZB1187B9B1E3A              NaN            Hillside of Vallejo, CA
# 2970  AR40YBH1187FB38A1A              NaN                  Maynardsville, TN
# 2971  ART39ZB1187B9B1E3A              NaN            Hillside of Vallejo, CA
# 2972  ARKDO731187B98E21B              NaN         Baimorto, La Coruna, Spain
# 2973  ARD2GXE1187B9A2E26         16.85576                Guyana, West Indies
#
#       artist_longitude            artist_name  duration  num_songs  \
# 2779         70.396426          Sneaker Pimps       298          1
# 2953               NaN                   1001       251          1
# 2954               NaN          Nipsey Hussle       200          1
# 2955               NaN            Of Montreal       121          1
# 2956               NaN                    Jem       282          1
# 2957               NaN            Of Montreal       138          1
# 2958               NaN            Of Montreal       201          1
# 2959               NaN  Arcangel La Maravilla       188          1
# 2960               NaN            Iron Maiden       410          1
# 2961               NaN                   GWAR       159          1
# 2962               NaN            Of Montreal       173          1
# 2963               NaN              Phenomden       229          1
# 2964               NaN            Iron Maiden       514          1
# 2965               NaN                   GWAR       261          1
# 2966               NaN              Phenomden       252          1
# 2967               NaN                   GWAR       189          1
# 2968               NaN                 Tricky       266          1
# 2969               NaN                   E-40       226          1
# 2970               NaN              Roy Acuff       138          1
# 2971               NaN      E-40_ Goldie Gold       254          1
# 2972               NaN              Luz Casal       216          1
# 2973        -69.468540          Mad Professor       266          1
#
#                  song_id                                              title  \
# 2779  SOQFCCN12AB0182A43                                      Walk The Rain
# 2953  SOYAAAT12AB018C947                                        Underground
# 2954  SOSPMPH12AB01849F5                                 One Take Freestyle
# 2955  SOPMCEZ12A8C136DCD                 A Dreamy Day Of Daydreaming Of You
# 2956  SOSIWPS12A58A7ED14                   Maybe I'm Amazed (Album Version)
# 2957  SODAZBR12A6D4F6FFA                 Requiem for O.M.M. (Album Version)
# 2958  SOZCITS12A8C13C65D                             Oslo in the Summertime
# 2959  SOARXRJ12AF72AACE9                                     En el Callejon
# 2960  SOJKLHZ12A6D4F90FC                            These Colours Don't Run
# 2961  SOUBXTR12AB0186DF5                                      Slap U Around
# 2962  SODUMOP12A8C136DCB                                           Penelope
# 2963  SOXUVEB12A8C13B65F                                      Wänn Lärnemer
# 2964  SOHOGUR12A6D4F58E0  Alexander The Great (356-323 BC) (1998 Digital...
# 2965  SORGVTY12AB018349A                                        Surf of Syn
# 2966  SONOTHB12A8C13EFFF                                     Jetz isch Ziit
# 2967  SOCAEYG12AB01849C0                           Let's Blame The Lightman
# 2968  SOJQHWI12B0B80BBC7                                   Record Companies
# 2969  SOGGNFQ12AB017F83C                                          Get Em Up
# 2970  SOBGYAV12A58A7E45D                                Back In The Country
# 2971  SOEXHJE12AB0184322  Off That Vodka (feat. Goldie Gold) (Clean Vers...
# 2972  SOPVGTJ12A8C13EACD                                     Bajo Tu Abrazo
# 2973  SOUIPHX12A6D4F8AB0                                  Schizophrenic Dub
#
#       year     _merge process      corrected_location     county city  \
# 2779  1997        NaN       N   Jalalabad Afghanistan  Chaparhar  NaN
# 2953     0        NaN       N          Leyton, London        NaN  NaN
# 2954     0        NaN       N                      CA        NaN  NaN
# 2955  2001        NaN       N              Athens, GA        NaN  NaN
# 2956     0        NaN       N             Los Angeles        NaN  NaN
# 2957     0        NaN       N              Athens, GA        NaN  NaN
# 2958  2005        NaN       N              Athens, GA        NaN  NaN
# 2959     0        NaN       N  por el mundo cantando.        NaN  NaN
# 2960  2006        NaN       N          Leyton, London        NaN  NaN
# 2961  1994        NaN       N              Antarctica        NaN  NaN
# 2962  2001        NaN       N              Athens, GA        NaN  NaN
# 2963     0        NaN       N                 Wiädikä        NaN  NaN
# 2964  1986        NaN       N          Leyton, London        NaN  NaN
# 2965  1995        NaN       N              Antarctica        NaN  NaN
# 2966     0        NaN       N                 Wiädikä        NaN  NaN
# 2967  1997        NaN       N              Antarctica        NaN  NaN
# 2968  1998        NaN       N    Knowle West, England        NaN  NaN
# 2969  1993        NaN       N             Vallejo, CA        NaN  NaN
# 2970  2001        NaN       N        Maynardville, TN        NaN  NaN
# 2971     0        NaN       N             Vallejo, CA        NaN  NaN
# 2972     0  left_only       N        La Coruna, Spain        NaN  NaN
# 2973  1986        NaN       N                  Guyana        NaN  NaN
#
#           state      country country_code
# 2779  Nangarhar  Afghanistan           af
# 2953        NaN          NaN          NaN
# 2954        NaN          NaN          NaN
# 2955        NaN          NaN          NaN
# 2956        NaN          NaN          NaN
# 2957        NaN          NaN          NaN
# 2958        NaN          NaN          NaN
# 2959        NaN          NaN          NaN
# 2960        NaN          NaN          NaN
# 2961        NaN          NaN          NaN
# 2962        NaN          NaN          NaN
# 2963        NaN          NaN          NaN
# 2964        NaN          NaN          NaN
# 2965        NaN          NaN          NaN
# 2966        NaN          NaN          NaN
# 2967        NaN          NaN          NaN
# 2968        NaN          NaN          NaN
# 2969        NaN          NaN          NaN
# 2970        NaN          NaN          NaN
# 2971        NaN          NaN          NaN
# 2972        NaN          NaN          NaN
# 2973        NaN          NaN          NaN

# %%
#Manually updating locations which was missed in earlier correction
temp.corrected_location = temp.corrected_location.replace('Sunlandia','Athens, GA')
temp.corrected_location = temp.corrected_location.replace('RSC Slauson Boy : CA','CA')
temp.corrected_location = temp.corrected_location.replace('Penarth, Wales to Los Angeles','Los Angeles')
temp.corrected_location = temp.corrected_location.replace('Leyton, East End de Londres','Leyton, London')
temp.corrected_location = temp.corrected_location.replace('Knowle West, Bristol, Avon, Engla','Knowle West, England')
temp.corrected_location = temp.corrected_location.replace('Hillside of Vallejo, CA','Vallejo, CA')
temp.corrected_location = temp.corrected_location.replace('Maynardsville, TN','Maynardville, TN')
temp.corrected_location = temp.corrected_location.replace('Baimorto, La Coruna, Spain','La Coruna, Spain')
temp.corrected_location = temp.corrected_location.replace('Guyana, West Indies','Guyana')
temp.process = 'N'

# %%
temp
# Out:
#                artist_id  artist_latitude                    artist_location  \
# 2779  ART9KTA1187B9A3956         34.22678        http://www.sneakerpimps.net
# 2953  ARHTAPO1187FB5AADE              NaN        Leyton, East End de Londres
# 2954  AREQFUK11F94B58515              NaN               RSC Slauson Boy : CA
# 2955  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 2956  ARQEFHV1187FB42762              NaN      Penarth, Wales to Los Angeles
# 2957  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 2958  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 2959  ARIDCB61187B98952E              NaN             por el mundo cantando.
# 2960  ARHTAPO1187FB5AADE              NaN        Leyton, East End de Londres
# 2961  ARO3SS31187FB3729C              NaN                         Antarctica
# 2962  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 2963  ARLS8UK1187B9898D8              NaN                            Wiädikä
# 2964  ARHTAPO1187FB5AADE              NaN        Leyton, East End de Londres
# 2965  ARO3SS31187FB3729C              NaN                         Antarctica
# 2966  ARLS8UK1187B9898D8              NaN                            Wiädikä
# 2967  ARO3SS31187FB3729C              NaN                         Antarctica
# 2968  AR065TW1187FB4C3A5              NaN  Knowle West, Bristol, Avon, Engla
# 2969  ART39ZB1187B9B1E3A              NaN            Hillside of Vallejo, CA
# 2970  AR40YBH1187FB38A1A              NaN                  Maynardsville, TN
# 2971  ART39ZB1187B9B1E3A              NaN            Hillside of Vallejo, CA
# 2972  ARKDO731187B98E21B              NaN         Baimorto, La Coruna, Spain
# 2973  ARD2GXE1187B9A2E26         16.85576                Guyana, West Indies
#
#       artist_longitude            artist_name  duration  num_songs  \
# 2779         70.396426          Sneaker Pimps       298          1
# 2953               NaN                   1001       251          1
# 2954               NaN          Nipsey Hussle       200          1
# 2955               NaN            Of Montreal       121          1
# 2956               NaN                    Jem       282          1
# 2957               NaN            Of Montreal       138          1
# 2958               NaN            Of Montreal       201          1
# 2959               NaN  Arcangel La Maravilla       188          1
# 2960               NaN            Iron Maiden       410          1
# 2961               NaN                   GWAR       159          1
# 2962               NaN            Of Montreal       173          1
# 2963               NaN              Phenomden       229          1
# 2964               NaN            Iron Maiden       514          1
# 2965               NaN                   GWAR       261          1
# 2966               NaN              Phenomden       252          1
# 2967               NaN                   GWAR       189          1
# 2968               NaN                 Tricky       266          1
# 2969               NaN                   E-40       226          1
# 2970               NaN              Roy Acuff       138          1
# 2971               NaN      E-40_ Goldie Gold       254          1
# 2972               NaN              Luz Casal       216          1
# 2973        -69.468540          Mad Professor       266          1
#
#                  song_id                                              title  \
# 2779  SOQFCCN12AB0182A43                                      Walk The Rain
# 2953  SOYAAAT12AB018C947                                        Underground
# 2954  SOSPMPH12AB01849F5                                 One Take Freestyle
# 2955  SOPMCEZ12A8C136DCD                 A Dreamy Day Of Daydreaming Of You
# 2956  SOSIWPS12A58A7ED14                   Maybe I'm Amazed (Album Version)
# 2957  SODAZBR12A6D4F6FFA                 Requiem for O.M.M. (Album Version)
# 2958  SOZCITS12A8C13C65D                             Oslo in the Summertime
# 2959  SOARXRJ12AF72AACE9                                     En el Callejon
# 2960  SOJKLHZ12A6D4F90FC                            These Colours Don't Run
# 2961  SOUBXTR12AB0186DF5                                      Slap U Around
# 2962  SODUMOP12A8C136DCB                                           Penelope
# 2963  SOXUVEB12A8C13B65F                                      Wänn Lärnemer
# 2964  SOHOGUR12A6D4F58E0  Alexander The Great (356-323 BC) (1998 Digital...
# 2965  SORGVTY12AB018349A                                        Surf of Syn
# 2966  SONOTHB12A8C13EFFF                                     Jetz isch Ziit
# 2967  SOCAEYG12AB01849C0                           Let's Blame The Lightman
# 2968  SOJQHWI12B0B80BBC7                                   Record Companies
# 2969  SOGGNFQ12AB017F83C                                          Get Em Up
# 2970  SOBGYAV12A58A7E45D                                Back In The Country
# 2971  SOEXHJE12AB0184322  Off That Vodka (feat. Goldie Gold) (Clean Vers...
# 2972  SOPVGTJ12A8C13EACD                                     Bajo Tu Abrazo
# 2973  SOUIPHX12A6D4F8AB0                                  Schizophrenic Dub
#
#       year     _merge process      corrected_location     county city  \
# 2779  1997        NaN       N   Jalalabad Afghanistan  Chaparhar  NaN
# 2953     0        NaN       N          Leyton, London        NaN  NaN
# 2954     0        NaN       N                      CA        NaN  NaN
# 2955  2001        NaN       N              Athens, GA        NaN  NaN
# 2956     0        NaN       N             Los Angeles        NaN  NaN
# 2957     0        NaN       N              Athens, GA        NaN  NaN
# 2958  2005        NaN       N              Athens, GA        NaN  NaN
# 2959     0        NaN       N  por el mundo cantando.        NaN  NaN
# 2960  2006        NaN       N          Leyton, London        NaN  NaN
# 2961  1994        NaN       N              Antarctica        NaN  NaN
# 2962  2001        NaN       N              Athens, GA        NaN  NaN
# 2963     0        NaN       N                 Wiädikä        NaN  NaN
# 2964  1986        NaN       N          Leyton, London        NaN  NaN
# 2965  1995        NaN       N              Antarctica        NaN  NaN
# 2966     0        NaN       N                 Wiädikä        NaN  NaN
# 2967  1997        NaN       N              Antarctica        NaN  NaN
# 2968  1998        NaN       N    Knowle West, England        NaN  NaN
# 2969  1993        NaN       N             Vallejo, CA        NaN  NaN
# 2970  2001        NaN       N        Maynardville, TN        NaN  NaN
# 2971     0        NaN       N             Vallejo, CA        NaN  NaN
# 2972     0  left_only       N        La Coruna, Spain        NaN  NaN
# 2973  1986        NaN       N                  Guyana        NaN  NaN
#
#           state      country country_code
# 2779  Nangarhar  Afghanistan           af
# 2953        NaN          NaN          NaN
# 2954        NaN          NaN          NaN
# 2955        NaN          NaN          NaN
# 2956        NaN          NaN          NaN
# 2957        NaN          NaN          NaN
# 2958        NaN          NaN          NaN
# 2959        NaN          NaN          NaN
# 2960        NaN          NaN          NaN
# 2961        NaN          NaN          NaN
# 2962        NaN          NaN          NaN
# 2963        NaN          NaN          NaN
# 2964        NaN          NaN          NaN
# 2965        NaN          NaN          NaN
# 2966        NaN          NaN          NaN
# 2967        NaN          NaN          NaN
# 2968        NaN          NaN          NaN
# 2969        NaN          NaN          NaN
# 2970        NaN          NaN          NaN
# 2971        NaN          NaN          NaN
# 2972        NaN          NaN          NaN
# 2973        NaN          NaN          NaN

# %%
#Replace non-processed corrected_location rows from song_df_wlocations_copy2 with newly corrected location rows
print('Before temp = ',temp.shape)
print('Before song_df_wlocations_copy = ',song_df_wlocations_copy.shape)

song_df_wlocations_copy2 = song_df_wlocations_copy.copy()
song_df_wlocations_copy2 = song_df_wlocations_copy2[song_df_wlocations_copy2.process == 'Y'].copy()
song_df_wlocations_copy2 = song_df_wlocations_copy2.append(temp, sort=False)

print('After temp = ',temp.shape)
print('Afer song_df_wlocations_copy2 = ',song_df_wlocations_copy2.shape)
# Out:
# Before temp =  (22, 18)
# Before song_df_wlocations_copy =  (2974, 18)
# After temp =  (22, 18)
# Afer song_df_wlocations_copy2 =  (2974, 18)

# %%
song_df_wlocations_copy2[song_df_wlocations_copy2.process == 'N']
# Out:
#                artist_id  artist_latitude                    artist_location  \
# 2779  ART9KTA1187B9A3956         34.22678        http://www.sneakerpimps.net
# 2953  ARHTAPO1187FB5AADE              NaN        Leyton, East End de Londres
# 2954  AREQFUK11F94B58515              NaN               RSC Slauson Boy : CA
# 2955  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 2956  ARQEFHV1187FB42762              NaN      Penarth, Wales to Los Angeles
# 2957  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 2958  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 2959  ARIDCB61187B98952E              NaN             por el mundo cantando.
# 2960  ARHTAPO1187FB5AADE              NaN        Leyton, East End de Londres
# 2961  ARO3SS31187FB3729C              NaN                         Antarctica
# 2962  ARYMCJZ1187FB513DA              NaN                          Sunlandia
# 2963  ARLS8UK1187B9898D8              NaN                            Wiädikä
# 2964  ARHTAPO1187FB5AADE              NaN        Leyton, East End de Londres
# 2965  ARO3SS31187FB3729C              NaN                         Antarctica
# 2966  ARLS8UK1187B9898D8              NaN                            Wiädikä
# 2967  ARO3SS31187FB3729C              NaN                         Antarctica
# 2968  AR065TW1187FB4C3A5              NaN  Knowle West, Bristol, Avon, Engla
# 2969  ART39ZB1187B9B1E3A              NaN            Hillside of Vallejo, CA
# 2970  AR40YBH1187FB38A1A              NaN                  Maynardsville, TN
# 2971  ART39ZB1187B9B1E3A              NaN            Hillside of Vallejo, CA
# 2972  ARKDO731187B98E21B              NaN         Baimorto, La Coruna, Spain
# 2973  ARD2GXE1187B9A2E26         16.85576                Guyana, West Indies
#
#       artist_longitude            artist_name  duration  num_songs  \
# 2779         70.396426          Sneaker Pimps       298          1
# 2953               NaN                   1001       251          1
# 2954               NaN          Nipsey Hussle       200          1
# 2955               NaN            Of Montreal       121          1
# 2956               NaN                    Jem       282          1
# 2957               NaN            Of Montreal       138          1
# 2958               NaN            Of Montreal       201          1
# 2959               NaN  Arcangel La Maravilla       188          1
# 2960               NaN            Iron Maiden       410          1
# 2961               NaN                   GWAR       159          1
# 2962               NaN            Of Montreal       173          1
# 2963               NaN              Phenomden       229          1
# 2964               NaN            Iron Maiden       514          1
# 2965               NaN                   GWAR       261          1
# 2966               NaN              Phenomden       252          1
# 2967               NaN                   GWAR       189          1
# 2968               NaN                 Tricky       266          1
# 2969               NaN                   E-40       226          1
# 2970               NaN              Roy Acuff       138          1
# 2971               NaN      E-40_ Goldie Gold       254          1
# 2972               NaN              Luz Casal       216          1
# 2973        -69.468540          Mad Professor       266          1
#
#                  song_id                                              title  \
# 2779  SOQFCCN12AB0182A43                                      Walk The Rain
# 2953  SOYAAAT12AB018C947                                        Underground
# 2954  SOSPMPH12AB01849F5                                 One Take Freestyle
# 2955  SOPMCEZ12A8C136DCD                 A Dreamy Day Of Daydreaming Of You
# 2956  SOSIWPS12A58A7ED14                   Maybe I'm Amazed (Album Version)
# 2957  SODAZBR12A6D4F6FFA                 Requiem for O.M.M. (Album Version)
# 2958  SOZCITS12A8C13C65D                             Oslo in the Summertime
# 2959  SOARXRJ12AF72AACE9                                     En el Callejon
# 2960  SOJKLHZ12A6D4F90FC                            These Colours Don't Run
# 2961  SOUBXTR12AB0186DF5                                      Slap U Around
# 2962  SODUMOP12A8C136DCB                                           Penelope
# 2963  SOXUVEB12A8C13B65F                                      Wänn Lärnemer
# 2964  SOHOGUR12A6D4F58E0  Alexander The Great (356-323 BC) (1998 Digital...
# 2965  SORGVTY12AB018349A                                        Surf of Syn
# 2966  SONOTHB12A8C13EFFF                                     Jetz isch Ziit
# 2967  SOCAEYG12AB01849C0                           Let's Blame The Lightman
# 2968  SOJQHWI12B0B80BBC7                                   Record Companies
# 2969  SOGGNFQ12AB017F83C                                          Get Em Up
# 2970  SOBGYAV12A58A7E45D                                Back In The Country
# 2971  SOEXHJE12AB0184322  Off That Vodka (feat. Goldie Gold) (Clean Vers...
# 2972  SOPVGTJ12A8C13EACD                                     Bajo Tu Abrazo
# 2973  SOUIPHX12A6D4F8AB0                                  Schizophrenic Dub
#
#       year     _merge process      corrected_location     county city  \
# 2779  1997        NaN       N   Jalalabad Afghanistan  Chaparhar  NaN
# 2953     0        NaN       N          Leyton, London        NaN  NaN
# 2954     0        NaN       N                      CA        NaN  NaN
# 2955  2001        NaN       N              Athens, GA        NaN  NaN
# 2956     0        NaN       N             Los Angeles        NaN  NaN
# 2957     0        NaN       N              Athens, GA        NaN  NaN
# 2958  2005        NaN       N              Athens, GA        NaN  NaN
# 2959     0        NaN       N  por el mundo cantando.        NaN  NaN
# 2960  2006        NaN       N          Leyton, London        NaN  NaN
# 2961  1994        NaN       N              Antarctica        NaN  NaN
# 2962  2001        NaN       N              Athens, GA        NaN  NaN
# 2963     0        NaN       N                 Wiädikä        NaN  NaN
# 2964  1986        NaN       N          Leyton, London        NaN  NaN
# 2965  1995        NaN       N              Antarctica        NaN  NaN
# 2966     0        NaN       N                 Wiädikä        NaN  NaN
# 2967  1997        NaN       N              Antarctica        NaN  NaN
# 2968  1998        NaN       N    Knowle West, England        NaN  NaN
# 2969  1993        NaN       N             Vallejo, CA        NaN  NaN
# 2970  2001        NaN       N        Maynardville, TN        NaN  NaN
# 2971     0        NaN       N             Vallejo, CA        NaN  NaN
# 2972     0  left_only       N        La Coruna, Spain        NaN  NaN
# 2973  1986        NaN       N                  Guyana        NaN  NaN
#
#           state      country country_code
# 2779  Nangarhar  Afghanistan           af
# 2953        NaN          NaN          NaN
# 2954        NaN          NaN          NaN
# 2955        NaN          NaN          NaN
# 2956        NaN          NaN          NaN
# 2957        NaN          NaN          NaN
# 2958        NaN          NaN          NaN
# 2959        NaN          NaN          NaN
# 2960        NaN          NaN          NaN
# 2961        NaN          NaN          NaN
# 2962        NaN          NaN          NaN
# 2963        NaN          NaN          NaN
# 2964        NaN          NaN          NaN
# 2965        NaN          NaN          NaN
# 2966        NaN          NaN          NaN
# 2967        NaN          NaN          NaN
# 2968        NaN          NaN          NaN
# 2969        NaN          NaN          NaN
# 2970        NaN          NaN          NaN
# 2971        NaN          NaN          NaN
# 2972        NaN          NaN          NaN
# 2973        NaN          NaN          NaN

# %%
#song_df_wlocations_copy2.to_csv('song_df_wlocations.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Rerun geopy in GatherLocationDetails.ipynb to find locations of locations PROCESS='N'

# %%
song_df_wlocations_copy = pd.read_csv("song_df_wlocations.csv")
print('song_df_wlocations.csv = ',song_df_wlocations_copy.shape)
# Out:
# song_df_wlocations.csv =  (2974, 18)

# %%
song_df_wlocations_copy[song_df_wlocations_copy.process != 'Y']
# Out:
#                artist_id  artist_latitude         artist_location  \
# 2959  ARIDCB61187B98952E              NaN  por el mundo cantando.
# 2961  ARO3SS31187FB3729C              NaN              Antarctica
# 2963  ARLS8UK1187B9898D8              NaN                 Wiädikä
# 2965  ARO3SS31187FB3729C              NaN              Antarctica
# 2966  ARLS8UK1187B9898D8              NaN                 Wiädikä
# 2967  ARO3SS31187FB3729C              NaN              Antarctica
#
#       artist_longitude            artist_name  duration  num_songs  \
# 2959               NaN  Arcangel La Maravilla       188          1
# 2961               NaN                   GWAR       159          1
# 2963               NaN              Phenomden       229          1
# 2965               NaN                   GWAR       261          1
# 2966               NaN              Phenomden       252          1
# 2967               NaN                   GWAR       189          1
#
#                  song_id                     title  year _merge process  \
# 2959  SOARXRJ12AF72AACE9            En el Callejon     0    NaN       N
# 2961  SOUBXTR12AB0186DF5             Slap U Around  1994    NaN       N
# 2963  SOXUVEB12A8C13B65F             Wänn Lärnemer     0    NaN       N
# 2965  SORGVTY12AB018349A               Surf of Syn  1995    NaN       N
# 2966  SONOTHB12A8C13EFFF            Jetz isch Ziit     0    NaN       N
# 2967  SOCAEYG12AB01849C0  Let's Blame The Lightman  1997    NaN       N
#
#           corrected_location county city state country country_code
# 2959  por el mundo cantando.    NaN  NaN   NaN     NaN          NaN
# 2961              Antarctica    NaN  NaN   NaN     NaN          NaN
# 2963                 Wiädikä    NaN  NaN   NaN     NaN          NaN
# 2965              Antarctica    NaN  NaN   NaN     NaN          NaN
# 2966                 Wiädikä    NaN  NaN   NaN     NaN          NaN
# 2967              Antarctica    NaN  NaN   NaN     NaN          NaN

# %%
song_df_wlocations_copy[song_df_wlocations_copy.corrected_location.isnull()]
# Out:
# Empty DataFrame
# Columns: [artist_id, artist_latitude, artist_location, artist_longitude, artist_name, duration, num_songs, song_id, title, year, _merge, process, corrected_location, county, city, state, country, country_code]
# Index: []

# %%
song_df_wblank.shape
# Out:
# (6707, 11)

# %%
song_df_latlon = pd.read_csv("song_df_latlon.csv")
song_df_wlocations = pd.read_csv("song_df_wlocations.csv")
song_df_wblank = pd.read_csv("song_df_wblank.csv")

# %%
print('All = ',song_df_copy.shape)
print('Locations = ',song_df_wlocations.shape)
print('Blank = ',song_df_wblank.shape)
print('LatLon= ',song_df_latlon.shape)

# %%
#song_df_wblank doesn't have those extra columns
song_df_wblank['process'] = np.NaN
song_df_wblank['process'] = song_df_wblank.process.astype(str)
song_df_wblank['corrected_location'] = np.NaN
song_df_wblank['corrected_location'] = song_df_wblank.corrected_location.astype(str)
song_df_wblank['county'] = np.NaN
song_df_wblank['county'] = song_df_wblank.county.astype(str)
song_df_wblank['city'] = np.NaN
song_df_wblank['city'] = song_df_wblank.city.astype(str)
song_df_wblank['state'] = np.NaN
song_df_wblank['state'] = song_df_wblank.state.astype(str)
song_df_wblank['country'] = np.NaN
song_df_wblank['country'] = song_df_wblank.country.astype(str)
song_df_wblank['country_code'] = np.NaN
song_df_wblank['country_code'] = song_df_wblank.country_code.astype(str)

# %%
print('All = ',song_df_copy.shape)
print('Locations = ',song_df_wlocations.shape)
print('Blank = ',song_df_wblank.shape)
print('LatLon= ',song_df_latlon.shape)
# Out:
# All =  (14896, 10)
# Locations =  (2974, 18)
# Blank =  (6649, 18)
# LatLon=  (5277, 18)

# %%
#Merging dataframes
song_df_clean = pd.DataFrame()
song_df_clean = song_df_clean.append(song_df_wlocations)
song_df_clean = song_df_clean.append(song_df_wblank)
song_df_clean = song_df_clean.append(song_df_latlon)
print(song_df_clean.shape)
# Out:
# (14900, 18)

# %%
#No duplicate records, but there is this 4 extra records(God damnit!).
print('All = ',song_df_clean.shape)
bool_series = song_df_clean.duplicated()
song_unique_df = song_df_clean[~bool_series]
print('Unique = ',song_unique_df.shape)
# Out:
# All =  (14900, 18)
# Unique =  (14900, 18)

# %% [markdown]
# ### Issue 6 : Convert log_df : userId column from float64 to Int
#
# #### Define
# Convert userId column from float64 to Int
#
# ### Code

# %%
log_df_clean = pd.read_csv("log_df_clean-original.csv")

# %%
log_df_clean.userId = log_df_clean.userId.replace(np.nan, 0)
log_df_clean['userId'] = log_df_clean.userId.astype(int)

# %% [markdown]
# ### Test

# %%
log_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8056 entries, 0 to 8055
# Data columns (total 18 columns):
# artist           6820 non-null object
# auth             8056 non-null object
# firstName        7770 non-null object
# gender           7770 non-null object
# itemInSession    8056 non-null int64
# lastName         7770 non-null object
# length           6820 non-null float64
# level            8056 non-null object
# location         7770 non-null object
# method           8056 non-null object
# page             8056 non-null object
# registration     8056 non-null int64
# sessionId        8056 non-null int64
# song             6820 non-null object
# status           8056 non-null int64
# ts               8056 non-null object
# userAgent        7770 non-null object
# userId           8056 non-null int64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 1.1+ MB

# %%
log_df_clean[log_df_clean.userId.isnull()]
# Out:
# Empty DataFrame
# Columns: [artist, auth, firstName, gender, itemInSession, lastName, length, level, location, method, page, registration, sessionId, song, status, ts, userAgent, userId]
# Index: []

# %%
#log_df_clean = log_df_clean.head(2).copy()

# %%
log_df_clean.to_csv('log_df_clean.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Issue 7 : song_df removing column _merge
# #### Define
# song_df : Remove column _merge
#
# #### Code

# %%
song_df_clean = pd.read_csv("song_df_clean-original.csv")

# %%
song_df_clean.drop(['_merge'], axis=1, inplace=True)

# %%
song_df_clean.to_csv('song_df_clean.csv', encoding='utf-8', index=False)

# %% [markdown]
# #### Test

# %%
song_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14900 entries, 0 to 14899
# Data columns (total 17 columns):
# artist_id             14900 non-null object
# artist_latitude       8245 non-null float64
# artist_location       8241 non-null object
# artist_longitude      8245 non-null float64
# artist_name           14900 non-null object
# duration              14900 non-null int64
# num_songs             14900 non-null int64
# song_id               14900 non-null object
# title                 14900 non-null object
# year                  14900 non-null int64
# process               8247 non-null object
# corrected_location    2974 non-null object
# county                7134 non-null object
# city                  6037 non-null object
# state                 8002 non-null object
# country               8241 non-null object
# country_code          8241 non-null object
# dtypes: float64(2), int64(3), object(12)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Writing clean datasets

# %% [markdown]
# Commenting the below writes so it does not get overwritten by mistake

# %%
#song_df_clean.to_csv('song_df_clean.csv', encoding='utf-8', index=False)
#log_df_copy.to_csv('log_df_clean.csv', encoding='utf-8', index=False)

# %%
log_df_clean = pd.read_csv("log_df_clean.csv")
song_df_clean = pd.read_csv("song_df_clean.csv")

# %%
print('Total rows in log_df_copy = {}'.format(log_df_clean.shape[0]))
print('Total rows in song_df_copy = {}'.format(song_df_clean.shape[0]))
# Out:
# Total rows in log_df_copy = 8056
# Total rows in song_df_copy = 14900

# %%
log_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8056 entries, 0 to 8055
# Data columns (total 18 columns):
# artist           6820 non-null object
# auth             8056 non-null object
# firstName        7770 non-null object
# gender           7770 non-null object
# itemInSession    8056 non-null int64
# lastName         7770 non-null object
# length           6820 non-null float64
# level            8056 non-null object
# location         7770 non-null object
# method           8056 non-null object
# page             8056 non-null object
# registration     8056 non-null int64
# sessionId        8056 non-null int64
# song             6820 non-null object
# status           8056 non-null int64
# ts               8056 non-null object
# userAgent        7770 non-null object
# userId           8056 non-null int64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 1.1+ MB

# %%
log_df_clean.head()
# Out:
#             artist       auth firstName gender  itemInSession lastName  \
# 0  The Grass Roots  Logged In      Sara      F             72  Johnson
# 1            Stars  Logged In      Sara      F             73  Johnson
# 2   Eddie Palmieri  Logged In      Sara      F             74  Johnson
# 3      The Bravery  Logged In      Sara      F             75  Johnson
# 4          K.U.K.L  Logged In      Sara      F             76  Johnson
#
#       length level           location method      page   registration  \
# 0  166.71302  paid  Winston-Salem, NC    PUT  NextSong  1540809153796
# 1  298.94485  paid  Winston-Salem, NC    PUT  NextSong  1540809153796
# 2  391.83628  paid  Winston-Salem, NC    PUT  NextSong  1540809153796
# 3  168.14975  paid  Winston-Salem, NC    PUT  NextSong  1540809153796
# 4  181.28934  paid  Winston-Salem, NC    PUT  NextSong  1540809153796
#
#    sessionId                                song  status  \
# 0        411                Let's Live For Today     200
# 1        411  Time Can Never Kill The True Heart     200
# 2        411                          Nada De Ti     200
# 3        411                             Give In     200
# 4        411                                Anna     200
#
#                         ts                                          userAgent  \
# 0  2018-11-14 00:03:22.796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 1  2018-11-14 00:06:08.796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 2  2018-11-14 00:11:06.796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 3  2018-11-14 00:17:37.796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 4  2018-11-14 00:20:25.796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
#
#    userId
# 0      95
# 1      95
# 2      95
# 3      95
# 4      95

# %%
song_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14900 entries, 0 to 14899
# Data columns (total 18 columns):
# artist_id             14900 non-null object
# artist_latitude       8245 non-null float64
# artist_location       8241 non-null object
# artist_longitude      8245 non-null float64
# artist_name           14900 non-null object
# duration              14900 non-null int64
# num_songs             14900 non-null int64
# song_id               14900 non-null object
# title                 14900 non-null object
# year                  14900 non-null int64
# _merge                6707 non-null object
# process               8247 non-null object
# corrected_location    2974 non-null object
# county                7134 non-null object
# city                  6037 non-null object
# state                 8002 non-null object
# country               8241 non-null object
# country_code          8241 non-null object
# dtypes: float64(2), int64(3), object(13)
# memory usage: 2.0+ MB

# %%
song_df_clean.head()
# Out:
#             artist_id  artist_latitude               artist_location  \
# 0  ARTH9041187FB43E1F        39.768610                St. Joseph, MO
# 1  ARQFUGM1187FB3E24E        34.053696  Los Angeles, California, USA
# 2  ARJ0AL61187B9A3F27        41.710404                       Georgia
# 3  ARJ2PMY1187FB5B563        40.851723              NY - Long Island
# 4  ARWR6RK1187FB3AB52        40.851723               Long Island, NY
#
#    artist_longitude           artist_name  duration  num_songs  \
# 0        -94.846704                Eminem       312          1
# 1       -118.242921   Black Label Society       258          1
# 2         44.031081           Katie Melua       193          1
# 3        -73.099233         Burning Spear       334          1
# 4        -73.099233  From Autumn To Ashes       147          1
#
#               song_id                              title  year _merge process  \
# 0  SOLXDDC12A6701FBFD                           I'm Back  2000    NaN       Y
# 1  SOHVHKM12A8C13F716                    Counterfeit God  2000    NaN       Y
# 2  SOFHFLK12AF72A4FB9  Mary Pickford (Used To Eat Roses)  2008    NaN       Y
# 3  SOVTFUO12A6310D813  The Invasion (Aka Black Wa Da Da)     0    NaN       Y
# 4  SOHKXAC12A58A7F6E5                                 IV  2002    NaN       Y
#
#   corrected_location               county         city         state  \
# 0     St. Joseph, MO      Buchanan County   St. Joseph      Missouri
# 1   Los Angeles, USA   Los Angeles County  Los Angeles    California
# 2            Georgia  Tsalka Municipality          NaN  Lower Kartli
# 3    NY, Long Island       Suffolk County          NaN      New York
# 4    Long Island, NY       Suffolk County          NaN      New York
#
#                     country country_code
# 0                       USA           us
# 1  United States of America           us
# 2                   Georgia           ge
# 3                       USA           us
# 4                       USA           us
