# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
import numpy as np
from sql_queries import *

# %%
import sql_queries
from importlib import reload
reload(sql_queries)
# Out:
# <module 'sql_queries' from '/home/workspace/sql_queries.py'>

# %%
print(sql_queries.song_select)
#print(artist_table_insert)
# Out:
# SELECT a.song_id, a.artist_id
# FROM songs a INNER JOIN artists b
# ON a.artist_id = b.artist_id
# WHERE a.title = %s AND b.name = %s AND a.duration = %s ;

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
'''
get_files() : Gets the filepath of all the files in the subdirectory
arg1 : filepath : Input filepath
output : returns absolute path of all the files. 
'''
# get_files : 
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
filepath= 'data/song_data'
song_files = get_files(filepath)
print("Total Files {}".format(len(song_files)))
#print(song_files)
for i, fp in enumerate(song_files):
    print("{}. {}".format(i, fp))
# Out:
# Total Files 71
# 0. /home/workspace/data/song_data/A/A/A/TRAAAAW128F429D538.json
# 1. /home/workspace/data/song_data/A/A/A/TRAAAVO128F93133D4.json
# 2. /home/workspace/data/song_data/A/A/A/TRAAADZ128F9348C2E.json
# 3. /home/workspace/data/song_data/A/A/A/TRAAAMO128F1481E7F.json
# 4. /home/workspace/data/song_data/A/A/A/TRAAAVG12903CFA543.json
# 5. /home/workspace/data/song_data/A/A/A/TRAAARJ128F9320760.json
# 6. /home/workspace/data/song_data/A/A/A/TRAAAMQ128F1460CD3.json
# 7. /home/workspace/data/song_data/A/A/A/TRAAAPK128E0786D96.json
# 8. /home/workspace/data/song_data/A/A/A/TRAAAFD128F92F423A.json
# 9. /home/workspace/data/song_data/A/A/A/TRAAAEF128F4273421.json
# 10. /home/workspace/data/song_data/A/A/A/TRAAABD128F429CF47.json
# 11. /home/workspace/data/song_data/A/A/B/TRAABCL128F4286650.json
# 12. /home/workspace/data/song_data/A/A/B/TRAABJV128F1460C49.json
# 13. /home/workspace/data/song_data/A/A/B/TRAABJL12903CDCF1A.json
# 14. /home/workspace/data/song_data/A/A/B/TRAABVM128F92CA9DC.json
# 15. /home/workspace/data/song_data/A/A/B/TRAABYN12903CFD305.json
# 16. /home/workspace/data/song_data/A/A/B/TRAABYW128F4244559.json
# 17. /home/workspace/data/song_data/A/A/B/TRAABXG128F9318EBD.json
# 18. /home/workspace/data/song_data/A/A/B/TRAABDL12903CAABBA.json
# 19. /home/workspace/data/song_data/A/A/B/TRAABLR128F423B7E3.json
# 20. /home/workspace/data/song_data/A/A/B/TRAABRB128F9306DD5.json
# 21. /home/workspace/data/song_data/A/A/B/TRAABNV128F425CEE1.json
# 22. /home/workspace/data/song_data/A/A/C/TRAACNS128F14A2DF5.json
# 23. /home/workspace/data/song_data/A/A/C/TRAACFV128F935E50B.json
# 24. /home/workspace/data/song_data/A/A/C/TRAACQT128F9331780.json
# 25. /home/workspace/data/song_data/A/A/C/TRAACCG128F92E8A55.json
# 26. /home/workspace/data/song_data/A/A/C/TRAACPE128F421C1B9.json
# 27. /home/workspace/data/song_data/A/A/C/TRAACVS128E078BE39.json
# 28. /home/workspace/data/song_data/A/A/C/TRAACER128F4290F96.json
# 29. /home/workspace/data/song_data/A/A/C/TRAACHN128F1489601.json
# 30. /home/workspace/data/song_data/A/A/C/TRAACSL128F93462F4.json
# 31. /home/workspace/data/song_data/A/A/C/TRAACZK128F4243829.json
# 32. /home/workspace/data/song_data/A/A/C/TRAACIW12903CC0F6D.json
# 33. /home/workspace/data/song_data/A/A/C/TRAACLV128F427E123.json
# 34. /home/workspace/data/song_data/A/A/C/TRAACTB12903CAAF15.json
# 35. /home/workspace/data/song_data/A/A/C/TRAACOW128F933E35F.json
# 36. /home/workspace/data/song_data/A/B/A/TRABAFP128F931E9A1.json
# 37. /home/workspace/data/song_data/A/B/A/TRABAXV128F92F6AE3.json
# 38. /home/workspace/data/song_data/A/B/A/TRABAFJ128F42AF24E.json
# 39. /home/workspace/data/song_data/A/B/A/TRABAXR128F426515F.json
# 40. /home/workspace/data/song_data/A/B/A/TRABAVQ12903CBF7E0.json
# 41. /home/workspace/data/song_data/A/B/A/TRABAXL128F424FC50.json
# 42. /home/workspace/data/song_data/A/B/A/TRABAZH128F930419A.json
# 43. /home/workspace/data/song_data/A/B/A/TRABAWW128F4250A31.json
# 44. /home/workspace/data/song_data/A/B/A/TRABACN128F425B784.json
# 45. /home/workspace/data/song_data/A/B/A/TRABATO128F42627E9.json
# 46. /home/workspace/data/song_data/A/B/A/TRABAIO128F42938F9.json
# 47. /home/workspace/data/song_data/A/B/B/TRABBJE12903CDB442.json
# 48. /home/workspace/data/song_data/A/B/B/TRABBXU128F92FEF48.json
# 49. /home/workspace/data/song_data/A/B/B/TRABBZN12903CD9297.json
# 50. /home/workspace/data/song_data/A/B/B/TRABBVJ128F92F7EAA.json
# 51. /home/workspace/data/song_data/A/B/B/TRABBOP128F931B50D.json
# 52. /home/workspace/data/song_data/A/B/B/TRABBTA128F933D304.json
# 53. /home/workspace/data/song_data/A/B/B/TRABBKX128F4285205.json
# 54. /home/workspace/data/song_data/A/B/B/TRABBNP128F932546F.json
# 55. /home/workspace/data/song_data/A/B/B/TRABBAM128F429D223.json
# 56. /home/workspace/data/song_data/A/B/B/TRABBLU128F93349CF.json
# 57. /home/workspace/data/song_data/A/B/B/TRABBOR128F4286200.json
# 58. /home/workspace/data/song_data/A/B/B/TRABBBV128F42967D7.json
# 59. /home/workspace/data/song_data/A/B/C/TRABCKL128F423A778.json
# 60. /home/workspace/data/song_data/A/B/C/TRABCEI128F424C983.json
# 61. /home/workspace/data/song_data/A/B/C/TRABCTK128F934B224.json
# 62. /home/workspace/data/song_data/A/B/C/TRABCFL128F149BB0D.json
# 63. /home/workspace/data/song_data/A/B/C/TRABCEC128F426456E.json
# 64. /home/workspace/data/song_data/A/B/C/TRABCRU128F423F449.json
# 65. /home/workspace/data/song_data/A/B/C/TRABCYE128F934CE1D.json
# 66. /home/workspace/data/song_data/A/B/C/TRABCUQ128E0783E2B.json
# 67. /home/workspace/data/song_data/A/B/C/TRABCIX128F4265903.json
# 68. /home/workspace/data/song_data/A/B/C/TRABCPZ128F4275C32.json
# 69. /home/workspace/data/song_data/A/B/C/TRABCXB128F4286BD3.json
# 70. /home/workspace/data/song_data/A/B/C/TRABCAJ12903CDFCC2.json

# %%
print("File {}".format(song_files[0]))
df = pd.read_json(song_files[0], lines=True)
print("df shape {}".format(df.shape))
df.head()

df.info()
# Out:
# File /home/workspace/data/song_data/A/A/A/TRAAAAW128F429D538.json
# df shape (1, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 10 columns):
# artist_id           1 non-null object
# artist_latitude     0 non-null float64
# artist_location     1 non-null object
# artist_longitude    0 non-null float64
# artist_name         1 non-null object
# duration            1 non-null float64
# num_songs           1 non-null int64
# song_id             1 non-null object
# title               1 non-null object
# year                1 non-null int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 160.0+ bytes

# %%
df[df.isnull().any(1)]
# Out:
#             artist_id  artist_latitude  artist_location  artist_longitude  \
# 0  ARD7TVE1187B99BFB1              NaN  California - LA               NaN
#
#   artist_name   duration  num_songs             song_id             title  \
# 0      Casual  218.93179          1  SOMZWCG12A8C13C480  I Didn't Mean To
#
#    year
# 0     0

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = df[['song_id', 'title', 'artist_id', 'year', 'duration']].values[0]
song_data
# Out:
# array(['SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0,
#        218.93179], dtype=object)

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
try:    
    cur.execute(song_table_insert, song_data)
    conn.commit()
except Exception as e:
    conn.rollback()
    print("{} : Error Message : {}".format('Rolled back', e))

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
df[['artist_id', 'artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']]
# Out:
#             artist_id artist_name  artist_location  artist_latitude  \
# 0  ARD7TVE1187B99BFB1      Casual  California - LA              NaN
#
#    artist_longitude
# 0               NaN

# %%
# Had a bit of concern of dataFrame column names are different than table column names, it doesn't matter it seems. Thats good news.
artist_data = df[['artist_id', 'artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']].values[0]
artist_data
# Out:
# array(['ARD7TVE1187B99BFB1', 'Casual', 'California - LA', nan, nan], dtype=object)

# %%
df.head()
# Out:
#             artist_id  artist_latitude  artist_location  artist_longitude  \
# 0  ARD7TVE1187B99BFB1              NaN  California - LA               NaN
#
#   artist_name   duration  num_songs             song_id             title  \
# 0      Casual  218.93179          1  SOMZWCG12A8C13C480  I Didn't Mean To
#
#    year
# 0     0

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
try:    
    cur.execute(artist_table_insert, artist_data)
    conn.commit()
except Exception as e:
    conn.rollback()
    print("{} : Error Message : {}".format('Rolled back', e))

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
filepath= 'data/log_data'
log_files = get_files(filepath)
print("Total Files {}".format(len(log_files)))
for i, fp in enumerate(log_files):
    print("{}. {}".format(i, fp))
# Out:
# Total Files 30
# 0. /home/workspace/data/log_data/2018/11/2018-11-14-events.json
# 1. /home/workspace/data/log_data/2018/11/2018-11-28-events.json
# 2. /home/workspace/data/log_data/2018/11/2018-11-30-events.json
# 3. /home/workspace/data/log_data/2018/11/2018-11-05-events.json
# 4. /home/workspace/data/log_data/2018/11/2018-11-01-events.json
# 5. /home/workspace/data/log_data/2018/11/2018-11-12-events.json
# 6. /home/workspace/data/log_data/2018/11/2018-11-09-events.json
# 7. /home/workspace/data/log_data/2018/11/2018-11-20-events.json
# 8. /home/workspace/data/log_data/2018/11/2018-11-08-events.json
# 9. /home/workspace/data/log_data/2018/11/2018-11-04-events.json
# 10. /home/workspace/data/log_data/2018/11/2018-11-11-events.json
# 11. /home/workspace/data/log_data/2018/11/2018-11-10-events.json
# 12. /home/workspace/data/log_data/2018/11/2018-11-27-events.json
# 13. /home/workspace/data/log_data/2018/11/2018-11-07-events.json
# 14. /home/workspace/data/log_data/2018/11/2018-11-03-events.json
# 15. /home/workspace/data/log_data/2018/11/2018-11-19-events.json
# 16. /home/workspace/data/log_data/2018/11/2018-11-16-events.json
# 17. /home/workspace/data/log_data/2018/11/2018-11-15-events.json
# 18. /home/workspace/data/log_data/2018/11/2018-11-13-events.json
# 19. /home/workspace/data/log_data/2018/11/2018-11-29-events.json
# 20. /home/workspace/data/log_data/2018/11/2018-11-18-events.json
# 21. /home/workspace/data/log_data/2018/11/2018-11-26-events.json
# 22. /home/workspace/data/log_data/2018/11/2018-11-24-events.json
# 23. /home/workspace/data/log_data/2018/11/2018-11-21-events.json
# 24. /home/workspace/data/log_data/2018/11/2018-11-02-events.json
# 25. /home/workspace/data/log_data/2018/11/2018-11-25-events.json
# 26. /home/workspace/data/log_data/2018/11/2018-11-23-events.json
# 27. /home/workspace/data/log_data/2018/11/2018-11-17-events.json
# 28. /home/workspace/data/log_data/2018/11/2018-11-22-events.json
# 29. /home/workspace/data/log_data/2018/11/2018-11-06-events.json

# %%
df = pd.read_json(log_files[0], lines=True)
print("df shape {}".format(df.shape))
df.head(3)
#df.info()
# Out:
# df shape (457, 18)
#             artist       auth firstName gender  itemInSession lastName  \
# 0  The Grass Roots  Logged In      Sara      F             72  Johnson
# 1            Stars  Logged In      Sara      F             73  Johnson
# 2   Eddie Palmieri  Logged In      Sara      F             74  Johnson
#
#       length level           location method      page  registration  \
# 0  166.71302  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
# 1  298.94485  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
# 2  391.83628  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
#
#    sessionId                                song  status             ts  \
# 0        411                Let's Live For Today     200  1542153802796
# 1        411  Time Can Never Kill The True Heart     200  1542153968796
# 2        411                          Nada De Ti     200  1542154266796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95
# 1  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95
# 2  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95

# %%
#convert timestamp(milli) to timestamp(normal)
df['ts'] = pd.to_datetime(df['ts'], unit='ms')

# %%
df[df.userId == '80']
df[(df.userId == '80') & (df.itemInSession == 0)]
# Out:
#          artist       auth firstName gender  itemInSession lastName  \
# 19   John Mayer  Logged In     Tegan      F              0   Levine
# 333  Wolfmother  Logged In     Tegan      F              0   Levine
#
#         length level                     location method      page  \
# 19   201.16853  paid  Portland-South Portland, ME    PUT  NextSong
# 333  280.86812  paid  Portland-South Portland, ME    PUT  NextSong
#
#      registration  sessionId                            song  status  \
# 19   1.540794e+12        548  Waiting On The World To Change     200
# 333  1.540794e+12        574             Joker And The Thief     200
#
#                          ts  \
# 19  2018-11-14 02:57:45.796
# 333 2018-11-14 15:13:13.796
#
#                                              userAgent userId
# 19   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 333  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
dfNS = df[df.page == 'NextSong']
df.shape
#df.head()
# Out:
# (457, 18)

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html
# Googled series.dt and got the below link
# This helped https://pandas.pydata.org/pandas-docs/stable/reference/series.html#time-series-related
# Search for Datetime properties
t = dfNS.copy()
t['ts'] = pd.to_datetime(t['ts'], unit='ms')
#t = t[:1] #Test with 1 row
t.head()
print(t.shape)
print(t.ts[0], t.ts.dt.hour[0], t.ts.dt.day[0] , t.ts.dt.dayofweek[0] , t.ts.dt.month[0], t.ts.dt.year[0] , t.ts.dt.weekday[0])
# Out:
# (390, 18)
# 2018-11-14 00:03:22.796000 0 14 2 11 2018 2

# %%
time_data = [t.ts, t.ts.dt.hour, t.ts.dt.day, t.ts.dt.week, t.ts.dt.month, t.ts.dt.year, t.ts.dt.weekday]
#time_data = [t.ts[0], t.ts.dt.hour[0], t.ts.dt.day[0] , t.ts.dt.dayofweek[0] , t.ts.dt.month[0], t.ts.dt.year[0] , t.ts.dt.weekday[0]]
column_labels = ['start_time', 'hour', 'day', 'week', 'month', 'year', 'weekday']

# %%
a = zip(column_labels, time_data)
a = list(a)
#print(a)
a = dict(zip(column_labels, time_data))
#print(a)

# %%
time_df = pd.DataFrame.from_dict(dict(zip(column_labels, time_data)))
time_df.head()
# Out:
#                start_time  hour  day  week  month  year  weekday
# 0 2018-11-14 00:03:22.796     0   14    46     11  2018        2
# 1 2018-11-14 00:06:08.796     0   14    46     11  2018        2
# 2 2018-11-14 00:11:06.796     0   14    46     11  2018        2
# 3 2018-11-14 00:17:37.796     0   14    46     11  2018        2
# 4 2018-11-14 00:20:25.796     0   14    46     11  2018        2

# %%
# Iterate each cell in a column
#for index, row in time_df['hour'].iteritems():
#    print(row)

# %%
# Iterate each rows
#for index, row in time_df.iterrows():
#    print(row['hour'], row['weekday'])

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
try:        
    for i, row in time_df.iterrows():
        cur.execute(time_table_insert, list(row))
        conn.commit()    
except Exception as e:
    conn.rollback()
    print("{} : Error Message : {}".format('Rolled back', e))

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[['userId', 'firstName', 'lastName', 'gender', 'level', 'ts']]
user_df.head()
user_df[user_df.userId == '80'].head(20)
# Out:
#    userId firstName lastName gender level                      ts
# 19     80     Tegan   Levine      F  paid 2018-11-14 02:57:45.796
# 20     80     Tegan   Levine      F  paid 2018-11-14 03:01:06.796
# 21     80     Tegan   Levine      F  paid 2018-11-14 03:03:08.796
# 22     80     Tegan   Levine      F  paid 2018-11-14 03:06:36.796
# 23     80     Tegan   Levine      F  paid 2018-11-14 03:09:36.796
# 24     80     Tegan   Levine      F  paid 2018-11-14 03:12:32.796
# 25     80     Tegan   Levine      F  paid 2018-11-14 03:13:19.796
# 26     80     Tegan   Levine      F  paid 2018-11-14 03:17:50.796
# 27     80     Tegan   Levine      F  paid 2018-11-14 03:21:57.796
# 28     80     Tegan   Levine      F  paid 2018-11-14 03:26:35.796
# 29     80     Tegan   Levine      F  paid 2018-11-14 03:30:46.796
# 30     80     Tegan   Levine      F  paid 2018-11-14 03:34:26.796
# 31     80     Tegan   Levine      F  paid 2018-11-14 03:37:52.796
# 32     80     Tegan   Levine      F  paid 2018-11-14 03:42:55.796
# 33     80     Tegan   Levine      F  paid 2018-11-14 03:46:36.796
# 36     80     Tegan   Levine      F  paid 2018-11-14 03:53:11.796
# 37     80     Tegan   Levine      F  paid 2018-11-14 03:57:48.796
# 38     80     Tegan   Levine      F  paid 2018-11-14 04:05:55.796
# 39     80     Tegan   Levine      F  paid 2018-11-14 04:08:42.796
# 40     80     Tegan   Levine      F  paid 2018-11-14 04:13:01.796

# %%
user_df[(user_df.userId == '80') & (user_df.level == 'free')].sort_values(by=['userId', 'ts']).head()
# Out:
# Empty DataFrame
# Columns: [userId, firstName, lastName, gender, level, ts]
# Index: []

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %% [markdown]
# #### Cleaning user_df

# %%
df_uc = user_df.copy()
print('All = ',df_uc.shape)
print('Null = ',df_uc[df_uc.firstName.isnull()].shape)
print('Not null = ',df_uc[df_uc.firstName.notnull()].shape)
# Out:
# All =  (457, 6)
# Null =  (12, 6)
# Not null =  (445, 6)

# %%
# Shows rows where any cell has null values.
#df_uc[df_uc.firstName.isnull()]
print(df_uc[df_uc.isnull().any(1)])
# Out:
#     userId firstName lastName gender level                      ts
# 78              None     None   None  free 2018-11-14 05:55:03.796
# 79              None     None   None  free 2018-11-14 05:55:41.796
# 80              None     None   None  free 2018-11-14 05:55:42.796
# 286             None     None   None  paid 2018-11-14 12:09:01.796
# 287             None     None   None  paid 2018-11-14 12:09:02.796
# 330             None     None   None  paid 2018-11-14 13:40:39.796
# 345             None     None   None  free 2018-11-14 15:27:30.796
# 359             None     None   None  free 2018-11-14 15:48:07.796
# 360             None     None   None  free 2018-11-14 15:48:19.796
# 425             None     None   None  paid 2018-11-14 19:38:09.796
# 426             None     None   None  paid 2018-11-14 19:38:34.796
# 427             None     None   None  paid 2018-11-14 19:38:50.796

# %%
# Assessment user_df : userId
# 12 Rows having userId column value as ''. So changing that to None datatype
print(df_uc.loc[78])
print(type(None))
print('Sample Nonetype = ',type(df_uc.loc[78,'firstName']))
print('Empty String = ',type(df_uc.loc[78,'userId']))
# Out:
# userId
# firstName                          None
# lastName                           None
# gender                             None
# level                              free
# ts           2018-11-14 05:55:03.796000
# Name: 78, dtype: object
# <class 'NoneType'>
# Sample Nonetype =  <class 'NoneType'>
# Empty String =  <class 'str'>

# %%
# Cleaning user_df : userId
df_uc = user_df.copy()
cnt=0
nullList = []
for row in df_uc['userId']:
    try:
        #print(cnt, df_uc.loc[cnt, 'userId'])
        if df_uc.loc[cnt, 'userId'] == '':
            nullList.append(cnt)
            #print(cnt)
            df_uc.loc[cnt, 'userId'] = None
    except ValueError:
        pass
    cnt+=1

#df_uc.loc[78, 'userId']
print('Null list = {}'.format(nullList))
print(df_uc[df_uc.userId.isnull()])

#df_uc[df_uc.firstName.isnull()].head()

#Need to clean up these null rows
# Out:
# Null list = [78, 79, 80, 286, 287, 330, 345, 359, 360, 425, 426, 427]
#     userId firstName lastName gender level                      ts
# 78    None      None     None   None  free 2018-11-14 05:55:03.796
# 79    None      None     None   None  free 2018-11-14 05:55:41.796
# 80    None      None     None   None  free 2018-11-14 05:55:42.796
# 286   None      None     None   None  paid 2018-11-14 12:09:01.796
# 287   None      None     None   None  paid 2018-11-14 12:09:02.796
# 330   None      None     None   None  paid 2018-11-14 13:40:39.796
# 345   None      None     None   None  free 2018-11-14 15:27:30.796
# 359   None      None     None   None  free 2018-11-14 15:48:07.796
# 360   None      None     None   None  free 2018-11-14 15:48:19.796
# 425   None      None     None   None  paid 2018-11-14 19:38:09.796
# 426   None      None     None   None  paid 2018-11-14 19:38:34.796
# 427   None      None     None   None  paid 2018-11-14 19:38:50.796

# %%
print('All = ',df_uc.shape)
df_uc = df_uc[df_uc.firstName.notnull()]
print('Not Null = ',df_uc.shape)
user_df = df_uc.copy()
# Out:
# All =  (457, 6)
# Not Null =  (445, 6)

# %%
user_df.head()
# Out:
#   userId firstName lastName gender level                      ts
# 0     95      Sara  Johnson      F  paid 2018-11-14 00:03:22.796
# 1     95      Sara  Johnson      F  paid 2018-11-14 00:06:08.796
# 2     95      Sara  Johnson      F  paid 2018-11-14 00:11:06.796
# 3     95      Sara  Johnson      F  paid 2018-11-14 00:17:37.796
# 4     95      Sara  Johnson      F  paid 2018-11-14 00:20:25.796

# %%
#for i, row in df_uc.iterrows():
try:
    for i, row in user_df.iterrows():
        cur.execute(user_table_insert, row)
        conn.commit()
except Exception as e:
    conn.rollback()
    print("{} : Error Message : {}".format('Rolled back', e))

# %%
# Delete null rows
try:        
    cur.execute("delete from users a where a.user_id is null;")
    print(cur.rowcount)
except Exception as e:
    conn.rollback()
    print("{} : Error Message : {}".format('Rolled back', e))
# Out:
# 0

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
df.shape
# Out:
# (457, 18)

# %%
df.head(1)
# Out:
#             artist       auth firstName gender  itemInSession lastName  \
# 0  The Grass Roots  Logged In      Sara      F             72  Johnson
#
#       length level           location method      page  registration  \
# 0  166.71302  paid  Winston-Salem, NC    PUT  NextSong  1.540809e+12
#
#    sessionId                  song  status                      ts  \
# 0        411  Let's Live For Today     200 2018-11-14 00:03:22.796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...     95

# %%
print(song_select)
# Out:
# SELECT a.song_id, a.artist_id
# FROM songs a INNER JOIN artists b
# ON a.artist_id = b.artist_id
# WHERE a.title = %s AND b.name = %s AND a.duration = %s ;

# %%
#only clue here is 'df' thats log_data. Its a bit frustrating when its not said what to do. Time burn.
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    a = sql_queries.song_select    
    cur.execute(a, (row.song, row.artist, row.length))
    results = cur.fetchone()

    print(results, (row.song, row.artist, row.length))
    
    if results:
        songid, artistid = results
    else:
#        continue
        songid, artistid = None, None

    '''
        print(songid)
        if type(songid) == type(None): 
            status = 'Skip'
        else:
            status = 'Insert'

        if type(songid) == type(None): 
            continue
    '''                
        
    #print("{} : {} : songid({}) song({}), artist({}), length({})".format(status, type(songid), songid, row.song, row.artist, row.length))        
    starttime = pd.to_datetime(row.ts,unit='ms')
        
    # insert songplay record
    # insert into songplay (songplay_id, start_time, user_id, level, song_id, artist_id, session_id, location, user_agent) 
    songplay_data = (starttime, row.userId, row.level, songid, artistid, row.sessionId, row.location, row.userAgent
                     , row.itemInSession, row.song, row.artist)
    try:
        cur.execute(songplay_table_insert, songplay_data)
        conn.commit()
    except Exception as e:
        conn.rollback()
        print("{} : Error Message : {}".format('Rolled back', e))
# Out:
# None ("Let's Live For Today", 'The Grass Roots', 166.71302)
# None ('Time Can Never Kill The True Heart', 'Stars', 298.94485)
# None ('Nada De Ti', 'Eddie Palmieri', 391.83628)
# None ('Give In', 'The Bravery', 168.14975)
# None ('Anna', 'K.U.K.L', 181.28934)
# None ('Syndicate', 'The Fray', 209.97179)
# None ('Roll Over Beethoven', 'Chuck Berry', 147.06893)
# None ('Kings Of The Carnival Creation', 'Dimmu Borgir', 468.47955)
# None ("Ain't No Doubt", 'Jimmy Nail', 245.65506)
# None ('Pork And Beans', 'Weezer', 189.43955)
# None (None, None, nan)
# None ("Beggin'", 'Madcon', 215.92771)
# None ('Teach Me Tonight', 'Joe Williams / Count Basie', 184.94649)
# None ('Piano Concerto No. 2 in G minor Op. 22 (2006 Digital Remaster): III.  Presto', 'Emil Gilels/Orchestre de la SociÃ\x83Â©tÃ\x83Â© des Concerts du Conservatoire/AndrÃ\x83Â© Cluytens', 375.19628)
# None ('Sunday Morning', 'Modwheelmood', 209.71057)
# None (None, None, nan)
# None (None, None, nan)
# None (None, None, nan)
# None (None, None, nan)
# None ('Waiting On The World To Change', 'John Mayer', 201.16853)
# None ('Two Time Mama (2004 Digital Remaster)', 'Ten Years After', 122.3571)
# None ('Six Days On The Road (Album Version)', 'Mudcrutch', 208.03873)
# None ('Ni TÃ\x83Âº Ni Nadie (VersiÃ\x83Â³n Demo)', 'Alaska Y Dinarama', 180.37506)
# None ('Liar', 'Kicking K8', 176.48281)
# None ('The Shining', 'Badly Drawn Boy', 318.51057)
# None (None, None, nan)
# None ('Pain Redefined (Album Version)', 'Disturbed', 247.09179)
# None ('Armistice', 'Phoenix', 278.80444)
# None ('The Hunger Stays', 'Margaret Becker', 251.84608)
# None ('Teeth', 'Lady GaGa', 220.65587)
# None ('Trouble Sleeping', 'Corinne Bailey Rae', 206.18404)
# None ('Miss It So Much', 'Royksopp', 303.62077)
# None ('Enter Sandman', 'Apocalyptica', 221.07383)
# None ('OMG', 'Usher featuring will.i.am', 395.72853)
# None (None, None, nan)
# None ('Read My Mind', 'The Killers', 246.80444)
# None ('Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 277.15873)
# None ('Public Pervert', 'Interpol', 487.67955)
# None ("What's It To You (Album Version)", 'Clay Walker', 167.99302)
# None ('One More Road To Cross', 'DMX', 259.65669)
# None ("Baker's Blue Jay Yarn", 'Dakota Oak', 45.63546)
# None ('Yellow', 'Coldplay', 268.30322)
# None ('Faxing Berlin', 'Deadmau5', 521.19465)
# None ("It Wasn't Me", 'Shaggy / Ricardo Ducent', 226.76853)
# None ('Talk About The Passion', 'R.E.M.', 202.4224)
# None ('Quality Of Mercy', 'Michelle Shocked', 217.83465)
# None ('Better To Reign In Hell', 'Cradle Of Filth', 371.66975)
# None ('Scorchio', 'Bond', 210.9122)
# None (None, None, nan)
# None ('Cuida Eso', 'Vieja Trova Santiaguera', 222.58893)
# None ('S.O.S.', 'Jonas Brothers', 153.46893)
# None ('Get Down Tonight (Miami Mix)', 'KC And The Sunshine Band', 301.03465)
# None ('Te lo agradezco_ pero no', 'Alejandro Sanz', 277.44608)
# None ('The Truth (Sick Of It All Cover Version)', 'Bleeding Through', 171.67628)
# None ('Criminal', 'Eminem', 323.49995)
# None ('You Wanted It (Album Version)', 'MoZella', 203.41506)
# None (None, None, nan)
# None ("At the Ball_ That's All", 'Laurel & Hardy', 123.71546)
# None ('The Mixed Tape (Album Version)', "Jack's Mannequin", 194.89914)
# None ('Intro', 'Percubaba', 124.78649)
# None ('Take The Devil (LP Version)', 'Eagles', 241.78893)
# None ('A Man/Me/Then Jim (Album Version)', 'Rilo Kiley', 322.42893)
# None ('Audience Of One', 'Rise Against', 245.96853)
# None ('Sworn To The Dark', 'Watain', 303.25506)
# None ('Scotch & Chocolate', 'Nickel Creek', 187.55873)
# None ('Como Duele (Album)', 'Ricardo Arjona', 210.25914)
# None ('The last to know', 'Sherwood', 122.77506)
# None (None, None, nan)
# None (None, None, nan)
# None ('Steel Rail Blues', 'Gordon Lightfoot', 172.61669)
# None ('Fader', 'The Temper Trap', 192.67873)
# None ('South Side', 'Moby', 228.25751)
# None ('How Do You Like Me Now?!', 'Toby Keith', 207.46404)
# None ('Me Demoro (vivo)', 'Joe Vasconcellos', 255.92118)
# None ('Next To You   (Explicit Album Version)', 'Mike Jones', 222.58893)
# None ('In You', 'MercyME', 257.51465)
# None (None, None, nan)
# None (None, None, nan)
# None (None, None, nan)
# Rolled back : Error Message : invalid input syntax for integer: ""
# LINE 3: values('2018-11-14T05:55:03.796000'::timestamp, '', 'free', ...
#                                                         ^
#
# None (None, None, nan)
# Rolled back : Error Message : invalid input syntax for integer: ""
# LINE 3: values('2018-11-14T05:55:41.796000'::timestamp, '', 'free', ...
#                                                         ^
#
# None (None, None, nan)
# Rolled back : Error Message : invalid input syntax for integer: ""
# LINE 3: values('2018-11-14T05:55:42.796000'::timestamp, '', 'free', ...
#                                                         ^
#
# None ('Just Stop (Album Version)', 'Disturbed', 223.45098)
# None (None, None, nan)
# None ('aNYway', 'Armand Van Helden & A-TRAK Present Duck Sauce', 325.0673)
# None ('Crying Shame', 'Jack Johnson', 185.99138)
# None ('Creil City', 'Alliance Ethnik', 265.76934)
# None ('Higinia (Album Version)', 'blessthefall', 166.45179)
# None ('Gotta Get Some', 'The Spades', 84.84526)
# None ('Rain', 'Subhumans', 209.37098)
# None ('This Is Goodbye (Album Version)', 'Killswitch Engage', 257.20118)
# None ('Persephone', 'Wishbone Ash', 221.54404)
# None ('Tive Sim', 'Cartola', 127.242)
# None ('Samba De Una Nota SoÃ\x82Â´', 'Joa~o Gilberto', 98.14159)
# None ('On A Deeper Level', 'Blufeld', 396.93016)
# None (None, None, nan)
# None ('(They Long To Be) Close To You', 'Carpenters', 276.06159)
# None ('Brother', 'Komeda', 261.72036)
# None ('Fuego', 'Bond', 181.68118)
# None (None, None, nan)
# None ('Johnny B.', 'The Hooters', 240.43057)
# None (None, None, nan)
# None ('Halo', 'BeyoncÃ\x83Â©', 261.74649)
# None (None, None, nan)
# None ('Thank You', 'Dido', 217.83465)
# None ('Beer And Bones', 'John Michael Montgomery', 217.0771)
# None ('Music Is The Key', 'Sarah Connor / Naturally 7', 277.10649)
# None (None, None, nan)
# None ('Con La Mano LevantÃ\x83Â¡', 'Macaco', 202.4224)
# None ('This Fire', 'Franz Ferdinand', 254.69342)
# None ('American Idiot [feat. Green Day & The Cast Of American Idiot] (Album Version)', 'Green Day', 185.12934)
# None ('Everybody Loves Me', 'OneRepublic', 218.95791)
# None ('Doctor Jones', 'Aqua', 201.92608)
# None ("Kyle's World", 'Craig Chaquico', 279.64036)
# None ("I'd Rather Be With You", 'Joshua Radin', 169.32526)
# None ('K.C. Moan', 'Memphis Jug Band', 150.80444)
# None ('A Boy Brushed Red Living In Black And White', 'Underoath', 268.042)
# None ('Time Signals Progress', 'Roses Are Red', 258.82077)
# None ("D'Evils", 'Jay-Z', 212.27057)
# None ('The Beautiful People', 'Marilyn Manson', 218.8273)
# None ('Tim McGraw', 'Taylor Swift', 232.09751)
# None ("Fingers And Thumbs (Cold Summer's Day) (Sound Factory Remix)", 'Erasure', 584.25424)
# None ('Hot Boyz (w/ Dear Nora)', 'Casiotone For The Painfully Alone', 210.12853)
# None ('Breathless', 'The Corrs', 205.94893)
# None ('Big City Lights (Album Version)', 'Black Stone Cherry', 261.79873)
# None ('Naive', 'The Kooks', 203.96363)
# None ('Marry Song (Album)', 'Band Of Horses', 203.25832)
# None ('Gift From Virgo', 'BeyoncÃ\x83Â©', 163.70893)
# None ('Gold Guns Girls', 'Metric', 245.52444)
# None ('Hoedown Throwdown', 'Miley Cyrus', 180.84526)
# None (None, None, nan)
# None ('Violent', 'Stars', 225.82812)
# None ("Wavin'  Flag", "K'Naan", 220.49914)
# None ('When The Stars Go Blue (Featuring Bono) (Disclab Remix)', 'The Corrs', 238.44526)
# None ('Evolution Of Man', 'Binary Star', 362.84036)
# None ('Dog Days Are Over (Radio Edit)', 'Florence + The Machine', 219.66322)
# None ('Heavyweight Champion Of The World', 'Reverend And The Makers', 209.81506)
# None ('Mama Loo', 'Les Humphries Singers', 222.79791)
# None ('Missing You', 'John Waite', 269.76608)
# None ('Familiar Realm', 'CKY', 240.27383)
# None ('When The Sun Comes Down', 'R.I.O.', 217.12934)
# None ('Halo', 'BeyoncÃ\x83Â©', 261.74649)
# None ('Electro Movimiento', 'Calle 13', 196.98893)
# None ('Coda', 'Chris Bathgate', 324.98893)
# None ('So Insane', 'Discovery', 192.522)
# None (None, None, nan)
# None ('Better Than Love', 'Griffin House', 226.42893)
# None ('The Maestro', 'Beastie Boys', 172.22485)
# None (None, None, nan)
# None ('Never Give You Up', 'Raphael Saadiq featuring Stevie Wonder and CJ', 252.94322)
# None ('Keep On Walking', 'Dead Meadow', 181.41995)
# None ('Found Home', '59 Times the Pain', 144.95302)
# None (None, None, nan)
# None ('1865 (96Ã\x82Âº In The Shade)', 'Third World', 268.79955)
# None ('Dead Souls (LP Version)', 'Nine Inch Nails', 293.69424)
# None ("Livin' On A Prayer", 'Bon Jovi', 250.69669)
# None ('Pursuit Of Happiness (nightmare)', 'Kid Cudi / MGMT / Ratatat', 295.67955)
# None ('Onde Estara O Meu Amor', 'Maria BethÃ\x83Â¢nia', 212.34893)
# None ('Come Back to Me', 'David Cook', 248.00608)
# None ('American Idiot [feat. Green Day & The Cast Of American Idiot] (Album Version)', 'Green Day', 185.12934)
# None ('1234', 'Feist', 183.58812)
# None ('The Lost Song', 'The Cat Empire', 200.35873)
# None ('The Gift', 'Angels and Airwaves', 302.05342)
# None ('Intermission 1', 'Brisa RochÃ\x83Â©', 48.19546)
# None ('Sailed Away', 'Saving Abel', 258.42893)
# None ('Hand Me Down', 'Mystery Jets', 245.02812)
# None (None, None, nan)
# None ('The Real Slim Shady', 'Eminem', 284.18567)
# None ('To Be Gone', 'Anna Ternheim', 166.86975)
# None ('Close To Heaven (Album Version)', 'Color Me Badd', 259.63057)
# None (None, None, nan)
# None (None, None, nan)
# None ('The Middle', 'Jimmy Eat World', 166.00771)
# None (None, None, nan)
# None ('We Care', 'Reel Big Fish', 289.61914)
# None ('Dub So', 'The Upsetters', 231.44444)
# None ('Piggy Pie (Old School)', 'Insane Clown Posse', 262.89587)
# None ('Reptilia', 'The Strokes', 218.56608)
# None ('Good Times', 'Yazoo', 269.16526)
# None ('Of Dust And Nations', 'Thrice', 291.76118)
# None ("Le Jardin d'Hiver", 'Jacky Terrasson', 342.7522)
# None ('Never Say Never', 'Armin van Buuren', 452.23138)
# None ('Silent Night/Away In A Manger (Album Version)', 'Relient K', 138.81424)
# None ('Spell', 'Nick Cave & The Bad Seeds', 265.27302)
# None ('9 Mai', 'Akcent', 235.44118)
# None ('Hey! Hey! Hey!', 'Riverboat Gamblers', 122.04363)
# None ('Continue?', 'Ikonika', 157.25669)
# None ('Thousand Ways', 'The Tallest Man On Earth', 175.43791)
# None ('Bodies', 'Drowning Pool', 201.63873)
# None (None, None, nan)
# None ('What Goes Around...Comes Around', 'Justin Timberlake', 313.0771)
# None ('Magic', 'The Pussycat Dolls', 221.3873)
# None ("It's The Same Old Song", 'KC And The Sunshine Band', 262.1122)
# None ('Today', 'Gary Allan', 237.53098)
# None ('Suffering', 'Rebelution', 244.55791)
# None ('Something (Album Version)', 'Jaci Velasquez', 200.95955)
# None ('Nobody Does It Better', 'Nate Dogg feat.  Warren G', 271.59465)
# None ('Crank That (Soulja Boy)', "Soulja Boy Tell'em", 224.91383)
# None ('Roll Over Beethoven', 'Chuck Berry', 147.06893)
# None ('Lamb on the Lam (In the City) (Album)', 'Band Of Horses', 50.59873)
# None ("You're The One", 'Dwight Yoakam', 239.3073)
# None ('Inches And Falling (I Love_ Love) (Live)', 'The Format', 225.802)
# None (None, None, nan)
# None ('I Wish I Knew Natalie Portman', 'K-OS', 189.64853)
# None ('Me & Mr Jones', 'Amy Winehouse', 151.562)
# None ('Sehr kosmisch', 'Harmonia', 655.77751)
# None ('With A Gun', 'Steely Dan', 138.84036)
# None ('The Game Of Love', 'Katrina & The Waves', 199.73179)
# None ('Love The Way You Love Me', 'The Pussycat Dolls', 200.9073)
# None ("I'll Breathe For You", 'Decyfer Down', 214.17751)
# None ('Girlfriend', 'Bow Wow & Omarion', 284.83873)
# None (None, None, nan)
# None ("All Tomorrow's Parties", 'The Velvet Underground / Nico', 360.09751)
# None (None, None, nan)
# None ('A Dustland Fairytale', 'The Killers', 225.12281)
# None ('Medley Jacob', "Kassav'", 446.74567)
# None (None, None, nan)
# None ('Coffee Girl', 'The Tragically Hip', 226.16771)
# None ('Everybody Knows', 'Ryan Adams', 145.08363)
# None ('Hoy Estoy Raro', 'El Cuarteto De Nos', 280.2673)
# None ('Over And Out', 'Foo Fighters', 316.18567)
# None ("Paintin' The Town (Album Version)", 'Phil Keaggy', 376.0322)
# None ('Bound For The Floor', 'Local H', 223.00689)
# None ('Jump Start', 'David Benoit', 288.96608)
# None ('Damaged Goods', 'Gang Of Four', 207.25506)
# None (None, None, nan)
# None ('Alright', 'Darius Rucker', 230.39955)
# None ('Coda', 'Chris Bathgate', 324.98893)
# None ("It'll Be a Long Time (Album Version)", 'The Offspring', 163.3171)
# None ('McFearless', 'Kings Of Leon', 189.1522)
# None ('Kaili', 'Caribou', 282.33098)
# None ('Closer', 'Nine Inch Nails', 373.2371)
# None ('Rising Moon', 'ATB', 191.7122)
# None ('Yellow', 'Coldplay', 268.38159)
# None ("Ain't No Rest For The Wicked (Original Version)", 'Cage The Elephant', 175.12444)
# None ('Bubble Toes', 'Jack Johnson', 236.93016)
# None ('Golden Skans', 'Klaxons', 166.79138)
# None ('Feel It', 'Three 6 Mafia vs. TiÃ\x83Â«sto with Sean Kingston and Flo Rida', 241.05751)
# None ('Cudi Zone', 'Kid Cudi', 259.00363)
# None ("Don't Stop The Music", 'Rihanna', 269.37424)
# None (None, None, nan)
# None ("He's Got You", 'Brooks & Dunn', 191.79057)
# None ('No Soul (High Contrast Remix)', 'ILS', 350.61506)
# None ('Ban The Tube Top', 'Reel Big Fish', 190.69342)
# None ('Oceans', 'Pearl Jam', 161.48853)
# None ("I'll Just Fall", 'Lucero', 231.94077)
# None ('Never Say Never', 'Armin van Buuren', 452.23138)
# None ('Yeah!', "Usher Featuring Lil' Jon & Ludacris", 250.38322)
# None (None, None, nan)
# None ('It Was A Good Day', 'Ice Cube', 252.02893)
# None ('Use It', 'The New Pornographers', 206.81098)
# None ('Unchained Melody', 'Righteous Brothers', 215.90159)
# None ('Curura', 'Toto La Momposina', 299.02322)
# None ('Everything Is Alright (Album Version)', 'Motion City Soundtrack', 206.34077)
# None (None, None, nan)
# None ('Kong Unleashed (Album Version)', 'Misfits', 45.47873)
# None ('Pursuit Of Happiness (nightmare)', 'Kid Cudi / MGMT / Ratatat', 295.67955)
# None ('Bodies', 'Drowning Pool', 201.63873)
# None ('Strange Fruit', 'Cocteau Twins', 110.602)
# None ('The Technicolor Phase', 'Owl City', 267.65016)
# None ('Good Directions', 'Billy Currington', 215.82322)
# None ('How Long', 'Soul II Soul', 239.67302)
# None ('Disappearing World (Album Version)', 'David Gray', 304.77016)
# None ("Here's Your Sign Christmas (Album Version)", 'Bill Engvall', 148.84526)
# None ('Invalid', 'Tub Ring', 233.69098)
# None ("Efils' God", 'Eels', 199.65342)
# None ('Yes_ I Would', 'Frightened Rabbit', 278.72608)
# None ('Melody Of Life', 'Hit-O-Matic', 229.27628)
# None ('With Legs Like That', 'zebrahead', 187.34975)
# None ('Born On The Bayou', 'Creedence Clearwater Revival', 315.42812)
# None ('Everlong', 'Foo Fighters', 250.14812)
# None ('On They Slay', 'Atheist', 241.05751)
# None ('Romeo And Juliet', 'The Killers', 327.91465)
# None ('Why You Wanna (Amended Album Version)', 'T.I.', 214.77832)
# None ('The Power of Orange Knickers', 'Tori Amos Featuring Damien Rice', 215.82322)
# None ('Ftes', 'Peggy Zina', 287.00689)
# None ('Il Mio Amico', 'Anna Tatangelo', 218.93179)
# None ('St. Elsewhere', 'Dave Grusin', 255.50322)
# None ('Jump The Gun', 'Tim Christensen', 204.17261)
# None (None, None, nan)
# None ('Blindsided', 'Bon Iver', 329.24689)
# None ('Baptize Me', 'The Exies', 217.88689)
# None ('Fireworks (bonus track)', 'The Whitest Boy Alive', 191.29424)
# None ('Flashing Lights', 'Kanye West', 238.52363)
# None ('Poison Oak (Album Version)', 'Bright Eyes', 279.87546)
# None ('Sunlight Bathed the Golden Glow', 'Felt', 171.57179)
# None (None, None, nan)
# None (None, None, nan)
# Rolled back : Error Message : invalid input syntax for integer: ""
# LINE 3: values('2018-11-14T12:09:01.796000'::timestamp, '', 'paid', ...
#                                                         ^
#
# None (None, None, nan)
# Rolled back : Error Message : invalid input syntax for integer: ""
# LINE 3: values('2018-11-14T12:09:02.796000'::timestamp, '', 'paid', ...
#                                                         ^
#
# None (None, None, nan)
# None ('Better Off Alone', 'Alice Deejay', 216.5024)
# None ('Ball & Chain', 'Murder By Death', 182.25587)
# None ("Walkin' On The Sun", 'Smash Mouth', 206.36689)
# None ('Just Like You Imagined', 'Nine Inch Nails', 229.82485)
# None ('Tell Him', 'Lauryn Hill', 280.81587)
# None ('Somebody To Love', 'Justin Bieber', 220.89098)
# None (None, None, nan)
# None ('All Night Long', 'Junior Kimbrough And The Soul Blues Boys', 350.58893)
# None ('Tonebank Computer', 'Holy Fuck', 428.72118)
# None ('Closer', 'Jes', 233.87383)
# None ('When You Were Young', 'The Killers', 220.89098)
# None ('Stationary Stationery', 'Anberlin', 178.23302)
# None ('Billionaire [feat. Bruno Mars]  (Explicit Album Version)', 'Travie McCoy', 211.12118)
# None ('Only The Moment (All The Time In The World Mix)', 'Marc Almond', 387.65669)
# None ("Aber Dich Gibt's Nur Einmal FÃ\x83Â¼r Mich", 'Guildo Horn', 240.37832)
# None ('You Scared', 'DJ Paul', 208.45669)
# None ('Between The Bars', 'Elliott Smith', 141.42649)
# None ('Silver Coin', 'Angus & Julia Stone', 295.81016)
# None ('Gabbie', 'Umberto Tozzi', 369.13587)
# None ('Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Lonnie Gordon', 181.21098)
# None ('P.I.M.P.', '50 Cent', 249.52118)
# None ('Hochmah (Interlude)', 'Olivia Newton-John', 132.23138)
# None ("Ballin' (Explicit) (Feat. The Dramatics_ Lil' Half Dead)", "snoop Dogg Featuring The Dramatics_ Lil' Half Dead", 319.99955)
# None ('Da Funk / Dadftendirekt', 'Daft Punk', 396.82567)
# None ('Talk Show Host', 'Radiohead', 255.42485)
# None ('Something Happened On The Way To Heaven', 'Phil Collins', 291.00363)
# None ('All Hands Against His Own', 'The Black Keys', 196.91057)
# None ('Shining Down [feat. Matthew Santos] (Amended Album Version)', 'Lupe Fiasco', 273.94567)
# None ('Take Me Out', 'Franz Ferdinand', 247.24853)
# None ('Bracelets (LP Version)', 'The Spill Canvas', 204.90404)
# None ('Use Somebody', 'Kings Of Leon', 231.81016)
# None (None, None, nan)
# None ('Goodbye My Lover', 'James Blunt', 257.95873)
# None ('We Intertwined (Album Version)', 'The Hush Sound', 196.28363)
# None ('Move Along', 'The All-American Rejects', 238.86322)
# None ('Enough To Get Away With', 'Joseph Arthur', 167.75791)
# None ('Parliamo al singolare', 'Nek', 211.12118)
# None ('Always With Me_ Always With You', 'Joe Satriani', 201.63873)
# None ('Each Coming Night', 'Iron & Wine', 205.89669)
# None ('Wood Beez', 'Scritti Politti', 286.9024)
# None (None, None, nan)
# None (None, None, nan)
# Rolled back : Error Message : invalid input syntax for integer: ""
# LINE 3: values('2018-11-14T13:40:39.796000'::timestamp, '', 'paid', ...
#                                                         ^
#
# None (None, None, nan)
# None ('Crow Song', 'The Bats', 367.12444)
# None ('Joker And The Thief', 'Wolfmother', 280.86812)
# None ("Don't Go", 'Starting Rock Feat. Diva Avari', 367.62077)
# None (None, None, nan)
# None ('Wordplay (Album Version)', 'Jason Mraz', 187.50649)
# None ('Totem On The Timeline', 'Klaxons', 161.07057)
# None ('Nubes', 'Caifanes', 273.99791)
# None ('The Seeds of Pain', 'Information Society', 281.80853)
# None ("You Know You're Right", 'Nirvana', 218.06975)
# None ('Me', 'Erykah Badu', 336.45669)
# None ('Up Up & Away', 'Kid Cudi', 227.34322)
# None ('Sooner Or Later', 'That Petrol Emotion', 265.1424)
# None ('All My Life', 'K-Ci & JoJo', 331.31057)
# None (None, None, nan)
# Rolled back : Error Message : invalid input syntax for integer: ""
# LINE 3: values('2018-11-14T15:27:30.796000'::timestamp, '', 'free', ...
#                                                         ^
#
# None ('Love And Only Love (1991 Live LP Version)', 'Neil Young', 557.13914)
# None (None, None, nan)
# None ('Cemetery Gates', 'The Smiths', 159.08526)
# None ('DÃ\x83Â\xadmelo', 'Enrique Iglesias', 217.99138)
# None ('Always Attract', 'You Me At Six', 366.41914)
# None ("We Don't Care", 'Kanye West', 242.93832)
# None ('One And Only', 'Mariah Carey / Twista', 194.7424)
# None ('Heart Attack and Vine', "Screamin' Jay Hawkins", 265.50812)
# None ('Like I Love You', 'Justin Timberlake', 283.84608)
# None (None, None, nan)
# None ("I Need Your Lovin' (Like The Sunshine) (Radio Edit)", 'Marc Et Claude', 220.86485)
# None ('Marigold', 'Sparklehorse', 220.3424)
# None (None, None, nan)
# None (None, None, nan)
# Rolled back : Error Message : invalid input syntax for integer: ""
# LINE 3: values('2018-11-14T15:48:07.796000'::timestamp, '', 'free', ...
#                                                         ^
#
# None (None, None, nan)
# Rolled back : Error Message : invalid input syntax for integer: ""
# LINE 3: values('2018-11-14T15:48:19.796000'::timestamp, '', 'free', ...
#                                                         ^
#
# None ('No. 5', 'Hollywood Undead', 185.20771)
# None ('Hiding', 'Violet Indiana', 226.87302)
# None ('Politik', 'Coldplay', 318.6673)
# None ('New Divide (Album Version)', 'Linkin Park', 268.61669)
# None (None, None, nan)
# None ('Police Car', 'Eliza Doolittle', 200.30649)
# None ('Bodies and Minds', 'Great Lake Swimmers', 228.54485)
# None (None, None, nan)
# None ('Tijuca Man', 'Jackson Conti', 158.64118)
# None ('KissKiss', 'Parov Stelar', 281.5473)
# None ('Test Drive', 'Skalpel', 163.49995)
# None ('Sunglasses At Night', 'Tiga & Zyntherius', 502.85669)
# None ('Light It Up (LP Version)', 'Master P', 205.42649)
# None ('Drugs Or Me', 'Jimmy Eat World', 385.802)
# None ('LoveStoned/I Think She Knows', 'Justin Timberlake', 277.9424)
# None ('Definitely Maybe', 'FM Static', 170.81424)
# None (None, None, nan)
# None ('Gonna Fly Now (Theme From "Rocky")', 'Bill Conti', 169.97832)
# None ('Crying Lightning', 'Arctic Monkeys', 224.83546)
# None ('Hotel California', 'Eagles', 372.29669)
# None ('Such Great Heights', 'The Postal Service', 266.47465)
# None ('City Headache', 'Scott Matthews', 299.72853)
# None ('Unreflected', 'Mazzy Star', 222.1971)
# None ('Blood sugar', 'Pendulum', 312.97261)
# None ('Complicated', 'Avril Lavigne', 244.50567)
# None ('Lola', 'El Koala', 213.62893)
# None ('Love', 'Musiq', 304.69179)
# None ('Nada Que Perder (Live)', 'Los Pericos', 263.44444)
# None ('Milkshake', 'Holy Fuck', 209.76281)
# None (None, None, nan)
# None ('Electric Hearts', 'Cash Cash', 212.16608)
# None ('God', 'OutKast', 140.17261)
# None ('Jambalaya', 'Tab Benoit', 221.09995)
# None ('Eternal Flame (Single Version)', 'Atomic Kitten', 197.32853)
# None ('Composure', 'August Burns Red', 252.21179)
# None ('If Today Was Your Last Day (Album Version)', 'Nickelback', 248.05832)
# None ('The Wild Rover (Album Version)', 'Dropkick Murphys', 205.66159)
# None ('The Vision', 'Nocturnal Rites', 260.62322)
# None ("That's My Home", 'Tony Bennett & k.d. lang', 188.26404)
# None ('Sweetest Girl (Dollar Bill)', 'Wyclef Jean featuring Akon_ Lil Wayne_ and introducing Niia', 239.43791)
# None ('Catedral ( Catedral Song)', 'ZÃ\x83Â©lia Duncan', 170.78812)
# None ('Undo', 'BjÃ\x83Â¶rk', 348.57751)
# None ('Exchange', 'Massive Attack', 251.24526)
# None ('Someday', 'Miley Cyrus', 182.9873)
# None ('Walk Out To Winter', 'Aztec Camera', 204.72118)
# None ('El Hombre Dirigente', 'Spinetta Jade', 270.31465)
# None ('Snuff', 'Planet X', 299.38893)
# None ('Secrets', 'OneRepublic', 224.67873)
# None ('LoveStoned/I Think She Knows', 'Justin Timberlake', 355.99628)
# None ('A Message To You Rudy', 'The Specials', 174.10567)
# None ('Better Man', 'Pearl Jam', 268.7473)
# None ('Lost In This Moment', 'Big & Rich', 212.74077)
# None ('Eye Of The Tiger', 'Survivor', 245.36771)
# None (None, None, nan)
# None ('Sick', 'Sam Sparro', 247.17016)
# None ('Forget It', 'Breaking Benjamin', 216.31955)
# None ('Thanks Vision', 'Toro Y Moi', 224.33914)
# None ('DONTTRUSTME [BENNYBLANCOREMIX] FEATURINGKIDCUDI (Explicit Bonus Version)', '3OH!3', 196.28363)
# None ('Give It Back', 'Polly Paulusma', 222.9024)
# None ('Black Man Ray', 'China Crisis', 219.32363)
# None ('Elliptical', "Me'Shell Ndegeocello", 334.86322)
# None ('Belle-Ile-En-Mer', 'Laurent Voulzy', 240.92689)
# None ('Ave Maria No Morro', 'JoÃ\x83Â£o Gilberto', 258.37669)
# None (None, None, nan)
# None (None, None, nan)
# Rolled back : Error Message : invalid input syntax for integer: ""
# LINE 3: values('2018-11-14T19:38:09.796000'::timestamp, '', 'paid', ...
#                                                         ^
#
# None (None, None, nan)
# Rolled back : Error Message : invalid input syntax for integer: ""
# LINE 3: values('2018-11-14T19:38:34.796000'::timestamp, '', 'paid', ...
#                                                         ^
#
# None (None, None, nan)
# Rolled back : Error Message : invalid input syntax for integer: ""
# LINE 3: values('2018-11-14T19:38:50.796000'::timestamp, '', 'paid', ...
#                                                         ^
#
# None ('In Your Eyes (LP Version)', 'Keith Sweat', 312.99873)
# None ('Rally', 'Phoenix', 195.91791)
# None ('The City Sleeps', 'MC 900 Ft. Jesus', 331.31057)
# None ('Danger Zone', 'Gwen Stefani', 216.76363)
# None ('You Got Me', 'VHS Or Beta', 216.94649)
# None ('Undo', 'BjÃ\x83Â¶rk', 348.57751)
# None ('Not Big', 'Lily Allen', 194.66404)
# None ('(Nice Dream)', 'Radiohead', 231.91465)
# None ("You're The One", 'Dwight Yoakam', 239.3073)
# None (None, None, nan)
# None (None, None, nan)
# None ('The Message', 'Grandmaster Flash & The Furious Five', 429.63546)
# None ('Chanson Sur Une Seule Note Samba De Uma Nota So', 'MichÃ\x83Â¨le Arnaud', 105.50812)
# None ('Breathe', 'Prodigy', 335.90812)
# None ('My Best Days Are Ahead Of Me', 'Danny Gokey', 187.08853)
# None ('Is This The World We Created? (1994 Digital Remaster)', 'Queen', 134.71302)
# None ("Ole Black 'n' Blue Eyes", 'The Fratellis', 196.25751)
# None ("What I've Done (Album Version)", 'Linkin Park', 208.92689)
# None ('SueÃ\x83Â±o de Una Noche de Verano', 'Silvio Rodriguez', 381.3873)
# None ('The Tower', 'Avantasia', 582.73914)
# None ('White Winter Hymnal', 'Fleet Foxes', 147.04281)
# None ('Not The American Average (feat. NO)', 'Asking Alexandria', 278.83057)
# None ("We Don't Care", 'Kanye West', 242.93832)
# None ('Monsoon', 'Jack Johnson', 264.82893)
# None ('What Is Love', 'Haddaway', 223.97342)
# None ('Sting Me', 'The Black Crowes', 279.7971)
# None ('This Is Something for the Radio', 'Biz Markie', 314.14812)
# None ('Brother Sport', 'Animal Collective', 359.02649)
# None ('Given Up (Album Version)', 'Linkin Park', 189.28281)

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
